# %% [markdown]
# ## WSD using BERT Masked Language Model
# This notebook explores the a part of the idea proposed by Ajit Rakasekharan in his blog post
# [Examining BERT raw embeddings.](https://towardsdatascience.com/examining-berts-raw-embeddings-fd905cb22df7)
#
# The idea is that examining the predictions of a masked language model for a masked ambiguous word can yield insights into the semantic meaning of the ambiguous word.
#
# We use the HuggingFace BERT for Masked LM with weights from a bert-base-cased pre-trained model for our experiment.
#
# We mask the ambiguous word (here we have used bank for our test) in sentences, and then send them through a BERT MLM model. Output is an array of logits for each position of the input sequence. So assuming a sentence with T tokens and a vocabulary size of V, the predictions of the MLM is (1, T, V) where 1 is the batch size (1 input sentence at a time in our experiment).
#
# In order to find the top k predictions, the logits for the masked position is softmaxed and the top k values chosen.

# %% [markdown]
# ## Prepare your environment
#
# As always, we highly recommend that you install all packages with a virtual environment manager, like [venv](https://packaging.python.org/en/latest/guides/installing-using-pip-and-virtual-environments/) or [conda](https://docs.conda.io/projects/conda/en/latest/user-guide/getting-started.html), to prevent version conflicts of different packages.

# %% [markdown]
# ### Masked LM Model and Tokenizer
# [tutorial](https://huggingface.co/docs/transformers/tasks/language_modeling)
# Task is to predict words that are masked using BERT, so we will use BERTMaskedLM model and BERTTokenizer and use the pre-trained bert-base-uncased model.

# %%
import pandas as pd
import torch
from transformers import BertTokenizer, BertForMaskedLM

# %%
tokenizer = BertTokenizer.from_pretrained('bert-base-cased')
model = BertForMaskedLM.from_pretrained('bert-base-cased', return_dict=True)
# Out:
# Some weights of the model checkpoint at bert-base-cased were not used when initializing BertForMaskedLM: ['cls.seq_relationship.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %% [markdown]
# We are going to use the pre-trained BERT language model in inference mode only.
#
# The tokenizer tokenizes the input sequence and pads it with the [CLS] and [SEP] tokens.
#
# The output produced by the model has two components, loss and logits. The logits component has shape (1, number_of_tokens, vocab_size) where the leading 1 represents the single input sentence.
#
# We will identify the logits corresponding to the position of our masked token, identify the top 5 vocabulary words predicted for that position, and return the softmax probabilities for each of the top 5 predicted words.

# %%
inputs = tokenizer("The capital of France is [MASK].", return_tensors="pt")
outputs = model(**inputs)

# %%
tokenizer.convert_ids_to_tokens(inputs.input_ids[0])
# Out:
# ['[CLS]', 'The', 'capital', 'of', 'France', 'is', '[MASK]', '.', '[SEP]']

# %%
outputs.logits.shape
# Out:
# torch.Size([1, 9, 28996])

# %%
outputs.logits
# Out:
# tensor([[[ -7.1545,  -6.9931,  -7.1826,  ...,  -5.9124,  -5.6733,  -5.9854],
#          [ -8.0190,  -8.1319,  -8.0509,  ...,  -6.5679,  -6.4058,  -6.8998],
#          [ -4.9772,  -6.1781,  -6.0669,  ...,  -5.6362,  -4.6603,  -5.1241],
#          ...,
#          [ -3.4420,  -3.2557,  -3.5733,  ...,  -2.4606,  -2.6495,  -3.1952],
#          [-10.5890, -10.4621, -11.7181,  ...,  -7.4646,  -9.9543,  -8.3927],
#          [-14.8900, -14.8873, -14.4569,  ..., -11.6588, -13.0151, -11.6073]]],
#        grad_fn=<ViewBackward0>)

# %%
outputs.logits[0][0][100]
# Out:
# tensor(0.5711, grad_fn=<SelectBackward0>)

# %%
inputs.input_ids
# Out:
# tensor([[ 101, 1109, 2364, 1104, 1699, 1110,  103,  119,  102]])

# %%
def get_mask_index(input_ids, tokenizer):
    x = input_ids[0]
    is_masked = torch.where(x == tokenizer.mask_token_id, x, 0)
    mask_idx = torch.nonzero(is_masked)
    return mask_idx.item()

mask_idx = get_mask_index(inputs.input_ids, tokenizer)
mask_idx
# Out:
# 6

# %%
def get_top_k_predictions(pred_logits, mask_idx, top_k):
    probs = torch.nn.functional.softmax(pred_logits[0, mask_idx, :], dim=-1)
    top_k_weights, top_k_indices = torch.topk(probs, top_k, sorted=True)
    top_k_pct_weights = [100 * x.item() for x in top_k_weights]
    top_k_tokens = tokenizer.convert_ids_to_tokens(top_k_indices)
    return list(zip(top_k_tokens, top_k_pct_weights))


get_top_k_predictions(outputs.logits, mask_idx, 5)
# Out:
# [('Paris', 44.46821212768555),
#  ('Lyon', 9.396013617515564),
#  ('Toulouse', 8.234520256519318),
#  ('Lille', 7.515154033899307),
#  ('Marseille', 5.692289397120476)]

# %% [markdown]
# ### WSD Test Sentences
# We take our pair of sentences for disambiguating the word bank and mask them, and extract the top 20 predictions from the pre-trained BERT MLM model.
#
# As expected, the first set of predictions predominantly point to some sort of financial institution, whereas the second set of predictions predominantly point to some geographical formation around bodies of water.

# %%
sentences = [
  "Go to the [MASK] and deposit your pay check.",
  "Jim and Janet went down to the river [MASK] to admire the swans."
]

# %%
def get_predictions(sentence, tokenizer, model):
    inputs = tokenizer(sentence, return_tensors="pt")
    outputs = model(**inputs)
    mask_idx = get_mask_index(inputs.input_ids, tokenizer)
    top_preds = get_top_k_predictions(outputs.logits, mask_idx, 20)
    return top_preds

# %%
get_predictions(sentences[0], tokenizer, model)
# Out:
# [('bank', 70.31388878822327),
#  ('office', 10.280612856149673),
#  ('register', 1.745203323662281),
#  ('store', 1.6284776851534843),
#  ('bathroom', 0.9394790045917034),
#  ('library', 0.893486849963665),
#  ('desk', 0.8724372833967209),
#  ('counter', 0.7977361790835857),
#  ('hotel', 0.5163752939552069),
#  ('lobby', 0.4956980235874653),
#  ('kitchen', 0.3637084970250726),
#  ('garage', 0.34799231216311455),
#  ('door', 0.3412739373743534),
#  ('car', 0.33113795798271894),
#  ('house', 0.26490604504942894),
#  ('airport', 0.25470347609370947),
#  ('elevator', 0.24911430664360523),
#  ('back', 0.24807732552289963),
#  ('computer', 0.24019635748118162),
#  ('banks', 0.23491408210247755)]

# %%
get_predictions(sentences[1], tokenizer, model)
# Out:
# [('##bank', 32.60203301906586),
#  ('below', 13.032017648220062),
#  ('bank', 11.940890550613403),
#  (',', 5.626513808965683),
#  ('##boat', 3.1638912856578827),
#  ('##front', 2.733219973742962),
#  ('basin', 1.6210557892918587),
#  ('##bed', 1.2178429402410984),
#  ('together', 1.1841758154332638),
#  ('bed', 0.9657194837927818),
#  ('again', 0.8369872346520424),
#  ('deck', 0.8356154896318913),
#  ('valley', 0.7271421141922474),
#  ('mouth', 0.7227553520351648),
#  ('boat', 0.7151072844862938),
#  ('pier', 0.649328576400876),
#  ('house', 0.6301597692072392),
#  ('banks', 0.5700565874576569),
#  ('pool', 0.5345731042325497),
#  ('Thames', 0.4995553754270077)]

# %% [markdown]
# ## Assignment
# In this week's assignment, you are tasked with processing SemCor data and feed the data into BERT masked-LM. After that, use the predictions to find the most likely sense of the target word using WordNet similarity.

# %% [markdown]
# ### Data Preprocessing
# You can find a sample of SemCor dataset [here](https://drive.google.com/file/d/1inmv3rUcGrtiS4VQwTMsT9HF-iL8jc5V/view?usp=sharing) and load the data using the following methods.

# %%
import json
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet as wn
sents = []
tokens = []
wn_id = []
lemmatizer = WordNetLemmatizer()

with open('semcor.sample.jsonl') as f:
    for line in f:
        data = json.loads(line)
        sents.append(data['sent'])
        tokens.append(data['tokens'])
        wn_id.append(data['wnid'])

# %%
import nltk
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /home/nlplab/yhc/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
for index in range(len(sents)):
    if len(wn_id[index]) !=  len(tokens[index]): 
        print(index, len(wn_id[index]) , len(tokens[index]))

# %%
# The WordNet ID can be converted to NLTK Lemma using the following function
wn.lemma_from_key('implementation%1:04:01::')
# Out:
# Lemma('execution.n.06.implementation')

# %% [markdown]
# ### TODO
# Please implement a method to convert the data to BERT Masked-LM format and keep track of the headword. Store the data into the following lists
#
# word[i] = 'implementation'
# ground_truth[i] = 'implementation%1:04:01::'
# sent[i] = "[MASK] of georgia 's automobile title law was also recommended by the outgoing jury ."

# %%
word = []
ground_truth = []
sent = []

for index in range(len(sents)):
    for index1 in range(len(tokens[index])):
        if wn_id[index][index1]!=0:
            #print(f'index: {index}, index1: {index1}')
            #sentence = sents[index]
            #tmp_tokens = sentence.split()
            #print(tmp_tokens[index1])
            ground_truth.append(wn_id[index][index1])
            word.append(tokens[index][index1])
            
            tmp_tokens =  tokens[index].copy()
            tmp_tokens[index1] = '[MASK]'
            modify_str = ' '.join(str(e) for e in tmp_tokens)
            sent.append(modify_str)

# %%
sent[200]
# Out:
# "the jury also commented on the fulton ordinary 's court which has been under fire for its [MASK] in the appointment of appraisers , guardians and administrators and the awarding of fees and compensation ."

# %%
ground_truth[0]
# Out:
# 'say%2:32:00::'

# %%
print(len(sent))
print(len(word))
print(len(ground_truth))
# Out:
# 1042
# 1042
# 1042

# %% [markdown]
# #### Identify the top 5 predictions other than the headword using Masked-LM
# 1. Use get_predictions to get the predicted words
# 2. Use lemmatizer to lemmatize the prediction
# 3. Remove headword
# 4. Keep top 5 unique predictions

# %%
get_predictions(sent[4], tokenizer, model)
# Out:
# [('2010', 13.912227749824524),
#  ('2008', 7.134079933166504),
#  ('2012', 4.418175294995308),
#  ('2006', 4.327632486820221),
#  ('2009', 3.2670795917510986),
#  ('2004', 3.139011934399605),
#  ('2007', 3.1135501340031624),
#  ('2011', 2.980724535882473),
#  ('2005', 2.7421828359365463),
#  ('2016', 2.4403834715485573),
#  ('2002', 2.3336390033364296),
#  ('2013', 2.2248294204473495),
#  ('2014', 2.1104879677295685),
#  ('first', 1.676163636147976),
#  ('November', 1.5382764860987663),
#  ('2003', 1.4332271181046963),
#  ('May', 1.2353728525340557),
#  ('Democratic', 1.1448323726654053),
#  ('2000', 1.0835643857717514),
#  ('Republican', 1.0767881758511066)]

# %%
import re 
print(re.search(r'\d', 'dadacc3sd') )
# Out:
# <re.Match object; span=(6, 7), match='3'>

# %%
candidate_lemmas = []

dump_punctuation = ['-', ';', '\'', '.', ',', '\\', ':']

for index in range(len(sent)):
    #print(sent[index])
    prediction = get_predictions(sent[index], tokenizer, model)
    
    individual_lemmas = []
    for index1 in range(len(prediction)):
        err = 0
        # ex: ('-', 1.1574707925319672) 取tuple前面第一個
        tmp_tokens = prediction[index1][0]
        if re.search(r'\d', tmp_tokens):
            continue
        for i in tmp_tokens:
            # checking whether the char is punctuation.
            if i in string.punctuation:
                err = 1
        if err == 1:
            continue
        if any(c.isdigit() for c in tmp_tokens):
            continue
            
        if tmp_tokens not in dump_punctuation:
            if lemmatizer.lemmatize(tmp_tokens) != lemmatizer.lemmatize(word[index]):
                individual_lemmas.append(lemmatizer.lemmatize(tmp_tokens))
            if len(individual_lemmas) == 5:
                break
    candidate_lemmas.append(individual_lemmas)
#get_predictions(sent[0], tokenizer, model)
#lemmatizer(get_predictions(sent[0], tokenizer, model))

# use nltk.wordnet.similarity

# %%
# candidate_lemmas =[ [], [], [], ... ], i = 50th
# candidate_lemmas中一個list of list 對應到sent[i], i = 50th
candidate_lemmas
# Out:
# [['found', 'and', 'in', 'concluded', 'told'],
#  ['that', 'after', 'in', 'during', 'of'],
#  ['analysis', 'examination', 'audit', 'evaluation', 'inspection'],
#  ['California', 'Virginia', 'Florida', 'Arizona', 'Alabama'],
#  ['first', 'November', 'May', 'Democratic', 'Republican'],
#  ['municipal', 'general', 'recall', 'presidential', 'gubernatorial'],
#  ['found', 'showed', 'uncovered', 'revealed', 'discovered'],
#  ['indication', 'proof', 'sign', 'information', 'confirmation'],
#  ['violence', 'election', 'voting', 'fraud', 'election'],
#  ['take', 'taking', 'in', 'taken', 'did'],
#  ['mayor', 'governor', 'president', 'council', 'city'],
#  ['stated', 'declared', 'noted', 'concluded', 'reported'],
#  ['the', 'it', 'their', 'his', 'her'],
#  ['of', 'three', 'two', 'length', 'court'],
#  ['celebration', 'term', 'celebration', 'remark', 'speech'],
#  ['took', 'ha', 'take', 'hold', 'held'],
#  ['knowledge', 'control', 'coverage', 'approval', 'account'],
#  ['contest', 'matter', 'event', 'vote', 'city'],
#  ['received', 'deserved', 'expressed', 'deserve', 'gave'],
#  ['respect', 'thanks', 'support', 'recognition', 'appreciation'],
#  ['respect', 'recognition', 'admiration', 'appreciation', 'attention'],
#  ['way', 'circumstance', 'year', 'order', 'spirit'],
#  ['vote', 'voting', 'polling', 'contest', 'poll'],
#  ['held', 'won', 'done', 'arranged', 'organised'],
#  ['four', 'two', 'three', 'first', 'five'],
#  ['long', 'first', 'mid', 'last', 'second'],
#  ['the', 'a', 'grand', 'trial', 'and'],
#  [],
#  ['appointed', 'convened', 'formed', 'hired', 'called'],
#  ['make', 'file', 'receive', 'report', 'produce'],
#  ['allegation', 'evidence', 'charge', 'claim', 'accusation'],
#  ['alleged', 'voting', 'financial', 'the', 'election'],
#  ['corruption', 'fraud', 'interference', 'flaw', 'sabotage'],
#  ['Democratic', 'Republican', 'state', 'party', 'presidential'],
#  ['election', 'case', 'contest', 'trial', 'race'],
#  ['decided', 'led', 'headed', 'contested', 'called'],
#  ['Only', 'Not', 'Quite', 'But', 'Perhaps'],
#  ['small', 'mere', 'select', 'very', 'tiny'],
#  ['number', 'lack', 'majority', 'few', 'amount'],
#  ['positive', 'negative', 'favorable', 'reliable', 'credible'],
#  ['vote', 'ballot', 'signature', 'proposal', 'call'],
#  ['published', 'made', 'produced', 'credible', 'available'],
#  ['newspaper', 'paper', 'report', 'Times', 'Guardian'],
#  ['wrote', 'concluded', 'noted', 'reported', 'stated'],
#  ['reflecting', 'given', 'despite', 'for', 'indicating'],
#  ['public', 'popular', 'national', 'local', 'general'],
#  ['turnout', 'fraud', 'corruption', 'violence', 'bias'],
#  ['city', 'area', 'matter', 'issue', 'race'],
#  ['percentage', 'proportion', 'turnout', 'size', 'lack'],
#  ['candidate', 'vote', 'supporter', 'participant', 'witness'],
#  ['population', 'reputation', 'status', 'character', 'history'],
#  ['electorate', 'constituency', 'district', 'community', 'group'],
#  ['government', 'BBC', 'newspaper', 'report', 'commission'],
#  ['stated', 'noted', 'found', 'admitted', 'indicated'],
#  ['note', 'show', 'notice', 'believe', 'agree'],
#  ['California', 'Georgia', 'Canada', 'Oregon', 'Arizona'],
#  ['law', 'constitutional', 'constitution', 'election', 'law'],
#  ['licensing', 'registration', 'copyright', 'trademark', 'tax'],
#  ['document', 'procedure', 'record', 'rule', 'requirement'],
#  ['were', 'appear', 'seem', 'remain', 'appeared'],
#  ['inadequate', 'weak', 'obsolete', 'inconsistent', 'vague'],
#  ['obsolete', 'inconsistent', 'archaic', 'vague', 'ineffective'],
#  ['politically', 'sometimes', 'somewhat', 'too', 'potentially'],
#  ['violated', 'corrupt', 'ineffective', 'unconstitutional', 'unreliable'],
#  ['requires', 'state', 'stated', 'required', 'demanded'],
#  ['should', 'commissioner', 'would', 'could', 'Commissioners'],
#  ['continue', 'agree', 'were', 'work', 'agreed'],
#  ['see', 'get', 'keep', 'make', 'consider'],
#  ['regulation', 'statute', 'policy', 'program', 'standard'],
#  ['revised', 'amended', 'updated', 'modified', 'repealed'],
#  ['brought', 'worked', 'put', 'fought', 'promoted'],
#  ['point', 'purpose', 'goal', 'aim', 'extent'],
#  ['writing', 'time', 'life', 'taking', 'drafting'],
#  ['replacing', 'implementing', 'expanding', 'extending', 'strengthening'],
#  ['expert', 'national', 'special', 'same', 'selection'],
#  ['reported', 'focused', 'spoke', 'decided', 'agreed'],
#  ['variety', 'range', 'host', 'multitude', 'series'],
#  ['different', 'key', 'important', 'related', 'policy'],
#  ['department', 'matter', 'issue', 'problem', 'factor'],
#  ['county', 'local', 'district', 'county', 'city'],
#  ['police', 'health', 'government', 'planning', 'fire'],
#  ['concluded', 'found', 'stated', 'noted', 'declared'],
#  ['remain', 'were', 'be', 'is', 'have'],
#  ['independently', 'properly', 'jointly', 'poorly', 'efficiently'],
#  ['established', 'managed', 'organized', 'developed', 'organised'],
#  ['are', 'have', 'meet', 'fairly', 'reflect'],
#  ['widely', 'well', 'internationally', 'universally', 'broadly'],
#  ['principle', 'procedure', 'policy', 'standard', 'law'],
#  ['appeal', 'are', 'serve', 'contribute', 'cater'],
#  ['common', 'public', 'mutual', 'joint', 'national'],
#  ['practice', 'effort', 'advantage', 'wish', 'judgment'],
#  ['party', 'side', 'country', 'community', 'state'],
#  ['However', 'Additionally', 'Furthermore', 'Nevertheless', 'Finally'],
#  ['government', 'company', 'firm', 'university', 'board'],
#  ['stated', 'say', 'indicated', 'state', 'noted'],
#  ['believed', 'concluded', 'found', 'felt', 'thought'],
#  ['three', 'four', 'five', 'six', 'new'],
#  ['approach', 'factor', 'technology', 'strategy', 'measure'],
#  ['provide', 'promote', 'ensure', 'foster', 'bring'],
#  ['more', 'increased', 'better', 'higher', 'economic'],
#  ['transparency', 'autonomy', 'effectiveness', 'productivity', 'security'],
#  ['lower', 'minimize', 'decrease', 'avoid', 'le'],
#  ['burden', 'complexity', 'effectiveness', 'efficiency', 'quality'],
#  ['operation', 'operation', 'litigation', 'operating', 'construction'],
#  ['report', 'mayor', 'city', 'commission', 'agency'],
#  ['noted', 'stated', 'say', 'state', 'reported'],
#  ['wa', 'were', 'remains', 'are', 'became'],
#  ['bringing', 'interested', 'drawing', 'investing', 'filling'],
#  ['adequate', 'qualified', 'it', 'quality', 'effective'],
#  ['police', 'management', 'administrative', 'government', 'city'],
#  ['staff', 'skill', 'experience', 'support', 'work'],
#  ['part', 'consequence', 'component', 'matter', 'feature'],
#  ['poor', 'inadequate', 'changing', 'it', 'weak'],
#  ['purchasing', 'hiring', 'management', 'planning', 'buying'],
#  ['shortage', 'shortage', 'training', 'misconduct', 'abuse'],
#  ['recommended', 'requires', 'requested', 'demanded', 'suggested'],
#  ['government', 'state', 'Government', 'public', 'Council'],
#  ['make', 'undertake', 'pursue', 'consider', 'took'],
#  ['action', 'measure', 'action', 'care', 'effort'],
#  ['address', 'solve', 'resolve', 'tackle', 'fix'],
#  ['situation', 'issue', 'crisis', 'condition', 'disaster'],
#  ['Enforcement', 'Part', 'Application', 'Passage', 'Much'],
#  ['California', 'Michigan', 'Pennsylvania', 'Florida', 'Georgia'],
#  ['land', 'new', 'civil', 'territorial', 'property'],
#  ['tax', 'safety', 'insurance', 'ownership', 'registration'],
#  ['system', 'scheme', 'design', 'change', 'proposal'],
#  ['not', 'strongly', 'unanimously', 'then', 'again'],
#  ['approved', 'rejected', 'blocked', 'criticized', 'opposed'],
#  ['grand', 'same', 'federal', 'national', 'state'],
#  ['government', 'parliament', 'cabinet', 'governor', 'legislature'],
#  ['required', 'recommended', 'requires', 'requested', 'proposed'],
#  ['state', 'provincial', 'new', 'Ontario', 'State'],
#  ['government', 'Parliament', 'amendment', 'legislation', 'parliament'],
#  ['appropriate', 'raise', 'approve', 'withdraw', 'consider'],
#  ['the', 'additional', 'sufficient', 'more', 'public'],
#  ['legislation', 'power', 'provision', 'measure', 'guidance'],
#  ['implementation', 'commencement', 'election', 'appropriate', 'adoption'],
#  ['budget', 'law', 'rule', 'rate', 'period'],
#  ['reform', 'revision', 'change', 'review', 'repeal'],
#  ['Act', 'bill', 'legislation', 'plan', 'act'],
#  ['undertaken', 'achieved', 'conducted', 'made', 'pursued'],
#  ['federal', 'trial', 'same', 'state', 'defense'],
#  ['list', 'allocation', 'use', 'review', 'collection'],
#  ['the', 'state', 'all', 'public', 'government'],
#  ['grant', 'funding', 'subsidy', 'assistance', 'permit'],
#  ['used', 'needed', 'allocated', 'required', 'available'],
#  ['social', 'infant', 'basic', 'youth', 'public'],
#  ['private', 'nursing', 'state', 'public', 'retirement'],
#  ['wa', 'being', 'constitutes', 'remains', 'form'],
#  ['none', 'some', 'another', 'two', 'all'],
#  ['key', 'basic', 'essential', 'main', 'important'],
#  ['issue', 'problem', 'factor', 'change', 'flaw'],
#  ['financial', 'social', 'public', 'welfare', 'economic'],
#  ['welfare', 'aid', 'fund', 'fund', 'insurance'],
#  ['plan', 'system', 'scheme', 'package', 'fund'],
#  ['report', 'court', 'governor', 'state', 'letter'],
#  ['stated', 'wrote', 'noted', 'reported', 'state'],
#  ['get', 'transfer', 'pas', 'direct', 'send'],
#  ['item', 'money', 'payment', 'dollar', 'benefit'],
#  ['various', 'health', 'other', 'different', 'social'],
#  ['agency', 'program', 'system', 'system', 'service'],
#  ['both', 'most', 'All', 'each', 'any'],
#  ['municipality', 'state', 'community', 'city', 'district'],
#  ['county', 'district', 'country', 'State', 'area'],
#  ['consent', 'assistance', 'support', 'help', 'benefit'],
#  ['ha', 'received', 'get', 'need', 'provides'],
#  ['funding', 'assistance', 'information', 'aid', 'fund'],
#  ['group', 'organization', 'committee', 'board', 'state'],
#  ['say', 'stated', 'claimed', 'indicated', 'noted'],
#  ['believed', 'thought', 'feared', 'felt', 'believe'],
#  ['massive', 'large', 'mass', 'poor', 'narrow'],
#  ['amount', 'portion', 'share', 'percentage', 'proportion'],
#  ['vote', 'number', 'item', 'voter', 'case'],
#  ['benefit', 'affect', 'support', 'help', 'impact'],
#  ['system', 'process', 'trend', 'situation', 'effort'],
#  ['most', 'more', 'least', 'very', 'many'],
#  ['developed', 'affluent', 'populated', 'prosperous', 'fortunate'],
#  ['country', 'region', 'community', 'country', 'area'],
#  ['However', 'Also', 'Additionally', 'Furthermore', 'Finally'],
#  ['believe', 'hope', 'expect', 'agree', 'think'],
#  ['have', 'retain', 'use', 'provide', 'keep'],
#  ['a', 'it', 'their', 'another', 'no'],
#  ['more', 'part', 'share', 'use', 'proportion'],
#  ['trust', 'state', 'public', 'tax', 'additional'],
#  ['asset', 'resource', 'land', 'right', 'grant'],
#  ['report', 'commission', 'governor', 'court', 'board'],
#  ['wrote', 'stated', 'noted', 'agreed', 'concluded'],
#  ['Trying', 'Having', 'And', 'How', 'Continuing'],
#  ['accomplish', 'achieve', 'implement', 'address', 'pay'],
#  ['tend', 'lead', 'seem', 'have', 'appear'],
#  ['impose', 'put', 'be', 'create', 'have'],
#  ['huge', 'heavy', 'tremendous', 'great', 'significant'],
#  ['value', 'toll', 'price', 'pressure', 'impact'],
#  ['member', 'Park', 'himself'],
#  ['report', 'paper', 'article', 'newspaper', 'BBC'],
#  ['ha', 'had', 'then', 'later', 'further'],
#  ['called', 'sat', 'reported', 'sits', 'relied'],
#  ['family', 'mill', 'court', 'church', 'parish'],
#  ['reputation', 'practice', 'work', 'jurisdiction', 'organisation'],
#  ['on', 'fighting', 'set', 'caught', 'given'],
#  ['role', 'involvement', 'part', 'interference', 'failure'],
#  ['prosecution', 'court', 'employment', 'training', 'hiring'],
#  ['judge', 'trustee', 'parent', 'lawyer', 'teacher'],
#  ['manager', 'lawyer', 'contractor', 'judge', 'director'],
#  ['trustee', 'manager', 'director', 'employee', 'assistant'],
#  ['distribution', 'payment', 'administration', 'provision', 'collection'],
#  ['damage', 'contract', 'compensation', 'benefit', 'commission'],
#  ['fine', 'benefit', 'fee', 'award', 'grant'],
#  ['court', 'judge', 'report', 'commission', 'committee'],
#  ['stated', 'concluded', 'noted', 'wrote', 'reported'],
#  ['said', 'felt', 'believed', 'noted', 'thought'],
#  ['jury', 'judge', 'commission', 'tribunal', 'committee'],
#  ['adopted', 'introduced', 'integrated', 'taken', 'put'],
#  ['judicial', 'own', 'administrative', 'legal', 'constitutional'],
#  ['work', 'finding', 'procedure', 'decision', 'action'],
#  ['the', 'three', 'several', 'four', 'five'],
#  ['state', 'local', 'other', 'separate', 'independent'],
#  ['state', 'county', 'judicial', 'advisory', 'district'],
#  ['elected', 'independent', 'active', 'individual', 'autonomous'],
#  ['judicial', 'advisory', 'law', 'judiciary', 'appeal'],
#  ['measure', 'provision', 'rule', 'law', 'arrangement'],
#  ['aim', 'help', 'be', 'seek', 'have'],
#  ['free', 'shield', 'save', 'recover', 'prevent'],
#  ['the', 'that', 'this', 'historical', 'a'],
#  ['to', 'at', 'into', 'even', 'with'],
#  ['city', 'town', 'City', 'state', 'government'],
#  ['judge', 'staff', 'jurisdiction', 'employee', 'member'],
#  ['court', 'it', 'legal', 'administrative', 'litigation'],
#  ['scrutiny', 'influence', 'criticism', 'pressure', 'abuse'],
#  ['judge', 'elected', 'officer', 'member', 'judicial'],
#  ['appointed', 'unpaid', 'qualified', 'paid', 'trusted'],
#  ['judge', 'member', 'officer', 'official', 'commissioner'],
#  ['such', 'public', 'any', 'external', 'adverse'],
#  ['conduct', 'expense', 'penalty', 'litigation', 'liability'],
#  ['court', 'judge', 'Court', 'report', 'government'],
#  ['wrote', 'concluded', 'noted', 'stated', 'reported'],
#  ['Regarding', 'For', 'On', 'With', 'In'],
#  ['Singapore', 'Chicago', 'Houston', 'Washington', 'Miami'],
#  ['one', 'two', 'five', 'three', 'four'],
#  ['billion', 'US', 'thousand', 'one', 'trillion'],
#  ['seater', 'euro', 'passenger', 'capacity', 'seat'],
#  ['contract', 'plan', 'bid', 'acquisition', 'investment'],
#  ['government', 'report', 'commission', 'board', 'committee'],
#  ['decided', 'concluded', 'stated', 'found', 'determined'],
#  ['airport', 'city', 'local', 'Airport', 'municipal'],
#  ['mayor', 'government', 'governor', 'judge', 'president'],
#  ['will', 'can', 'is', 'shall', 'ha'],
#  ['of', 'number', 'level', 'Phase', '№'],
#  ['Airport', 'facility', 'aircraft', 'terminal', 'airfield'],
#  ['renovated', 'rebuilt', 'run', 'upgraded', 'expanded'],
#  ['way', 'style', 'fashion', 'direction', 'state'],
#  ['avoid', 'remove', 'reduce', 'exclude', 'minimize'],
#  ['external', 'foreign', 'adverse', 'outside', 'negative'],
#  ['corruption', 'interference', 'opposition', 'instability', 'violence'],
#  ['report', 'government', 'commission', 'Commission', 'court'],
#  ['later', 'indeed', 'no', 'never', 'nothing'],
#  ['agree', 'comment', 'disagree', 'respond', 'report'],
#  ['concluded', 'recommended', 'found', 'ruled', 'held'],
#  ['been', 'exist', 'remain', 'occur', 'come'],
#  ['adequate', 'extensive', 'a', 'proper', 'no'],
#  ['review', 'monitoring', 'scrutiny', 'investigation', 'analysis'],
#  ['business', 'economic', 'trading', 'financial', 'trade'],
#  ['policy', 'activity', 'behaviour', 'arrangement', 'system'],
#  ['company', 'company', 'firm', 'defendant', 'party'],
#  ['sake', 'benefit', 'aim', 'reason', 'objective'],
#  ['making', 'rendering', 'setting', 'holding', 'maintaining'],
#  ['rate', 'condition', 'claim', 'cost', 'rate'],
#  ['low', 'stable', 'high', 'down', 'level'],
#  ['these', 'all', 'such', 'those', 'technical'],
#  ['issue', 'occasion', 'ground', 'count', 'question'],
#  ['committee', 'Commission', 'Committee', 'commission', 'Court'],
#  ['found', 'decided', 'determined', 'held', 'concluded'],
#  ['Two', 'two', 'Three', 'and', 'The'],
#  ['county', 'sheriff', 'state', 'deputy', 'jail'],
#  ['officer', 'men', 'inmate', 'staff', 'member'],
#  ['stationed', 'housed', 'appointed', 'trained', 'hired'],
#  ['clerk', 'nurse', 'physician', 'lawyer', 'deputy'],
#  ['an', 'dental', 'prison', 'veterinary', 'military'],
#  ['nurse', 'assistant', 'clerk', 'doctor', 'teacher'],
#  ['assigned', 'appointed', 'hired', 'designated', 'responsible'],
#  ['day', 'evening', 'weekday', 'morning', 'afternoon'],
#  ['day', 'morning', 'night', 'evening', 'afternoon'],
#  ['work', 'shift', 'service', 'operation', 'service'],
#  ['prison', 'courthouse', 'facility', 'hospital', 'time'],
#  ['will', 'would', 'also', 'must', 'ha'],
#  ['worked', 'partnered', 'negotiated', 'collaborated', 'voted'],
#  ['elected', 'local', 'public', 'municipal', 'City'],
#  ['leader', 'council', 'government', 'commissioner', 'voter'],
#  ['draft', 'create', 'find', 'approve', 'develop'],
#  ['new', 'comprehensive', 'appropriate', 'the', 'federal'],
#  ['ensure', 'require', 'include', 'allow', 'enable'],
#  ['creation', 'implementation', 'development', 'adoption', 'provision'],
#  ['free', 'reasonable', 'inclusive', 'affordable', 'fair'],
#  ['employment', 'retirement', 'health', 'service', 'master'],
#  ['fund', 'system', 'scheme', 'program', 'pool'],
#  ['all', 'their', 'new', 'local', 'minority'],
#  ['report', 'group', 'paper', 'newspaper', 'article'],
#  ['oversaw', 'oversees', 'and', 'for', 'supervised'],
#  ['structure', 'construction', 'organization', 'design', 'management'],
#  ['management', 'control', 'service', 'personnel', 'work'],
#  ['local', 'city', 'county', 'town', 'new'],
#  ['fire', 'tax', 'health', 'justice', 'prison'],
#  ['dairy', 'cattle', 'fruit', 'tree', 'chicken'],
#  ['brought', 'entered', 'file', 'file', 'in'],
#  ['unsuccessfully', 'successfully', 'again', 'twice', 'paper'],
#  ['damage', 'separation', 'dismissal', 'harassment', 'compensation'],
#  ['mother', 'daughter', 'sister', 'partner', 'mistress'],
#  ['v', 'court', 'proceeding', 'no', 'case'],
#  ['own', 'deeply', 'sexually', 'highly', 'blood'],
#  ['against', 'for', 'of', 'Against', 'condemned'],
#  ['with', 'his', 'him', 'her', 'the'],
#  ['illness', 'health', 'disorder', 'disorder', 'disease'],
#  ['latter', 'former', 'two', 'son', 'daughter'],
#  ['divorced', 'widowed', 'wed', 'born', 'engaged'],
#  ['December', 'June', 'November', 'September', 'August'],
#  ['had', 'left', 'bore', 'were', 'produced'],
#  ['daughter', 'brother', 'wife', 'boy', 'grandson'],
#  ['son', 'grandson', 'granddaughter', 'wife', 'sister'],
#  ['Counsel', 'Representatives', 'Attorney', 'Speaking', 'Appeals'],
#  ['plaintiff', 'company', 'defendant', 'defense', 'prosecution'],
#  ['claim', 'state', 'say', 'argue', 'report'],
#  ['entire', 'intellectual', 'official', 'additional', 'extensive'],
#  ['legal', 'financial', 'plea', 'settlement', 'monetary'],
#  ['settled', 'decided', 'entered', 'insisted', 'advanced'],
#  ['census', 'report', 'city', 'article', 'Census'],
#  ['gave', 'described', 'list', 'stated', 'give'],
#  ['man', 'defendant', 'plaintiff', 'judge', 'sheriff'],
#  ['name', 'title', 'rank', 'position', 'status'],
#  ['unknown', 'minor', 'carpenter', 'farmer', 'blacksmith'],
#  ['occupation', 'number', 'population', 'death', 'attendance'],
#  ['give', 'record', 'list', 'recorded', 'gave'],
#  ['mother', 'father', 'family', 'daughter', 'widow'],
#  ['number', 'population', 'year', 'name', 'birthday'],
#  ['year', 'date', 'country', 'month', 'day'],
#  ['judge', 'court', 'article', 'couple', 'author'],
#  ['state', 'claim', 'say', 'stated', 'asserts'],
#  ['family', 'pair', 'two', 'woman', 'marriage'],
#  ['never', 'already', 'only', 'been', 'now'],
#  ['been', 'slept', 'worked', 'remained', 'stayed'],
#  ['apart', 'separately', 'there', 'again', 'legally'],
#  ['husband', 'father', 'wife', 'partner', 'mother'],
#  ['longer', 'le', 'further', 'greater', 'fewer'],
#  ['decade', 'century', 'month', 'week', 'millennium'],
#  ['address', 'station', 'house', 'site', 'boundary'],
#  ['stood', 'wa', 'stand', 'standing', 'lived'],
#  ['named', 'included', 'present', 'represented', 'also'],
#  ['ballot', 'list', 'record', 'paper', 'roll'],
#  ['county', 'city', 'state', 'plaintiff', 'district'],
#  ['wife', 'successor', 'son', 'daughter', 'candidate'],
#  ['remained', 'served', 'wa', 'a', 'held'],
#  ['composed', 'fond', 'devoid', 'full', 'free'],
#  ['Portland', 'Cleveland', 'Springfield', 'Manchester', 'Boston'],
#  ['only', 'just', 'memory', 'something', 'most'],
#  ['a', 'the', 'this', 'that', 'their'],
#  ['electoral', 'political', 'historical', 'summer', 'historic'],
#  ['term', 'stint', 'period', 'spell', 'time'],
#  ['professional', 'public', 'elected', 'municipal', 'long'],
#  ['affiliation', 'history', 'legacy', 'experience', 'influence'],
#  ['date', 'dated', 'went', 'trace', 'date'],
#  ['appointment', 'elevation', 'nomination', 'selection', 'reelection'],
#  ['the', 'local', 'town', 'county', 'Wigan'],
#  ['President', 'president', 'incumbent', 'governor', 'Governor'],
#  ['full', 'first', 'final', 'current', 'entire'],
#  ['year', 'period', 'date', 'day', 'tenure'],
#  ['is', 'wa', 'end', 'includes', 'begin'],
#  ['January', 'June', 'April', 'December', 'November'],
#  ['replaced', 'defeated', 'opposed', 'joined', 'challenged'],
#  ['wa', 'is', 'remained', 'becomes', 'a'],
#  ['challenger', 'Democrat', 'finalist', 'contender', 'nominee'],
#  ['May', 'November', 'June', 'April', 'August'],
#  ['day', 'year', 'November', 'October', 'month'],
#  ['declared', 'stated', 'indicated', 'ruled', 'said'],
#  ['never', 'also', 'instead', 'again', 'only'],
#  ['stand', 'campaign', 'contest', 'bid', 'compete'],
#  ['mayor', 'office', 'election', 'Mayor', 'governor'],
#  ['Irish', 'While', 'Although', 'The', 'Young'],
#  [],
#  ['given', 'a', 'giving', 'of', 'under'],
#  ['the', 'some', 'more', 'an', 'enough'],
#  ['enough', 'support', 'pressure', 'call', 'offer'],
#  ['be', 'support', 'run', 'nominate', 'include'],
#  ['Democrat', 'party', 'Republican', 'woman', 'district'],
#  ['woman', 'mayor', 'President', 'president', 'Governor'],
#  ['in', 'of', 'for', 'at', 'on'],
#  ['in', 'on', 'since', 'of', 'at'],
#  ['later', 'unanimously', 'afterwards', 'earlier', 'so'],
#  ['the', 'a', 'it', 'their', 'former'],
#  ['party', 'council', 'senate', 'board', 'convention'],
#  ['resident', 'host', 'member', 'expert', 'president'],
#  ['at', 'and', 'in', 'attended', 'called'],
#  ['party', 'concert', 'ball', 'ceremony', 'festival'],
#  ['on', 'that', 'one', 'at', 'of'],
#  ['that', 'one', 'last', 'Friday', 'at'],
#  ['and'],
#  ['drew', 'received', 'attracted', 'prompted', 'generated'],
#  ['positive', 'negative', 'no', 'mixed', 'strong'],
#  ['applause', 'cheer', 'support', 'laughter', 'reaction'],
#  ['community', 'public', 'resident', 'crowd', 'people'],
#  ['said', 'stated', 'announced', 'reported', 'noted'],
#  ['it', 'he', 'time', 'she', 'news'],
#  ['built', 'building', 'stirred', 'still', 'pumped'],
#  ['major', 'national', 'special', 'new', 'big'],
#  ['convention', 'conference', 'election', 'meeting', 'debate'],
#  ['at', 'in', 'on', 'a', 'called'],
#  ['September', 'November', 'February', 'June', 'July'],
#  ['November', 'August', 'June', 'July', 'September'],
#  ['the', 'an', 'locally', 'popularly', 'recently'],
#  ['installed', 'inducted', 'constructed', 'appointed', 'built'],
#  ['governor', 'state', 'Governor', 'speaker', 'president'],
#  ['become', 'host', 'have', 'provide', 'play'],
#  ['main', 'official', 'chief', 'guest', 'party'],
#  ['event', 'candidate', 'rally', 'venue', 'guest'],
#  ['scene', 'stage', 'area', 'theater', 'below'],
#  ['party', 'state', 'organization', 'board', 'union'],
#  ['told', 'informed', 'convinced', 'concerned', 'advised'],
#  ['being', 'choosing', 'selecting', 'having', 'becoming'],
#  ['race', 'ballot', 'contest', 'convention', 'bid'],
#  ['president', 'office', 'President', 'election', 'mayor'],
#  ['cause', 'require', 'allow', 'lead', 'encourage'],
#  ['send', 'carry', 'bring', 'throw', 'launch'],
#  ['him', 'her', 'them', 'people', 'it'],
#  ['deep', 'directly', 'going', 'from', 'back'],
#  ['the', 'other', 'all', 'their', 'it'],
#  ['collect', 'get', 'gather', 'request', 'seek'],
#  ['support', 'vote', 'approval', 'endorsement', 'consent'],
#  ['the', 'potential', 'eligible', 'it', 'all'],
#  ['elector', 'candidate', 'Democrats', 'citizen', 'people'],
#  ['election', 'result', 'controversy', 'ban', 'vote'],
#  ['is', 'remained', 'were', 'being', 'became'],
#  ['secret', 'public', 'no', 'majority', 'free'],
#  ['decision', 'agreement', 'refusal', 'consent', 'recommendation'],
#  ['choose', 'nominate', 'select', 'appoint', 'pick'],
#  ['contest', 'parliament', 'debate', 'room', 'vote'],
#  ['those', 'all', 'everyone', 'delegate', 'voter'],
#  ['objected', 'voted', 'disagreed', 'protested', 'agreed'],
#  ['party', 'House', 'Senate', 'state', 'Assembly'],
#  ['asking', 'considering', 'debating', 'unsure', 'ask'],
#  ['ought', 'wa', 'had', 'needed', 'intended'],
#  ['run', 'win', 'have', 'try', 'seek'],
#  ['for', 'any', 'two', 'some', 'even'],
#  ['year', 'day', 'week', 'month', 'hour'],
#  ['win', 'enter', 'join', 'contest', 'continue'],
#  ['vote', 'change', 'decision', 'election', 'move'],
#  ['said', 'replied', 'answered', 'wa', 'responded'],
#  ['yes', 'No', 'Yes', 'otherwise', 'unanimously'],
#  ['are', 'wa', 'being', 'remained', 'been'],
#  ['vote', 'winner', 'change', 'result', 'candidate'],
#  ['obstacle', 'challenge', 'problem', 'issue', 'threat'],
#  ['team', 'horse', 'horse', 'team', 'winner'],
#  ['overcome', 'avoid', 'cross', 'take', 'solve'],
#  ['wa', 'being', 'in', 'to', 'under'],
#  ['new', 'proposed', 'constitutional', 'federal', 'British'],
#  ['constitution', 'statute', 'Constitution', 'clause', 'policy'],
#  ['state', 'requires', 'provides', 'hold', 'mean'],
#  ['entering', 'winning', 'starting', 'having', 'taking'],
#  ['presidential', 'political', 'second', 'new', 'Senate'],
#  ['speech', 'move', 'choice', 'strike', 'attempt'],
#  ['either', 'consideration', 'any', 'two', 'choice'],
#  ['three', 'four', 'several', 'five', 'the'],
#  ['different', 'golf', 'obstacle', 'race', 'possible'],
#  ['route', 'path', 'step', 'approach', 'measure'],
#  ['used', 'considered', 'chosen', 'run', 'offered'],
#  ['Fifty', 'Ten', 'Twenty', 'Thirty', 'Five'],
#  ['Per', 'a', 'one', 'in', 'each'],
#  ['delegate', 'elector', 'citizen', 'people', 'Republicans'],
#  ['the', 'a', 'every', 'one', 'that'],
#  ['district', 'state', 'ward', 'constituency', 'precinct'],
#  ['file', 'submit', 'present', 'signed', 'lodge'],
#  ['paper', 'document', 'letter', 'sign', 'legislation'],
#  ['demanding', 'asking', 'urging', 'calling', 'suggesting'],
#  ['party', 'voter', 'party', 'state', 'Democrats'],
#  ['able', 'permitted', 'required', 'authorized', 'asked'],
#  ['submit', 'put', 'include', 'list', 'give'],
#  ['list', 'list', 'dozen', 'score', 'signature'],
#  ['voter', 'elector', 'individual', 'themselves', 'supporter'],
#  ['local', 'state', 'primary', 'presidential', 'special'],
#  ['roll', 'roll', 'list', 'ticket', 'ticket'],
#  ['party', 'state', 'county', 'party', 'Republicans'],
#  ['contest', 'win', 'run', 'have', 'enter'],
#  ['ballot', 'vote', 'majority', 'referendum', 'convention'],
#  ['state', 'electoral', 'presidential', 'regional', 'single'],
#  ['ballot', 'quota', 'electoral', 'voting', 'council'],
#  ['code', 'rule', 'rule', 'charter', 'constitution'],
#  ['method', 'process', 'policy', 'provision', 'model'],
#  ['Party', 'state', 'Republican', 'government', 'Republicans'],
#  ['us', 'support', 'follows', 'used', 'utilizes'],
#  ['entirety', 'primary', 'state', 'majority', 'favor'],
#  ['medium', 'race', 'labor', 'government', 'consumer'],
#  ['officer', 'manager', 'consultant', 'specialist', 'assistant'],
#  ['left', 'hired', 'recruited', 'chose', 'joined'],
#  ['temporarily', 'voluntarily', 'briefly', 'unexpectedly', 'early'],
#  ['run', 'campaign', 'vote', 'compete', 'stand'],
#  ['office', 'website', 'department', 'board', 'agency'],
#  ['arrival', 'return', 'departure', 'visit', 'death'],
#  ['accepted', 'delayed', 'considered', 'pending', 'announced'],
#  ['a', 'all', 'the', 'another', 'no'],
#  ['reason', 'year', 'month', 'day', 'week'],
#  ['killed', 'murdered', 'arrested', 'replaced', 'executed'],
#  ['remained', 'had', 'stayed', 'served', 'wa'],
#  ['exile', 'MP', 'invalid', 'earl', 'prisoner'],
#  ['le', 'longer', 'for', 'better', 'greater'],
#  ['twenty', 'ten', 'two', 'thirty', 'five'],
#  ['decade', 'century', 'generation', 'month', 'week'],
#  ['new', 'presidential', 'election', 'next', 'second'],
#  ['race', 'election', 'term', 'season', 'run'],
#  ['begin', 'end', 'open', 'close', 'concludes'],
#  ['asked', 'hired', 'invited', 'selected', 'recruited'],
#  ['be', 'have', 'hire', 'provide', 'find'],
#  ['political', 'senior', 'regional', 'recruiting', 'program'],
#  ['slogan', 'target', 'name', 'choice', 'goal'],
#  ['wrap', 'break', 'give', 'pick', 'finish'],
#  ['tax', 'budget', 'election', 'financial', 'traffic'],
#  ['early', 'here', 'there', 'late', 'tomorrow'],
#  ['leave', 'depart', 'run', 'sail', 'headed'],
#  ['Washington', 'Denver', 'Montana', 'Chicago', 'Texas'],
#  ['new', 'state', 'federal', 'government', 'original'],
#  ['tax', 'toll', 'construction', 'maintenance', 'improvement'],
#  ['issue', 'change', 'amendment', 'document', 'bill'],
#  ['need', 'receives', 'ha', 'collect', 'raise'],
#  ['be', 'arrive', 'go', 'come', 'remain'],
#  ['suit', 'up', 'it', 'him', 'soon'],
#  ['the', 'each', 'a', 'every', 'next'],
#  ['that', 'this', 'tomorrow', 'Monday', 'Friday'],
#  ['begin', 'start', 'end', 'arrives', 'date'],
#  ['Governor', 'governor', 'legislature', 'President', 'Senate'],
#  ['required', 'asked', 'requested', 'scheduled', 'instructed'],
#  ['conduct', 'perform', 'begin', 'do', 'undertake'],
#  ['review', 'reduction', 'census', 'list', 'survey'],
#  ['salary', 'amount', 'percentage', 'work', 'portfolio'],
#  ['seat', 'acre', 'day', 'hour', 'hectare'],
#  ['assigned', 'traveling', 'sent', 'moving', 'posted'],
#  ['city', 'suburban', 'town', 'state', 'school'],
#  ['remote', 'coastal', 'suburban', 'rural', 'tribal'],
#  ['decide', 'see', 'consider', 'ass', 'evaluate'],
#  ['decision', 'change', 'recommendation', 'amendment', 'choice'],
#  ['implemented', 'taken', 'done', 'required', 'necessary'],
#  ['scheduled', 'required', 'asked', 'allowed', 'invited'],
#  ['enjoy', 'pay', 'attend', 'perform', 'continue'],
#  ['first', 'final', 'occasional', 'required', 'same'],
#  ['call', 'approach', 'trip', 'commitment', 'entrance'],
#  ['party', 'school', 'city', 'side', 'state'],
#  ['move', 'progress', 'head', 'proceed', 'march'],
#  ['completion', 'victory', 'success', 'independence', 'agreement'],
#  ['also', 'then'],
#  ['have', 'use', 'consider', 'see', 'view'],
#  [],
#  ['billion', 'Million', 'thousand', 'crore', 'trillion'],
#  ['state', 'school', 'federal', 'city', 'bond'],
#  ['construction', 'widening', 'funding', 'toll', 'budget'],
#  ['measure', 'package', 'proposal', 'being', 'option'],
#  ['passed', 'filed', 'announced', 'proposed', 'introduced'],
#  ['early', 'late', 'later', 'prior', 'previously'],
#  ['year', 'month', 'week', 'day', 'season'],
#  ['top', 'next', 'highest', 'final', 'last'],
#  ['agenda', 'budget', 'ballot', 'major', 'legislative'],
#  ['issue', 'priority', 'measure', 'budget', 'project'],
#  ['Also', 'However', 'Recently', 'Additionally', 'Meanwhile'],
#  ['reported', 'announced', 'noted', 'revealed', 'said'],
#  ['wa', 'were', 'came', 'stood', 'hovered'],
#  ['nowhere', 'still', 'not', 'damn', 'just'],
#  ['not', 'much', 'nearly', 'likely', 'about'],
#  ['and', 'getting', 'to', 'coming', 'becoming'],
#  ['able', 'allowed', 'authorized', 'forced', 'prepared'],
#  ['sign', 'sell', 'approve', 'release', 'pay'],
#  ['US', 'next', 'remaining', 'nearly', 'required'],
#  [],
#  ['billion', 'trillion', 'Million', 'year', 'thousand'],
#  ['package', 'set', 'issue', 'series', 'round'],
#  ['state', 'road', 'the', 'new', 'federal'],
#  ['insurance', 'construction', 'maintenance', 'tax', 'state'],
#  ['project', 'permit', 'plan', 'proposal', 'fund'],
#  ['legal', 'actual', 'first', 'entire', 'real'],
#  ['holder', 'sale', 'company', 'money', 'holder'],
#  ['apply', 'proceed', 'turn', 'run', 'send'],
#  ['federal', 'county', 'local', 'district', 'civil'],
#  ['government', 'legislature', 'attorney', 'commission', 'office'],
#  ['federal', 'civil', 'second', 'legal', 'court'],
#  ['fire', 'defense', 'interest', 'loan', 'cause'],
#  ['prove', 'determine', 'challenge', 'establish', 'verify'],
#  ['merit', 'power', 'integrity', 'term', 'provision'],
#  ['bond', 'bond', 'contract', 'sale', 'debt'],
#  ['but', 'where', 'or', 'while', 'so'],
#  ['construction', 'work', 'investigation', 'negotiation', 'hearing'],
#  ['cease', 'be', 'continue', 'pay', 'come'],
#  ['be', 'are', 'is', 'being', 'then'],
#  ['signed', 'begin', 'commence', 'awarded', 'sign'],
#  ['the', 'construction', 'contract', 'their', 'engineering'],
#  ['project', 'contract', 'service', 'job', 'repair'],
#  ['Alabama', 'Texas', 'California', 'Kentucky', 'Oregon'],
#  ['more', 'least', 'le', 'other', 'many'],
#  ['lightly', 'densely', 'well', 'easily', 'poorly'],
#  ['used', 'damaged', 'developed', 'built', 'constructed'],
#  ['road', 'bridge', 'street', 'railroad', 'route'],
#  ['spokesman', 'spokesperson', 'official', 'report', 'ha'],
#  ['say', 'stated', 'suggested', 'suggests', 'state'],
#  ['still', 'already', 'currently', 'now', 'probably'],
#  ['wa', 'existed', 'exists', 'were', 'been'],
#  ['proposal', 'need', 'scheme', 'commission', 'program'],
#  ['underway', 'designed', 'proposed', 'intended', 'planned'],
#  ['use', 'sell', 'borrow', 'raise', 'secure'],
#  ['between', 'about', 'from', 'approximately', 'around'],
#  ['up'],
#  ['billion', 'thousand', 'hundred', 'm', 'Million'],
#  [],
#  ['billion', 'trillion', 'Million', 'thousand', 'year'],
#  ['annually', 'each', 'consisting', 'out', 'million'],
#  ['funding', 'grant', 'permit', 'fund', 'approval'],
#  ['the', 'additional', 'state', 'new', 'future'],
#  ['highway', 'infrastructure', 'roadway', 'freeway', 'bypass'],
#  ['maintenance', 'improvement', 'repair', 'infrastructure', 'development'],
#  ['project', 'company', 'purpose', 'contract', 'fund'],
#  ['government', 'bill', 'state', 'plan', 'legislation'],
#  ['also', 'now', 'instead', 'therefore', 'then'],
#  ['intended', 'planned', 'decided', 'wanted', 'hoped'],
#  ['give', 'offer', 'provide', 'grant', 'create'],
#  ['trust', 'new', 'special', 'reserve', 'hedge'],
#  ['the', 'state', 'government', 'these', 'tax'],
#  ['vehicle', 'tax', 'contract', 'fund', 'road'],
#  ['sold', 'released', 'paid', 'signed', 'purchased'],
#  ['each', 'any', 'over', 'the', 'Each'],
#  ['year', 'day', 'month', 'week', 'when'],
#  ['third', 'quarter', 'share', 'few', 'percentage'],
#  ['existing', 'new', 'older', 'previous', 'current'],
#  ['sold', 'taken', 'written', 'cut', 'bought'],
#  ['the', 'local', 'other', 'those', 'these'],
#  ['began', 'started', 'ended', 'concluded', 'launched'],
#  ['campaign', 'bid', 'candidacy', 'run', 'term'],
#  ['reelection', 'Governor', 'mayor', 'office', 'president'],
#  ['vote', 'motion', 'campaign', 'debate', 'resolution'],
#  ['Senate', 'primary', 'House', 'senate', 'court'],
#  ['issue', 'sale', 'cancellation', 'passage', 'introduction'],
#  [],
#  ['billion', 'thousand', 'Million', 'year', 'cent'],
#  ['consisting', 'short', 'out', 'instead', 'each'],
#  ['state', 'federal', 'new', 'the', 'private'],
#  ['toll', 'state', 'county', 'federal', 'interstate'],
#  ['development', 'school', 'government', 'bank', 'saving'],
#  ['a', 'originally', 'being', 'first', 'initially'],
#  ['signed', 'issued', 'owed', 'offered', 'promised'],
#  ['the', 'state', 'former', 'Louisiana', 'Texas'],
#  ['ha', 'had', 'also', 'later', 'is'],
#  ['from', 'in', 'to', 'on', 'of'],
#  ['though', 'therefore', 'meanwhile', 'too', 'then'],
#  ['never', 'only', 'no', 'hardly', 'neither'],
#  ['informed', 'told', 'notified', 'contacted', 'heard'],
#  ['since', 'again', 'directly', 'publicly', 'before'],
#  ['authority', 'proposal', 'process', 'decision', 'legislation'],
#  ['make', 'build', 'use', 'have', 'create'],
#  ['first', 'proposed', 'state', 'federal', 'two'],
#  ['state', 'toll', 'public', 'national', 'federal'],
#  ['development', 'state', 'bond', 'tax', 'highway'],
#  ['license', 'permit', 'license', 'licence', 'permit'],
#  ['pas', 'introduce', 'issue', 'sign', 'present'],
#  ['single', 'second', 'third', 'special', 'free'],
#  ['passed', 'elsewhere', 'circulating', 'unanimously', 'raised'],
#  ['support', 'address', 'end', 'review', 'protest'],
#  ['state', 'government', 'legislature', 'governor', 'county'],
#  ['right', 'lack', 'use', 'offer', 'choice'],
#  ['delay', 'assisting', 'resulting', 'succeeding', 'interfering'],
#  ['giving', 'granting', 'paying', 'providing', 'awarding'],
#  [],
#  ['year', 'cent', 'month', 'pound', 'hour'],
#  ['reduction', 'payment', 'hike', 'raise', 'cut'],
#  ['disability', 'tax', 'retirement', 'pension', 'housing'],
#  ['saving', 'payment', 'increase', 'tax', 'revenue'],
#  ['On', 'By', 'One', 'At', 'Late'],
#  ['that', 'last', 'at', 'Friday', 'Monday'],
#  ['meant', 'said', 'indicated', 'that', 'showed'],
#  ['is', 'were', 'are', 'being', 'been'],
#  ['work', 'debate', 'discussion', 'consultation', 'speculation'],
#  ['conducted', 'made', 'undertaken', 'performed', 'taken'],
#  ['no', 'yes', 'No', 'Yes', 'majority'],
#  ['clause', 'provision', 'bill', 'ban', 'act'],
#  ['bill', 'amendment', 'repeal', 'motion', 'measure'],
#  ['passed', 'won', 'taken', 'rejected', 'cast'],
#  ['immediately', 'again', 'quickly', 'now', 'indefinitely'],
#  ['it', 'approval', 'consent', 'time', 'permission'],
#  ['be', 'also', 'later', 'then', 'eventually'],
#  ['taken', 'made', 'granted', 'passed', 'issued'],
#  ['approval', 'none', 'notice', 'part', 'some'],
#  ['measure', 'bill', 'law', 'amendment', 'referendum'],
#  ['necessary', 'required', 'possible', 'needed', 'appropriate'],
#  ['noting', 'acknowledging', 'saying', 'admitting', 'stating'],
#  ['the', 'these', 'some', 'those', 'such'],
#  ['issue', 'matter', 'problem', 'difference', 'aspect'],
#  ['never', 'being', 'now', 'already', 'more'],
#  ['being', 'well', 'yet', 'always', 'properly'],
#  ['carried', 'thought', 'figured', 'mapped', 'spelled'],
#  ['stated', 'in', 'announced', 'and', 'indicated'],
#  ['administration', 'committee', 'party', 'colleague', 'office'],
#  ['serve', 'be', 'help', 'have', 'fail'],
#  ['put', 'lay', 'cast', 'setting', 'push'],
#  ['original', 'previous', 'final', 'earlier', 'budget'],
#  ['on', 'for', 'to', 'of', 'upon'],
#  ['passed', 'approved', 'moved', 'went', 'pass'],
#  ['joint', 'Senate', 'unanimous', 'House', 'congressional'],
#  ['bill', 'measure', 'motion', 'proposal', 'amendment'],
#  ['failed', 'approved', 'won', 'defeated', 'adopted'],
#  ['Senate', 'Assembly', 'House', 'end', 'Congress'],
#  ['margin', 'majority', 'score', 'total', 'resolution'],
#  [],
#  [],
#  ['that', 'last', 'Monday', 'Wednesday', 'this'],
#  ['approached', 'now', 'though', 'arrived', 'morning'],
#  ['is', 'were', 'came', 'remained', 'seemed'],
#  ['sign', 'prospect', 'indication', 'evidence', 'chance'],
#  ['hand', 'word', 'truce', 'sign', 'settlement'],
#  ['passed', 'reached', 'brought', 'made', 'put'],
#  ['or', 'yet', 'except', 'but', 'even'],
#  ['take', 'stop', 'prevent', 'justify', 'continue'],
#  ['ban', 'order', 'agreement', 'offer', 'invitation'],
#  ['point', 'point', 'found', 'pointing', 'find'],
#  ['the', 'Virginia', 'Louisiana', 'Vermont', 'Colorado'],
#  ['the', 'and', 'his', 'The', 'it'],
#  ['in', 'per', 'every', 'each', 'of'],
#  ['year', 'week', 'month', 'night', 'time'],
#  ['approved', 'passed', 'supported', 'for', 'ratified'],
#  ['proposed', 'legislative', 'Constitutional', 'House', 'bill'],
#  ['provision', 'proposal', 'bill', 'requirement', 'convention'],
#  ['require', 'permit', 'enable', 'direct', 'force'],
#  ['voter', 'them', 'senator', 'woman', 'Democrats'],
#  ['agree', 'decide', 'focus', 'bid', 'rely'],
#  ['tax', 'salary', 'fund', 'budget', 'wage'],
#  ['increase', 'cut', 'rise', 'ceiling', 'bill'],
#  ['state', 'their', 'the', 'special', 'regular'],
#  ['legislative', 'congressional', 'special', 'Senate', 'House'],
#  ['member', 'election', 'meeting', 'seat', 'candidate'],
#  ['former', 'young', 'white', 'new', 'fellow'],
#  ['council', 'official', 'commission', 'executive', 'board'],
#  ['use', 'urge', 'support', 'call', 'lead'],
#  ['government', 'legislature', 'not', 'district', 'party'],
#  ['approve', 'end', 'increase', 'withdraw', 'provide'],
#  ['up', 'it', 'state', 'down', 'their'],
#  ['funding', 'cut', 'grant', 'fund', 'assistance'],
#  ['Arizona', 'Alaska', 'agriculture', 'Texas', 'Oklahoma'],
#  ['successfully', 'strongly', 'long', 'actively', 'vigorously'],
#  ['done', 'accomplished', 'refused', 'did', 'failed'],
#  ['legislature', 'election', 'state', 'year', 'area'],
#  ['representing', 'leading', 'in', 'with', 'represented'],
#  ['joint', 'special', 'unanimous', 'committee', 'Senate'],
#  ['suit', 'letter', 'case', 'bill', 'request'],
#  ['provide', 'seek', 'approve', 'support', 'secure'],
#  ['all', 'the', 'any', 'direct', 'full'],
#  ['state', 'public', 'congressional', 'local', 'Federal'],
#  ['funding', 'fund', 'spending', 'grant', 'dollar'],
#  ['higher', 'special', 'free', 'secondary', 'basic'],
#  ['fund', 'school', 'work', 'spending', 'funding'],
#  ['federal', 'the', 'these', 'state', 'public'],
#  ['support', 'funding', 'assistance', 'aid', 'resource'],
#  ['collected', 'used', 'distributed', 'raised', 'spent'],
#  ['used', 'distributed', 'maintained', 'spent', 'administered'],
#  ['other', 'federal', 'appropriate', 'public', 'additional'],
#  ['policy', 'requires', 'law', 'required', 'legislation'],
#  ['wa', 'lived', 'served', 'died', 'came'],
#  ['second', 'third', 'first', 'fourth', 'last'],
#  ['term', 'decade', 'century', 'month', 'district'],
#  ['Congressman', 'senator', 'Representative', 'delegate', 'Senator'],
#  ['say', 'stated', 'state', 'added', 'noted'],
#  ['were', 'remain', 'is', 'exist', 'Are'],
#  ['many', 'several', 'few', 'certain', 'two'],
#  ['friend', 'Members', 'representative', 'people', 'part'],
#  ['parliamentary', 'Congressional', 'legislative', 'House', 'state'],
#  ['committee', 'party', 'caucus', 'staff', 'team'],
#  ['Washington', 'Congress', 'office', 'Virginia', 'California'],
#  ['have', 'hear', 'get', 'consider', 'know'],
#  ['bill', 'law', 'measure', 'legislation', 'Act'],
#  ['pas', 'adopted', 'approved', 'enacted', 'read'],
#  ['noted', 'said', 'note', 'found', 'stated'],
#  ['Washington', 'Lincoln', 'Virginia', 'Iowa', 'Louisiana'],
#  ['leader', 'representative', 'member', 'minister', 'inhabitant'],
#  ['had', 'ever', 'even', 'have', 'actually'],
#  ['wanted', 'urged', 'expected', 'invited', 'requested'],
#  ['sign', 'support', 'veto', 'oppose', 'write'],
#  ['job', 'offer', 'money', 'position', 'deal'],
#  ['letter', 'paper', 'book', 'bill', 'note'],
#  ['step', 'break', 'go', 'fly', 'move'],
#  ['by', 'and', 'in', 'a', 'on'],
#  ['machine', 'box', 'room', 'bucket', 'basket'],
#  ['to', 'first', 'then', 'all', 'now'],
#  ['announced', 'called', 'accepted', 'approved', 'dated'],
#  ['out', 'aloud', 'off', 'immediately', 'later'],
#  ['argued', 'added', 'argues', 'state', 'said'],
#  ['case', 'way', 'time', 'year', 'manner'],
#  ['approve', 'allow', 'reject', 'address', 'consider'],
#  ['amount', 'money', 'reduction', 'raise', 'benefit'],
#  ['state', 'education', 'public', 'school', 'pension'],
#  ['funding', 'spending', 'revenue', 'dollar', 'aid'],
#  ['asked', 'required', 'able', 'prepared', 'told'],
#  ['assign', 'add', 'put', 'provide', 'giving'],
#  ['in', 'way', 'rise', 'preference', 'effect'],
#  ['the', 'these', 'state', 'all', 'federal'],
#  ['salary', 'pension', 'wage', 'tax', 'compensation'],
#  ['increase', 'cut', 'increase', 'rise', 'rate'],
#  ['brief', 'short', 'lengthy', 'big', 'huge'],
#  ['bitter', 'heated', 'long', 'running', 'ongoing'],
#  ['summer', 'winter', 'drought', 'year', 'spring'],
#  ['elected', 'appointed', 'hired', 'had', 'chose'],
#  ['black', 'Republican', 'special', 'local', 'single'],
#  ['county', 'police', 'district', 'town', 'chief'],
#  ['resulting', 'who', 'and', 'running', 'which'],
#  ['newspaper', 'reporter', 'journalist', 'writer', 'legend'],
#  ['call', 'in', 'before', 'for', 'to'],
#  ['worst', 'best', 'first', 'greatest', 'biggest'],
#  ['office', 'position', 'year', 'uniform', 'district'],
#  ['never', 'have', 've', 'just', 'always'],
#  ['country', 'state', 'town', 'nation', 'city'],
#  ['current', 'former', 'incumbent', 'Republican', 'elected'],
#  ['county', 'district', 'state', 'assistant', 'deputy'],
#  ['wa', 'replaced', 'succeeded', 'hired', 'faced'],
#  ['former', 'retired', 'local', 'young', 'longtime'],
#  ['school', 'history', 'English', 'former', 'state'],
#  ['worker', 'consultant', 'expert', 'administrator', 'official'],
#  ['is', 'play', 'replaced', 'replaces', 'hired'],
#  ['former', 'new', 'previous', 'retired', 'local'],
#  ['member', 'chair', 'head', 'leader', 'president'],
#  ['got', 'had', 'won', 'obtained', 'gained'],
#  ['seat', 'point', 'voter', 'ballot', 'signature'],
#  ['today', 'August', 'November', 'May'],
#  ['favor', 'favour', 'poll', 'constituency', 'district'],
#  ['delivered', 'for', 'with', 'boy'],
#  ['A', 'The', 'Two', 'His', 'Some'],
#  ['equipped', 'along', 'loaded', 'also', 'one'],
#  ['shotgun', 'sword', 'gun', 'rifle', 'knife'],
#  ['stopped', 'came', 'stop', 'passed', 'stand'],
#  ['door', 'gate', 'window', 'entrance', 'doorway'],
#  ['restore', 'maintain', 'keep', 'ensure', 'enforce'],
#  ['victory', 'peace', 'vote', 'attendance', 'progress'],
#  ['is', 's', 'be', 'Is', 'in'],
#  ['biggest', 'best', 'longest', 'first', 'largest'],
#  ['best', 'biggest', 'worst', 'largest', 'greatest'],
#  ['thing', 'man', 'place', 'day', 'person'],
#  ['never', 'just', 'have', 'really', 'yet'],
#  ['replied', 'say', 'asked', 'wrote', 'answered'],
#  ['Being', 'Sitting', 'Getting', 'Speaking', 'Running'],
#  ['church', 'hospital', 'school', 'altar', 'bar'],
#  ['is', 'feel', 'felt', 'sound', 'seems'],
#  ['almost', 'more', 'not', 'nothing', 'much'],
#  ['sitting', 'that', 'it', 'running', 'speaking'],
#  ['home', 'poll', 'it', 'war', 'odds'],
#  ['have', 'get', 'drink', 'need', 'had'],
#  ['bit', 'lot', 'thing', 'little', 'penny'],
#  ['blood', 'it', 'coffee', 'rain', 'water'],
#  ['feel', 'smell', 'see', 'hear', 'want'],
#  ['alcohol', 'it', 'beer', 'liquor', 'wine'],
#  ['night', 'day', 'week', 'period', 'weekend'],
#  ['prior', 'close', 'response', 'reaction', 'approach'],
#  ['war', 'battle', 'coup', 'assassination', 'attack'],
#  ['is', 'were', 'remained', 'proved', 'became'],
#  ['never', 'ever', 'always', 'still', 'generally'],
#  ['always', 'entirely', 'a', 'very', 'kept'],
#  ['successful', 'promising', 'positive', 'bad', 'strong'],
#  ['though', 'either', 'then', 'too', 'nevertheless'],
#  ['marred', 'accompanied', 'fueled', 'characterized', 'surrounded'],
#  ['long', 'short', 'anonymous', 'frequent', 'brief'],
#  ['including', 'with', 'involving', 'numerous', 'frequent'],
#  ['phone', 'threatening', 'anonymous', 'telephone', 'public'],
#  ['telephone', 'radio', 'conference', 'police', 'bomb'],
#  ['repeated', 'constant', 'numerous', 'anonymous', 'frequent'],
#  ['act', 'accusation', 'display', 'incident', 'allegation'],
#  ['assault', 'death', 'harassment', 'arrest', 'retaliation'],
#  ['new', 'then', 'first', 'previous', 'last'],
#  ['local', 'district', 'town', 'city', 'assistant'],
#  ['education', 'district', 'police', 'health', 'assistant'],
#  ['burned', 'sentenced', 'stabbed', 'hanged', 'poisoned'],
#  ['Death', 'on', 'the', 'health', 'a'],
#  ['at', 'May', 'June', 'October', 'August'],
#  ['two', 'three', 'five', 'six', 'seven'],
#  ['month', 'year', 'week', 'hour', 'minute'],
#  ['left', 'lost', 'quit', 'took', 'vacated'],
#  ['position', 'seat', 'office', 'job', 'position'],
#  ['confrontation', 'disagreement', 'meeting', 'conflict', 'shootout'],
#  ['local', 'city', 'state', 'district', 'town'],
#  ['education', 'health', 'fire', 'library', 'water'],
#  ['primary', 'presidential', 'same', 'electoral', 'entire'],
#  ['process', 'period', 'night', 'day', 'season'],
#  ['woman', 'MPs', 'supporter', 'men', 'activist'],
#  ['had', 'frequently', 'have', 'often', 'also'],
#  ['made', 'exchanged', 'answered', 'took', 'had'],
#  ['threatening', 'several', 'numerous', 'frequent', 'many'],
#  ['phone', 'conference', 'radio', 'close', 'Phone'],
#  ['The', 'A', 'Mr', 'John', 'the'],
#  ['claimed', 'claim', 'say', 'claim', 'and'],
#  ['himself', 'however', 'unusually', 'personally', 'herself'],
#  ['responding', 'subject', 'exposed', 'referring', 'going'],
#  ['phone', 'telephone', 'similar', 'repeated', 'close'],
#  ['harassment', 'threat', 'attack', 'criticism', 'abuse'],
#  ['shortly', 'immediately', 'long', 'right', 'just'],
#  ['won', 'lost', 'entered', 'announced', 'contested'],
#  ['meeting', 'wedding', 'interview', 'event', 'funeral'],
#  ['The', 'Many', 'Some', 'Several', 'Most'],
#  ['resident', 'voter', 'people', 'politician', 'leader'],
#  ['worried', 'believed', 'warned', 'predicted', 'felt'],
#  ['been', 'become', 'arise', 'occur', 'come'],
#  ['trouble', 'violence', 'riot', 'unrest', 'chaos'],
#  ['election', 'election', 'meeting', 'time', 'assembly'],
#  ['gave', 'granted', 'denied', 'issued', 'obtained'],
#  ['license', 'licence', 'man', 'warrant', 'revolver'],
#  ['buy', 'use', 'purchase', 'fire', 'own'],
#  ['horse', 'ballot', 'newspaper', 'candidate', 'rifle'],
#  ['call', 'hold', 'conduct', 'called', 'organize'],
#  ['early', 'open', 'immediate', 'easy', 'indirect'],
#  ['funeral', 'burial', 'government', 'return', 'response'],
#  ['on', 'in', 'of', 'at', 'for'],
#  ['man', 'boy', 'priest', 'guy', 'king'],
#  ['man', 'boy', 'person', 'priest', 'one'],
#  ['did', 'make', 'making', 'wa', 'make'],
#  ['mind', 'day', 'story', 'case', 'reputation'],
#  ['go', 'going', 'is', 'wa', 'seems'],
#  ['pretty', 'so', 'really', 'very', 'perfectly'],
#  ['fast', 'well', 'good', 'quick', 'great'],
#  ['man', 'woman', 'voice', 'doctor', 'captain'],
#  ['replied', 'say', 'added', 'remarked', 'explained'],
#  ['is', 'be', 'a', 'are', 'need'],
#  ['one', 'least', 'mean', 'no', 'the'],
#  ['time', 'it', 'that', 'money', 'one'],
#  ['The', 'His', 'Their', 'Her', 'Public'],
#  ['investigation', 'hearing', 'criticism', 'hearing', 'discussion'],
#  ['intellectual', 'private', 'real', 'stolen', 'public'],
#  ['it', 'him', 'business', 'me', 'country'],
#  ['had', 'ha', 'still', 'also', 'now'],
#  ['on', 'for', 'in', 'at', 'by'],
#  ['to', 'like', 'inevitable', 'impossible', 'appropriate'],
#  ['enough', 'even', 'today', 'and', 'not'],
#  ['strong', 'repeated', 'vigorous', 'fierce', 'vocal'],
#  ['objection', 'support', 'opposition', 'effort', 'backing'],
#  ['the', 'his', 'local', 'many', 'other'],
#  ['member', 'supporter', 'lawyer', 'advocate', 'official'],
#  ['had', 'then', 'first', 'also', 'later'],
#  ['joined', 'began', 'launched', 'won', 'started'],
#  ['campaign', 'vote', 'argument', 'way', 'debate'],
#  ['bill', 'law', 'constitution', 'amendment', 'Constitution'],
#  ['put', 'turned', 'backed', 'voted', 'scaled'],
#  ['significantly', 'on', 'ever', 'much', 'somewhat'],
#  ['passage', 'adoption', 'introduction', 'approval', 'passing'],
#  ['the', 'several', 'three', 'all', 'his'],
#  ['state', 'successive', 'different', 'separate', 'territorial'],
#  ['committee', 'opponent', 'governor', 'senator', 'house'],
#  ['special', 'heated', 'joint', 'lengthy', 'brief'],
#  ['speech', 'meeting', 'address', 'debate', 'session'],
#  ['the', 'federal', 'Senate', 'new', 'current'],
#  ['control', 'law', 'approval', 'condition', 'recommendation'],
#  ['report', 'go', 'move', 'return', 'reported'],
#  ['back', 'down', 'up', 'directly', 'on'],
#  ['meeting', 'committee', 'minimum', 'conference', 'member'],
#  ['a', 'the', 'that', 'each', 'another'],
#  ['year', 'vote', 'month', 'day', 'term'],
#  ['experience', 'that', 'ease', 'skill', 'incident'],
#  ['family', 'it', 'party', 'the', 'church'],
#  ['or', 'and', 'of', 'are', 'have'],
#  ['in', 'by', 'on', 'or', 'at'],
#  ['and', 'or', 'such', 'acted', 'appear'],
#  ['such', 'spy', 'themselves', 'well', 'politician'],
#  ['leave', 'make', 'leaf', 'have', 'give'],
#  ['no', 'some', 'me', 'the', 'much'],
#  ['evidence', 'indication', 'sign', 'hope', 'question'],
#  ['gain', 'get', 'prevent', 'seek', 'deny'],
#  ['any', 'much', 'some', 'approval', 'proof'],
#  ['wa', 'called', 'is', 'said', 'stated'],
#  ['too', 'overly', 'very', 'so', 'surprisingly'],
#  ['optimistic', 'accurate', 'ambitious', 'reasonable', 'disappointing'],
#  ['proposal', 'forecast', 'prediction', 'claim', 'view'],
#  ['cost', 'take', 'be', 'require', 'save'],
#  [],
#  ['billion', 'trillion', 'thousand', 'Million', 'hundred'],
#  ['job', 'employee', 'worker', 'people', 'pound'],
#  ['effectively', 'completely', 'fully', 'roughly', 'temporarily'],
#  ['meet', 'offset', 'fill', 'cover', 'alleviate'],
#  ['economic', 'estimated', 'budget', 'existing', 'annual'],
#  ['surplus', 'loss', 'debt', 'shortage', 'recession'],
#  ['billion', 'thousand', 'trillion', 'Million', 'hundred'],
#  ['pound', 'USD', 'job', 'annually', 'euro'],
#  ['beginning', 'start', 'close', 'conclusion', 'completion'],
#  ['next', 'proposed', 'upcoming', 'projected', 'fiscal'],
#  ['financial', 'tax', 'economic', 'budget', 'academic'],
#  ['a', 'in', 'under', 'of', 'by'],
#  ['December', 'October', 'March', 'January', 'August'],
#  ['warned', 'informed', 'assured', 'advised', 'promised'],
#  ['council', 'press', 'court', 'assembly', 'government'],
#  ['bill', 'government', 'proposal', 'law', 'legislation'],
#  ['also', 'not', 'only', 'help', 'now'],
#  ['be', 'a', 'give', 'become', 'a'],
#  ['way', 'way', 'measure', 'method', 'purpose'],
#  ['changing', 'passing', 'implementing', 'breaking', 'removing'],
#  ['constitutional', 'new', 'martial', 'electoral', 'existing'],
#  ['clause', 'system', 'policy', 'doctrine', 'treaty'],
#  ['remained', 'stayed', 'existed', 'sat', 'stood'],
#  ['Brazil', 'Venezuela', 'India', 'it', 'France'],
#  ['is', 'became', 'were', 'becomes', 'formed'],
#  ['province', 'state', 'city', 'village', 'colony'],
#  ['allows', 'allowed', 'enables', 'authorized', 'enabled'],
#  ['bank', 'government', 'police', 'court', 'authority'],
#  ['turn', 'hand', 'look', 'trace', 'sign'],
#  ['the', 'all', 'personal', 'any', 'trust'],
#  ['asset', 'property', 'paper', 'passport', 'record'],
#  ['the', 'any', 'all', 'even', 'some'],
#  ['private', 'valuable', 'legal', 'public', 'other'],
#  ['those', 'anyone', 'people', 'individual', 'the'],
#  ['detained', 'imprisoned', 'abroad', 'unemployed', 'living'],
#  ['five', 'ten', 'three', 'twenty', 'several'],
#  ['month', 'day', 'week', 'decade', 'hour'],
#  ...]

# %% [markdown]
# example:
# candidate_lemmas = ['office', 'register', 'store', 'bathroom', 'library']

# %% [markdown]
# Identify the most similar sense of headword with relation to the 5 unique candidates

# %%
print(word[0])
print(ground_truth[0])
print(wn.lemma_from_key(ground_truth[0]) )
# Lemma('state.v.01.say')
# lemma's key = say%2:32:00::
# Out:
# said
# say%2:32:00::
# Lemma('state.v.01.say')

# %%
wn.synsets(word[0])
# Out:
# [Synset('state.v.01'),
#  Synset('allege.v.01'),
#  Synset('suppose.v.01'),
#  Synset('read.v.02'),
#  Synset('order.v.01'),
#  Synset('pronounce.v.01'),
#  Synset('say.v.07'),
#  Synset('say.v.08'),
#  Synset('say.v.09'),
#  Synset('say.v.10'),
#  Synset('say.v.11'),
#  Synset('aforesaid.s.01')]

# %%
print(f'word:  {word[0]}, ground_truth:  {ground_truth[0]}')
# print(wn.synsets(word[0]))

print(f'ground_truth to lemma:  {wn.lemma_from_key(ground_truth[0])}')
print(f'ground_truth to sensenet:  {wn.lemma_from_key(ground_truth[0]).synset()}')

print(f'ground_truth def:  {wn.lemma_from_key(ground_truth[0]).synset().definition() }')
wn.synset('found.n.01').definition()
tt = wn.synsets(word[0])
# print(wn.synset(wn.synsets(word[0])).definition())
# Out:
# word:  said, ground_truth:  say%2:32:00::
# ground_truth to lemma:  Lemma('state.v.01.say')
# ground_truth to sensenet:  Synset('state.v.01')
# ground_truth def:  express in words

# %%
for x in wn.synsets(word[0]):
    print(x.lemmas()[0].key())
    print(wn.lemma_from_key(x.lemmas()[0].key()) )
# Out:
# state%2:32:00::
# Lemma('state.v.01.state')
# allege%2:32:00::
# Lemma('allege.v.01.allege')
# suppose%2:32:00::
# Lemma('suppose.v.01.suppose')
# read%2:42:00::
# Lemma('read.v.02.read')
# order%2:32:01::
# Lemma('order.v.01.order')
# pronounce%2:32:01::
# Lemma('pronounce.v.01.pronounce')
# say%2:32:07::
# Lemma('say.v.07.say')
# say%2:32:15::
# Lemma('say.v.08.say')
# say%2:32:13::
# Lemma('say.v.09.say')
# say%2:32:08::
# Lemma('say.v.10.say')
# say%2:32:09::
# Lemma('say.v.11.say')
# aforesaid%5:00:00:same:02
# Lemma('aforesaid.s.01.aforesaid')

# %%
wn.synset('found.n.01').definition()
# Out:
# 'food and lodging provided in addition to money'

# %%
a = wn.lemma_from_key('say%2:32:00::')
print(a)
print(wn.synset('say.v.01').definition())
# Out:
# Lemma('state.v.01.say')
# express in words

# %%
len(candidate_lemmas)
# Out:
# 1042

# %%
correct = 0
ppredict = []
ground_err = 0

for index in range(len(candidate_lemmas)):
# for index in range(10):
    max_score = 0
    most_sim_word = None
    sub_can = candidate_lemmas[index]
    try:
        #對同一個word內所有synset做score紀錄
        mean_score_word = []
        for ii in range(len(wn.synsets(word[index]))):
            accu_score = 0
        # ground_truth_lemma = wn.lemma_from_key(ground_truth[index])
        # ground_truth_synset = ground_truth_lemma.synset()
        
            for i in range(len(candidate_lemmas[index])):
                w = wn.synsets(candidate_lemmas[index][i])
                
                if w:
                    for index1 in range(len(w)):
                        sim_score = wn.path_similarity(w[index1], wn.synsets(word[index])[ii])
                        accu_score += sim_score
                        # if sim_score > max_score:
                        #     most_sim_word = w[index1]
                        #     max_score = sim_score
                        #     ppredict_cur = most_sim_word
            mean_score_word.append(accu_score)
            
        # if not most_sim_word:
        #     print(index, candidate_lemmas[index])
        #     print('Bomb!!!')
        #     ppredict_cur = wn.synsets(word[index])[0]
        #     ppredict_cur = None
        for k in range(len(mean_score_word)):
            if mean_score_word[k] >= max_score:
                max_score = mean_score_word[k]
                max_index = k
                most_sim_word = wn.synsets(word[index])[k]
        ppredict.append(most_sim_word)
    except Exception as e:
        print("捕捉錯誤資訊: "+ str(e))
    except:
        ground_err +=1
        print('ground_truth 轉不過去')
        ppredict.append(None)
        ppredict_cur = None

# %%
for x in range(len(word)):
    if not wn.synsets(word[x]):
        print(x, word[x], wn.synsets(word[x]))
# Out:
# 247 jan. []
# 314 aug. []
# 365 jan. []
# 369 sept. []
# 404 sept. []
# 463 per []
# 581 and []
# 975 aug. []

# %%
for x in range(len(ppredict)):
    if not ppredict[x] and wn.synsets(word[x]):
        ppredict[x] =  wn.synsets(word[x])[0]

# %%
ground_err =0
correct = 0
total = len(ppredict)
for index in range(len(ppredict)):
    try:
        ground_truth_lemma = wn.lemma_from_key(ground_truth[index])
        ground_truth_synset = ground_truth_lemma.synset()
        
        if ppredict[index] == ground_truth_synset:
             correct +=1
    except Exception as e:
        # print("捕捉錯誤資訊: "+ str(e))
        ground_err +=1

# %%
print(f'correct: {correct}, total: {total}')
correct/total
# Out:
# correct: 305, total: 1042
# 0.2927063339731286

# %%
candidate_lemmas
# Out:
# [['found', 'and', 'in', 'concluded', 'told'],
#  ['that', 'after', 'in', 'during', 'of'],
#  ['analysis', 'examination', 'audit', 'evaluation', 'inspection'],
#  ['California', 'Virginia', 'Florida', 'Arizona', 'Alabama'],
#  ['first', 'November', 'May', 'Democratic', 'Republican'],
#  ['municipal', 'general', 'recall', 'presidential', 'gubernatorial'],
#  ['found', 'showed', 'uncovered', 'revealed', 'discovered'],
#  ['indication', 'proof', 'sign', 'information', 'confirmation'],
#  ['violence', 'election', 'voting', 'fraud', 'election'],
#  ['take', 'taking', 'in', 'taken', 'did'],
#  ['mayor', 'governor', 'president', 'council', 'city'],
#  ['stated', 'declared', 'noted', 'concluded', 'reported'],
#  ['the', 'it', 'their', 'his', 'her'],
#  ['of', 'three', 'two', 'length', 'court'],
#  ['celebration', 'term', 'celebration', 'remark', 'speech'],
#  ['took', 'ha', 'take', 'hold', 'held'],
#  ['knowledge', 'control', 'coverage', 'approval', 'account'],
#  ['contest', 'matter', 'event', 'vote', 'city'],
#  ['received', 'deserved', 'expressed', 'deserve', 'gave'],
#  ['respect', 'thanks', 'support', 'recognition', 'appreciation'],
#  ['respect', 'recognition', 'admiration', 'appreciation', 'attention'],
#  ['way', 'circumstance', 'year', 'order', 'spirit'],
#  ['vote', 'voting', 'polling', 'contest', 'poll'],
#  ['held', 'won', 'done', 'arranged', 'organised'],
#  ['four', 'two', 'three', 'first', 'five'],
#  ['long', 'first', 'mid', 'last', 'second'],
#  ['the', 'a', 'grand', 'trial', 'and'],
#  [],
#  ['appointed', 'convened', 'formed', 'hired', 'called'],
#  ['make', 'file', 'receive', 'report', 'produce'],
#  ['allegation', 'evidence', 'charge', 'claim', 'accusation'],
#  ['alleged', 'voting', 'financial', 'the', 'election'],
#  ['corruption', 'fraud', 'interference', 'flaw', 'sabotage'],
#  ['Democratic', 'Republican', 'state', 'party', 'presidential'],
#  ['election', 'case', 'contest', 'trial', 'race'],
#  ['decided', 'led', 'headed', 'contested', 'called'],
#  ['Only', 'Not', 'Quite', 'But', 'Perhaps'],
#  ['small', 'mere', 'select', 'very', 'tiny'],
#  ['number', 'lack', 'majority', 'few', 'amount'],
#  ['positive', 'negative', 'favorable', 'reliable', 'credible'],
#  ['vote', 'ballot', 'signature', 'proposal', 'call'],
#  ['published', 'made', 'produced', 'credible', 'available'],
#  ['newspaper', 'paper', 'report', 'Times', 'Guardian'],
#  ['wrote', 'concluded', 'noted', 'reported', 'stated'],
#  ['reflecting', 'given', 'despite', 'for', 'indicating'],
#  ['public', 'popular', 'national', 'local', 'general'],
#  ['turnout', 'fraud', 'corruption', 'violence', 'bias'],
#  ['city', 'area', 'matter', 'issue', 'race'],
#  ['percentage', 'proportion', 'turnout', 'size', 'lack'],
#  ['candidate', 'vote', 'supporter', 'participant', 'witness'],
#  ['population', 'reputation', 'status', 'character', 'history'],
#  ['electorate', 'constituency', 'district', 'community', 'group'],
#  ['government', 'BBC', 'newspaper', 'report', 'commission'],
#  ['stated', 'noted', 'found', 'admitted', 'indicated'],
#  ['note', 'show', 'notice', 'believe', 'agree'],
#  ['California', 'Georgia', 'Canada', 'Oregon', 'Arizona'],
#  ['law', 'constitutional', 'constitution', 'election', 'law'],
#  ['licensing', 'registration', 'copyright', 'trademark', 'tax'],
#  ['document', 'procedure', 'record', 'rule', 'requirement'],
#  ['were', 'appear', 'seem', 'remain', 'appeared'],
#  ['inadequate', 'weak', 'obsolete', 'inconsistent', 'vague'],
#  ['obsolete', 'inconsistent', 'archaic', 'vague', 'ineffective'],
#  ['politically', 'sometimes', 'somewhat', 'too', 'potentially'],
#  ['violated', 'corrupt', 'ineffective', 'unconstitutional', 'unreliable'],
#  ['requires', 'state', 'stated', 'required', 'demanded'],
#  ['should', 'commissioner', 'would', 'could', 'Commissioners'],
#  ['continue', 'agree', 'were', 'work', 'agreed'],
#  ['see', 'get', 'keep', 'make', 'consider'],
#  ['regulation', 'statute', 'policy', 'program', 'standard'],
#  ['revised', 'amended', 'updated', 'modified', 'repealed'],
#  ['brought', 'worked', 'put', 'fought', 'promoted'],
#  ['point', 'purpose', 'goal', 'aim', 'extent'],
#  ['writing', 'time', 'life', 'taking', 'drafting'],
#  ['replacing', 'implementing', 'expanding', 'extending', 'strengthening'],
#  ['expert', 'national', 'special', 'same', 'selection'],
#  ['reported', 'focused', 'spoke', 'decided', 'agreed'],
#  ['variety', 'range', 'host', 'multitude', 'series'],
#  ['different', 'key', 'important', 'related', 'policy'],
#  ['department', 'matter', 'issue', 'problem', 'factor'],
#  ['county', 'local', 'district', 'county', 'city'],
#  ['police', 'health', 'government', 'planning', 'fire'],
#  ['concluded', 'found', 'stated', 'noted', 'declared'],
#  ['remain', 'were', 'be', 'is', 'have'],
#  ['independently', 'properly', 'jointly', 'poorly', 'efficiently'],
#  ['established', 'managed', 'organized', 'developed', 'organised'],
#  ['are', 'have', 'meet', 'fairly', 'reflect'],
#  ['widely', 'well', 'internationally', 'universally', 'broadly'],
#  ['principle', 'procedure', 'policy', 'standard', 'law'],
#  ['appeal', 'are', 'serve', 'contribute', 'cater'],
#  ['common', 'public', 'mutual', 'joint', 'national'],
#  ['practice', 'effort', 'advantage', 'wish', 'judgment'],
#  ['party', 'side', 'country', 'community', 'state'],
#  ['However', 'Additionally', 'Furthermore', 'Nevertheless', 'Finally'],
#  ['government', 'company', 'firm', 'university', 'board'],
#  ['stated', 'say', 'indicated', 'state', 'noted'],
#  ['believed', 'concluded', 'found', 'felt', 'thought'],
#  ['three', 'four', 'five', 'six', 'new'],
#  ['approach', 'factor', 'technology', 'strategy', 'measure'],
#  ['provide', 'promote', 'ensure', 'foster', 'bring'],
#  ['more', 'increased', 'better', 'higher', 'economic'],
#  ['transparency', 'autonomy', 'effectiveness', 'productivity', 'security'],
#  ['lower', 'minimize', 'decrease', 'avoid', 'le'],
#  ['burden', 'complexity', 'effectiveness', 'efficiency', 'quality'],
#  ['operation', 'operation', 'litigation', 'operating', 'construction'],
#  ['report', 'mayor', 'city', 'commission', 'agency'],
#  ['noted', 'stated', 'say', 'state', 'reported'],
#  ['wa', 'were', 'remains', 'are', 'became'],
#  ['bringing', 'interested', 'drawing', 'investing', 'filling'],
#  ['adequate', 'qualified', 'it', 'quality', 'effective'],
#  ['police', 'management', 'administrative', 'government', 'city'],
#  ['staff', 'skill', 'experience', 'support', 'work'],
#  ['part', 'consequence', 'component', 'matter', 'feature'],
#  ['poor', 'inadequate', 'changing', 'it', 'weak'],
#  ['purchasing', 'hiring', 'management', 'planning', 'buying'],
#  ['shortage', 'shortage', 'training', 'misconduct', 'abuse'],
#  ['recommended', 'requires', 'requested', 'demanded', 'suggested'],
#  ['government', 'state', 'Government', 'public', 'Council'],
#  ['make', 'undertake', 'pursue', 'consider', 'took'],
#  ['action', 'measure', 'action', 'care', 'effort'],
#  ['address', 'solve', 'resolve', 'tackle', 'fix'],
#  ['situation', 'issue', 'crisis', 'condition', 'disaster'],
#  ['Enforcement', 'Part', 'Application', 'Passage', 'Much'],
#  ['California', 'Michigan', 'Pennsylvania', 'Florida', 'Georgia'],
#  ['land', 'new', 'civil', 'territorial', 'property'],
#  ['tax', 'safety', 'insurance', 'ownership', 'registration'],
#  ['system', 'scheme', 'design', 'change', 'proposal'],
#  ['not', 'strongly', 'unanimously', 'then', 'again'],
#  ['approved', 'rejected', 'blocked', 'criticized', 'opposed'],
#  ['grand', 'same', 'federal', 'national', 'state'],
#  ['government', 'parliament', 'cabinet', 'governor', 'legislature'],
#  ['required', 'recommended', 'requires', 'requested', 'proposed'],
#  ['state', 'provincial', 'new', 'Ontario', 'State'],
#  ['government', 'Parliament', 'amendment', 'legislation', 'parliament'],
#  ['appropriate', 'raise', 'approve', 'withdraw', 'consider'],
#  ['the', 'additional', 'sufficient', 'more', 'public'],
#  ['legislation', 'power', 'provision', 'measure', 'guidance'],
#  ['implementation', 'commencement', 'election', 'appropriate', 'adoption'],
#  ['budget', 'law', 'rule', 'rate', 'period'],
#  ['reform', 'revision', 'change', 'review', 'repeal'],
#  ['Act', 'bill', 'legislation', 'plan', 'act'],
#  ['undertaken', 'achieved', 'conducted', 'made', 'pursued'],
#  ['federal', 'trial', 'same', 'state', 'defense'],
#  ['list', 'allocation', 'use', 'review', 'collection'],
#  ['the', 'state', 'all', 'public', 'government'],
#  ['grant', 'funding', 'subsidy', 'assistance', 'permit'],
#  ['used', 'needed', 'allocated', 'required', 'available'],
#  ['social', 'infant', 'basic', 'youth', 'public'],
#  ['private', 'nursing', 'state', 'public', 'retirement'],
#  ['wa', 'being', 'constitutes', 'remains', 'form'],
#  ['none', 'some', 'another', 'two', 'all'],
#  ['key', 'basic', 'essential', 'main', 'important'],
#  ['issue', 'problem', 'factor', 'change', 'flaw'],
#  ['financial', 'social', 'public', 'welfare', 'economic'],
#  ['welfare', 'aid', 'fund', 'fund', 'insurance'],
#  ['plan', 'system', 'scheme', 'package', 'fund'],
#  ['report', 'court', 'governor', 'state', 'letter'],
#  ['stated', 'wrote', 'noted', 'reported', 'state'],
#  ['get', 'transfer', 'pas', 'direct', 'send'],
#  ['item', 'money', 'payment', 'dollar', 'benefit'],
#  ['various', 'health', 'other', 'different', 'social'],
#  ['agency', 'program', 'system', 'system', 'service'],
#  ['both', 'most', 'All', 'each', 'any'],
#  ['municipality', 'state', 'community', 'city', 'district'],
#  ['county', 'district', 'country', 'State', 'area'],
#  ['consent', 'assistance', 'support', 'help', 'benefit'],
#  ['ha', 'received', 'get', 'need', 'provides'],
#  ['funding', 'assistance', 'information', 'aid', 'fund'],
#  ['group', 'organization', 'committee', 'board', 'state'],
#  ['say', 'stated', 'claimed', 'indicated', 'noted'],
#  ['believed', 'thought', 'feared', 'felt', 'believe'],
#  ['massive', 'large', 'mass', 'poor', 'narrow'],
#  ['amount', 'portion', 'share', 'percentage', 'proportion'],
#  ['vote', 'number', 'item', 'voter', 'case'],
#  ['benefit', 'affect', 'support', 'help', 'impact'],
#  ['system', 'process', 'trend', 'situation', 'effort'],
#  ['most', 'more', 'least', 'very', 'many'],
#  ['developed', 'affluent', 'populated', 'prosperous', 'fortunate'],
#  ['country', 'region', 'community', 'country', 'area'],
#  ['However', 'Also', 'Additionally', 'Furthermore', 'Finally'],
#  ['believe', 'hope', 'expect', 'agree', 'think'],
#  ['have', 'retain', 'use', 'provide', 'keep'],
#  ['a', 'it', 'their', 'another', 'no'],
#  ['more', 'part', 'share', 'use', 'proportion'],
#  ['trust', 'state', 'public', 'tax', 'additional'],
#  ['asset', 'resource', 'land', 'right', 'grant'],
#  ['report', 'commission', 'governor', 'court', 'board'],
#  ['wrote', 'stated', 'noted', 'agreed', 'concluded'],
#  ['Trying', 'Having', 'And', 'How', 'Continuing'],
#  ['accomplish', 'achieve', 'implement', 'address', 'pay'],
#  ['tend', 'lead', 'seem', 'have', 'appear'],
#  ['impose', 'put', 'be', 'create', 'have'],
#  ['huge', 'heavy', 'tremendous', 'great', 'significant'],
#  ['value', 'toll', 'price', 'pressure', 'impact'],
#  ['member', 'Park', 'himself'],
#  ['report', 'paper', 'article', 'newspaper', 'BBC'],
#  ['ha', 'had', 'then', 'later', 'further'],
#  ['called', 'sat', 'reported', 'sits', 'relied'],
#  ['family', 'mill', 'court', 'church', 'parish'],
#  ['reputation', 'practice', 'work', 'jurisdiction', 'organisation'],
#  ['on', 'fighting', 'set', 'caught', 'given'],
#  ['role', 'involvement', 'part', 'interference', 'failure'],
#  ['prosecution', 'court', 'employment', 'training', 'hiring'],
#  ['judge', 'trustee', 'parent', 'lawyer', 'teacher'],
#  ['manager', 'lawyer', 'contractor', 'judge', 'director'],
#  ['trustee', 'manager', 'director', 'employee', 'assistant'],
#  ['distribution', 'payment', 'administration', 'provision', 'collection'],
#  ['damage', 'contract', 'compensation', 'benefit', 'commission'],
#  ['fine', 'benefit', 'fee', 'award', 'grant'],
#  ['court', 'judge', 'report', 'commission', 'committee'],
#  ['stated', 'concluded', 'noted', 'wrote', 'reported'],
#  ['said', 'felt', 'believed', 'noted', 'thought'],
#  ['jury', 'judge', 'commission', 'tribunal', 'committee'],
#  ['adopted', 'introduced', 'integrated', 'taken', 'put'],
#  ['judicial', 'own', 'administrative', 'legal', 'constitutional'],
#  ['work', 'finding', 'procedure', 'decision', 'action'],
#  ['the', 'three', 'several', 'four', 'five'],
#  ['state', 'local', 'other', 'separate', 'independent'],
#  ['state', 'county', 'judicial', 'advisory', 'district'],
#  ['elected', 'independent', 'active', 'individual', 'autonomous'],
#  ['judicial', 'advisory', 'law', 'judiciary', 'appeal'],
#  ['measure', 'provision', 'rule', 'law', 'arrangement'],
#  ['aim', 'help', 'be', 'seek', 'have'],
#  ['free', 'shield', 'save', 'recover', 'prevent'],
#  ['the', 'that', 'this', 'historical', 'a'],
#  ['to', 'at', 'into', 'even', 'with'],
#  ['city', 'town', 'City', 'state', 'government'],
#  ['judge', 'staff', 'jurisdiction', 'employee', 'member'],
#  ['court', 'it', 'legal', 'administrative', 'litigation'],
#  ['scrutiny', 'influence', 'criticism', 'pressure', 'abuse'],
#  ['judge', 'elected', 'officer', 'member', 'judicial'],
#  ['appointed', 'unpaid', 'qualified', 'paid', 'trusted'],
#  ['judge', 'member', 'officer', 'official', 'commissioner'],
#  ['such', 'public', 'any', 'external', 'adverse'],
#  ['conduct', 'expense', 'penalty', 'litigation', 'liability'],
#  ['court', 'judge', 'Court', 'report', 'government'],
#  ['wrote', 'concluded', 'noted', 'stated', 'reported'],
#  ['Regarding', 'For', 'On', 'With', 'In'],
#  ['Singapore', 'Chicago', 'Houston', 'Washington', 'Miami'],
#  ['one', 'two', 'five', 'three', 'four'],
#  ['billion', 'US', 'thousand', 'one', 'trillion'],
#  ['seater', 'euro', 'passenger', 'capacity', 'seat'],
#  ['contract', 'plan', 'bid', 'acquisition', 'investment'],
#  ['government', 'report', 'commission', 'board', 'committee'],
#  ['decided', 'concluded', 'stated', 'found', 'determined'],
#  ['airport', 'city', 'local', 'Airport', 'municipal'],
#  ['mayor', 'government', 'governor', 'judge', 'president'],
#  ['will', 'can', 'is', 'shall', 'ha'],
#  ['of', 'number', 'level', 'Phase', '№'],
#  ['Airport', 'facility', 'aircraft', 'terminal', 'airfield'],
#  ['renovated', 'rebuilt', 'run', 'upgraded', 'expanded'],
#  ['way', 'style', 'fashion', 'direction', 'state'],
#  ['avoid', 'remove', 'reduce', 'exclude', 'minimize'],
#  ['external', 'foreign', 'adverse', 'outside', 'negative'],
#  ['corruption', 'interference', 'opposition', 'instability', 'violence'],
#  ['report', 'government', 'commission', 'Commission', 'court'],
#  ['later', 'indeed', 'no', 'never', 'nothing'],
#  ['agree', 'comment', 'disagree', 'respond', 'report'],
#  ['concluded', 'recommended', 'found', 'ruled', 'held'],
#  ['been', 'exist', 'remain', 'occur', 'come'],
#  ['adequate', 'extensive', 'a', 'proper', 'no'],
#  ['review', 'monitoring', 'scrutiny', 'investigation', 'analysis'],
#  ['business', 'economic', 'trading', 'financial', 'trade'],
#  ['policy', 'activity', 'behaviour', 'arrangement', 'system'],
#  ['company', 'company', 'firm', 'defendant', 'party'],
#  ['sake', 'benefit', 'aim', 'reason', 'objective'],
#  ['making', 'rendering', 'setting', 'holding', 'maintaining'],
#  ['rate', 'condition', 'claim', 'cost', 'rate'],
#  ['low', 'stable', 'high', 'down', 'level'],
#  ['these', 'all', 'such', 'those', 'technical'],
#  ['issue', 'occasion', 'ground', 'count', 'question'],
#  ['committee', 'Commission', 'Committee', 'commission', 'Court'],
#  ['found', 'decided', 'determined', 'held', 'concluded'],
#  ['Two', 'two', 'Three', 'and', 'The'],
#  ['county', 'sheriff', 'state', 'deputy', 'jail'],
#  ['officer', 'men', 'inmate', 'staff', 'member'],
#  ['stationed', 'housed', 'appointed', 'trained', 'hired'],
#  ['clerk', 'nurse', 'physician', 'lawyer', 'deputy'],
#  ['an', 'dental', 'prison', 'veterinary', 'military'],
#  ['nurse', 'assistant', 'clerk', 'doctor', 'teacher'],
#  ['assigned', 'appointed', 'hired', 'designated', 'responsible'],
#  ['day', 'evening', 'weekday', 'morning', 'afternoon'],
#  ['day', 'morning', 'night', 'evening', 'afternoon'],
#  ['work', 'shift', 'service', 'operation', 'service'],
#  ['prison', 'courthouse', 'facility', 'hospital', 'time'],
#  ['will', 'would', 'also', 'must', 'ha'],
#  ['worked', 'partnered', 'negotiated', 'collaborated', 'voted'],
#  ['elected', 'local', 'public', 'municipal', 'City'],
#  ['leader', 'council', 'government', 'commissioner', 'voter'],
#  ['draft', 'create', 'find', 'approve', 'develop'],
#  ['new', 'comprehensive', 'appropriate', 'the', 'federal'],
#  ['ensure', 'require', 'include', 'allow', 'enable'],
#  ['creation', 'implementation', 'development', 'adoption', 'provision'],
#  ['free', 'reasonable', 'inclusive', 'affordable', 'fair'],
#  ['employment', 'retirement', 'health', 'service', 'master'],
#  ['fund', 'system', 'scheme', 'program', 'pool'],
#  ['all', 'their', 'new', 'local', 'minority'],
#  ['report', 'group', 'paper', 'newspaper', 'article'],
#  ['oversaw', 'oversees', 'and', 'for', 'supervised'],
#  ['structure', 'construction', 'organization', 'design', 'management'],
#  ['management', 'control', 'service', 'personnel', 'work'],
#  ['local', 'city', 'county', 'town', 'new'],
#  ['fire', 'tax', 'health', 'justice', 'prison'],
#  ['dairy', 'cattle', 'fruit', 'tree', 'chicken'],
#  ['brought', 'entered', 'file', 'file', 'in'],
#  ['unsuccessfully', 'successfully', 'again', 'twice', 'paper'],
#  ['damage', 'separation', 'dismissal', 'harassment', 'compensation'],
#  ['mother', 'daughter', 'sister', 'partner', 'mistress'],
#  ['v', 'court', 'proceeding', 'no', 'case'],
#  ['own', 'deeply', 'sexually', 'highly', 'blood'],
#  ['against', 'for', 'of', 'Against', 'condemned'],
#  ['with', 'his', 'him', 'her', 'the'],
#  ['illness', 'health', 'disorder', 'disorder', 'disease'],
#  ['latter', 'former', 'two', 'son', 'daughter'],
#  ['divorced', 'widowed', 'wed', 'born', 'engaged'],
#  ['December', 'June', 'November', 'September', 'August'],
#  ['had', 'left', 'bore', 'were', 'produced'],
#  ['daughter', 'brother', 'wife', 'boy', 'grandson'],
#  ['son', 'grandson', 'granddaughter', 'wife', 'sister'],
#  ['Counsel', 'Representatives', 'Attorney', 'Speaking', 'Appeals'],
#  ['plaintiff', 'company', 'defendant', 'defense', 'prosecution'],
#  ['claim', 'state', 'say', 'argue', 'report'],
#  ['entire', 'intellectual', 'official', 'additional', 'extensive'],
#  ['legal', 'financial', 'plea', 'settlement', 'monetary'],
#  ['settled', 'decided', 'entered', 'insisted', 'advanced'],
#  ['census', 'report', 'city', 'article', 'Census'],
#  ['gave', 'described', 'list', 'stated', 'give'],
#  ['man', 'defendant', 'plaintiff', 'judge', 'sheriff'],
#  ['name', 'title', 'rank', 'position', 'status'],
#  ['unknown', 'minor', 'carpenter', 'farmer', 'blacksmith'],
#  ['occupation', 'number', 'population', 'death', 'attendance'],
#  ['give', 'record', 'list', 'recorded', 'gave'],
#  ['mother', 'father', 'family', 'daughter', 'widow'],
#  ['number', 'population', 'year', 'name', 'birthday'],
#  ['year', 'date', 'country', 'month', 'day'],
#  ['judge', 'court', 'article', 'couple', 'author'],
#  ['state', 'claim', 'say', 'stated', 'asserts'],
#  ['family', 'pair', 'two', 'woman', 'marriage'],
#  ['never', 'already', 'only', 'been', 'now'],
#  ['been', 'slept', 'worked', 'remained', 'stayed'],
#  ['apart', 'separately', 'there', 'again', 'legally'],
#  ['husband', 'father', 'wife', 'partner', 'mother'],
#  ['longer', 'le', 'further', 'greater', 'fewer'],
#  ['decade', 'century', 'month', 'week', 'millennium'],
#  ['address', 'station', 'house', 'site', 'boundary'],
#  ['stood', 'wa', 'stand', 'standing', 'lived'],
#  ['named', 'included', 'present', 'represented', 'also'],
#  ['ballot', 'list', 'record', 'paper', 'roll'],
#  ['county', 'city', 'state', 'plaintiff', 'district'],
#  ['wife', 'successor', 'son', 'daughter', 'candidate'],
#  ['remained', 'served', 'wa', 'a', 'held'],
#  ['composed', 'fond', 'devoid', 'full', 'free'],
#  ['Portland', 'Cleveland', 'Springfield', 'Manchester', 'Boston'],
#  ['only', 'just', 'memory', 'something', 'most'],
#  ['a', 'the', 'this', 'that', 'their'],
#  ['electoral', 'political', 'historical', 'summer', 'historic'],
#  ['term', 'stint', 'period', 'spell', 'time'],
#  ['professional', 'public', 'elected', 'municipal', 'long'],
#  ['affiliation', 'history', 'legacy', 'experience', 'influence'],
#  ['date', 'dated', 'went', 'trace', 'date'],
#  ['appointment', 'elevation', 'nomination', 'selection', 'reelection'],
#  ['the', 'local', 'town', 'county', 'Wigan'],
#  ['President', 'president', 'incumbent', 'governor', 'Governor'],
#  ['full', 'first', 'final', 'current', 'entire'],
#  ['year', 'period', 'date', 'day', 'tenure'],
#  ['is', 'wa', 'end', 'includes', 'begin'],
#  ['January', 'June', 'April', 'December', 'November'],
#  ['replaced', 'defeated', 'opposed', 'joined', 'challenged'],
#  ['wa', 'is', 'remained', 'becomes', 'a'],
#  ['challenger', 'Democrat', 'finalist', 'contender', 'nominee'],
#  ['May', 'November', 'June', 'April', 'August'],
#  ['day', 'year', 'November', 'October', 'month'],
#  ['declared', 'stated', 'indicated', 'ruled', 'said'],
#  ['never', 'also', 'instead', 'again', 'only'],
#  ['stand', 'campaign', 'contest', 'bid', 'compete'],
#  ['mayor', 'office', 'election', 'Mayor', 'governor'],
#  ['Irish', 'While', 'Although', 'The', 'Young'],
#  [],
#  ['given', 'a', 'giving', 'of', 'under'],
#  ['the', 'some', 'more', 'an', 'enough'],
#  ['enough', 'support', 'pressure', 'call', 'offer'],
#  ['be', 'support', 'run', 'nominate', 'include'],
#  ['Democrat', 'party', 'Republican', 'woman', 'district'],
#  ['woman', 'mayor', 'President', 'president', 'Governor'],
#  ['in', 'of', 'for', 'at', 'on'],
#  ['in', 'on', 'since', 'of', 'at'],
#  ['later', 'unanimously', 'afterwards', 'earlier', 'so'],
#  ['the', 'a', 'it', 'their', 'former'],
#  ['party', 'council', 'senate', 'board', 'convention'],
#  ['resident', 'host', 'member', 'expert', 'president'],
#  ['at', 'and', 'in', 'attended', 'called'],
#  ['party', 'concert', 'ball', 'ceremony', 'festival'],
#  ['on', 'that', 'one', 'at', 'of'],
#  ['that', 'one', 'last', 'Friday', 'at'],
#  ['and'],
#  ['drew', 'received', 'attracted', 'prompted', 'generated'],
#  ['positive', 'negative', 'no', 'mixed', 'strong'],
#  ['applause', 'cheer', 'support', 'laughter', 'reaction'],
#  ['community', 'public', 'resident', 'crowd', 'people'],
#  ['said', 'stated', 'announced', 'reported', 'noted'],
#  ['it', 'he', 'time', 'she', 'news'],
#  ['built', 'building', 'stirred', 'still', 'pumped'],
#  ['major', 'national', 'special', 'new', 'big'],
#  ['convention', 'conference', 'election', 'meeting', 'debate'],
#  ['at', 'in', 'on', 'a', 'called'],
#  ['September', 'November', 'February', 'June', 'July'],
#  ['November', 'August', 'June', 'July', 'September'],
#  ['the', 'an', 'locally', 'popularly', 'recently'],
#  ['installed', 'inducted', 'constructed', 'appointed', 'built'],
#  ['governor', 'state', 'Governor', 'speaker', 'president'],
#  ['become', 'host', 'have', 'provide', 'play'],
#  ['main', 'official', 'chief', 'guest', 'party'],
#  ['event', 'candidate', 'rally', 'venue', 'guest'],
#  ['scene', 'stage', 'area', 'theater', 'below'],
#  ['party', 'state', 'organization', 'board', 'union'],
#  ['told', 'informed', 'convinced', 'concerned', 'advised'],
#  ['being', 'choosing', 'selecting', 'having', 'becoming'],
#  ['race', 'ballot', 'contest', 'convention', 'bid'],
#  ['president', 'office', 'President', 'election', 'mayor'],
#  ['cause', 'require', 'allow', 'lead', 'encourage'],
#  ['send', 'carry', 'bring', 'throw', 'launch'],
#  ['him', 'her', 'them', 'people', 'it'],
#  ['deep', 'directly', 'going', 'from', 'back'],
#  ['the', 'other', 'all', 'their', 'it'],
#  ['collect', 'get', 'gather', 'request', 'seek'],
#  ['support', 'vote', 'approval', 'endorsement', 'consent'],
#  ['the', 'potential', 'eligible', 'it', 'all'],
#  ['elector', 'candidate', 'Democrats', 'citizen', 'people'],
#  ['election', 'result', 'controversy', 'ban', 'vote'],
#  ['is', 'remained', 'were', 'being', 'became'],
#  ['secret', 'public', 'no', 'majority', 'free'],
#  ['decision', 'agreement', 'refusal', 'consent', 'recommendation'],
#  ['choose', 'nominate', 'select', 'appoint', 'pick'],
#  ['contest', 'parliament', 'debate', 'room', 'vote'],
#  ['those', 'all', 'everyone', 'delegate', 'voter'],
#  ['objected', 'voted', 'disagreed', 'protested', 'agreed'],
#  ['party', 'House', 'Senate', 'state', 'Assembly'],
#  ['asking', 'considering', 'debating', 'unsure', 'ask'],
#  ['ought', 'wa', 'had', 'needed', 'intended'],
#  ['run', 'win', 'have', 'try', 'seek'],
#  ['for', 'any', 'two', 'some', 'even'],
#  ['year', 'day', 'week', 'month', 'hour'],
#  ['win', 'enter', 'join', 'contest', 'continue'],
#  ['vote', 'change', 'decision', 'election', 'move'],
#  ['said', 'replied', 'answered', 'wa', 'responded'],
#  ['yes', 'No', 'Yes', 'otherwise', 'unanimously'],
#  ['are', 'wa', 'being', 'remained', 'been'],
#  ['vote', 'winner', 'change', 'result', 'candidate'],
#  ['obstacle', 'challenge', 'problem', 'issue', 'threat'],
#  ['team', 'horse', 'horse', 'team', 'winner'],
#  ['overcome', 'avoid', 'cross', 'take', 'solve'],
#  ['wa', 'being', 'in', 'to', 'under'],
#  ['new', 'proposed', 'constitutional', 'federal', 'British'],
#  ['constitution', 'statute', 'Constitution', 'clause', 'policy'],
#  ['state', 'requires', 'provides', 'hold', 'mean'],
#  ['entering', 'winning', 'starting', 'having', 'taking'],
#  ['presidential', 'political', 'second', 'new', 'Senate'],
#  ['speech', 'move', 'choice', 'strike', 'attempt'],
#  ['either', 'consideration', 'any', 'two', 'choice'],
#  ['three', 'four', 'several', 'five', 'the'],
#  ['different', 'golf', 'obstacle', 'race', 'possible'],
#  ['route', 'path', 'step', 'approach', 'measure'],
#  ['used', 'considered', 'chosen', 'run', 'offered'],
#  ['Fifty', 'Ten', 'Twenty', 'Thirty', 'Five'],
#  ['Per', 'a', 'one', 'in', 'each'],
#  ['delegate', 'elector', 'citizen', 'people', 'Republicans'],
#  ['the', 'a', 'every', 'one', 'that'],
#  ['district', 'state', 'ward', 'constituency', 'precinct'],
#  ['file', 'submit', 'present', 'signed', 'lodge'],
#  ['paper', 'document', 'letter', 'sign', 'legislation'],
#  ['demanding', 'asking', 'urging', 'calling', 'suggesting'],
#  ['party', 'voter', 'party', 'state', 'Democrats'],
#  ['able', 'permitted', 'required', 'authorized', 'asked'],
#  ['submit', 'put', 'include', 'list', 'give'],
#  ['list', 'list', 'dozen', 'score', 'signature'],
#  ['voter', 'elector', 'individual', 'themselves', 'supporter'],
#  ['local', 'state', 'primary', 'presidential', 'special'],
#  ['roll', 'roll', 'list', 'ticket', 'ticket'],
#  ['party', 'state', 'county', 'party', 'Republicans'],
#  ['contest', 'win', 'run', 'have', 'enter'],
#  ['ballot', 'vote', 'majority', 'referendum', 'convention'],
#  ['state', 'electoral', 'presidential', 'regional', 'single'],
#  ['ballot', 'quota', 'electoral', 'voting', 'council'],
#  ['code', 'rule', 'rule', 'charter', 'constitution'],
#  ['method', 'process', 'policy', 'provision', 'model'],
#  ['Party', 'state', 'Republican', 'government', 'Republicans'],
#  ['us', 'support', 'follows', 'used', 'utilizes'],
#  ['entirety', 'primary', 'state', 'majority', 'favor'],
#  ['medium', 'race', 'labor', 'government', 'consumer'],
#  ['officer', 'manager', 'consultant', 'specialist', 'assistant'],
#  ['left', 'hired', 'recruited', 'chose', 'joined'],
#  ['temporarily', 'voluntarily', 'briefly', 'unexpectedly', 'early'],
#  ['run', 'campaign', 'vote', 'compete', 'stand'],
#  ['office', 'website', 'department', 'board', 'agency'],
#  ['arrival', 'return', 'departure', 'visit', 'death'],
#  ['accepted', 'delayed', 'considered', 'pending', 'announced'],
#  ['a', 'all', 'the', 'another', 'no'],
#  ['reason', 'year', 'month', 'day', 'week'],
#  ['killed', 'murdered', 'arrested', 'replaced', 'executed'],
#  ['remained', 'had', 'stayed', 'served', 'wa'],
#  ['exile', 'MP', 'invalid', 'earl', 'prisoner'],
#  ['le', 'longer', 'for', 'better', 'greater'],
#  ['twenty', 'ten', 'two', 'thirty', 'five'],
#  ['decade', 'century', 'generation', 'month', 'week'],
#  ['new', 'presidential', 'election', 'next', 'second'],
#  ['race', 'election', 'term', 'season', 'run'],
#  ['begin', 'end', 'open', 'close', 'concludes'],
#  ['asked', 'hired', 'invited', 'selected', 'recruited'],
#  ['be', 'have', 'hire', 'provide', 'find'],
#  ['political', 'senior', 'regional', 'recruiting', 'program'],
#  ['slogan', 'target', 'name', 'choice', 'goal'],
#  ['wrap', 'break', 'give', 'pick', 'finish'],
#  ['tax', 'budget', 'election', 'financial', 'traffic'],
#  ['early', 'here', 'there', 'late', 'tomorrow'],
#  ['leave', 'depart', 'run', 'sail', 'headed'],
#  ['Washington', 'Denver', 'Montana', 'Chicago', 'Texas'],
#  ['new', 'state', 'federal', 'government', 'original'],
#  ['tax', 'toll', 'construction', 'maintenance', 'improvement'],
#  ['issue', 'change', 'amendment', 'document', 'bill'],
#  ['need', 'receives', 'ha', 'collect', 'raise'],
#  ['be', 'arrive', 'go', 'come', 'remain'],
#  ['suit', 'up', 'it', 'him', 'soon'],
#  ['the', 'each', 'a', 'every', 'next'],
#  ['that', 'this', 'tomorrow', 'Monday', 'Friday'],
#  ['begin', 'start', 'end', 'arrives', 'date'],
#  ['Governor', 'governor', 'legislature', 'President', 'Senate'],
#  ['required', 'asked', 'requested', 'scheduled', 'instructed'],
#  ['conduct', 'perform', 'begin', 'do', 'undertake'],
#  ['review', 'reduction', 'census', 'list', 'survey'],
#  ['salary', 'amount', 'percentage', 'work', 'portfolio'],
#  ['seat', 'acre', 'day', 'hour', 'hectare'],
#  ['assigned', 'traveling', 'sent', 'moving', 'posted'],
#  ['city', 'suburban', 'town', 'state', 'school'],
#  ['remote', 'coastal', 'suburban', 'rural', 'tribal'],
#  ['decide', 'see', 'consider', 'ass', 'evaluate'],
#  ['decision', 'change', 'recommendation', 'amendment', 'choice'],
#  ['implemented', 'taken', 'done', 'required', 'necessary'],
#  ['scheduled', 'required', 'asked', 'allowed', 'invited'],
#  ['enjoy', 'pay', 'attend', 'perform', 'continue'],
#  ['first', 'final', 'occasional', 'required', 'same'],
#  ['call', 'approach', 'trip', 'commitment', 'entrance'],
#  ['party', 'school', 'city', 'side', 'state'],
#  ['move', 'progress', 'head', 'proceed', 'march'],
#  ['completion', 'victory', 'success', 'independence', 'agreement'],
#  ['also', 'then'],
#  ['have', 'use', 'consider', 'see', 'view'],
#  [],
#  ['billion', 'Million', 'thousand', 'crore', 'trillion'],
#  ['state', 'school', 'federal', 'city', 'bond'],
#  ['construction', 'widening', 'funding', 'toll', 'budget'],
#  ['measure', 'package', 'proposal', 'being', 'option'],
#  ['passed', 'filed', 'announced', 'proposed', 'introduced'],
#  ['early', 'late', 'later', 'prior', 'previously'],
#  ['year', 'month', 'week', 'day', 'season'],
#  ['top', 'next', 'highest', 'final', 'last'],
#  ['agenda', 'budget', 'ballot', 'major', 'legislative'],
#  ['issue', 'priority', 'measure', 'budget', 'project'],
#  ['Also', 'However', 'Recently', 'Additionally', 'Meanwhile'],
#  ['reported', 'announced', 'noted', 'revealed', 'said'],
#  ['wa', 'were', 'came', 'stood', 'hovered'],
#  ['nowhere', 'still', 'not', 'damn', 'just'],
#  ['not', 'much', 'nearly', 'likely', 'about'],
#  ['and', 'getting', 'to', 'coming', 'becoming'],
#  ['able', 'allowed', 'authorized', 'forced', 'prepared'],
#  ['sign', 'sell', 'approve', 'release', 'pay'],
#  ['US', 'next', 'remaining', 'nearly', 'required'],
#  [],
#  ['billion', 'trillion', 'Million', 'year', 'thousand'],
#  ['package', 'set', 'issue', 'series', 'round'],
#  ['state', 'road', 'the', 'new', 'federal'],
#  ['insurance', 'construction', 'maintenance', 'tax', 'state'],
#  ['project', 'permit', 'plan', 'proposal', 'fund'],
#  ['legal', 'actual', 'first', 'entire', 'real'],
#  ['holder', 'sale', 'company', 'money', 'holder'],
#  ['apply', 'proceed', 'turn', 'run', 'send'],
#  ['federal', 'county', 'local', 'district', 'civil'],
#  ['government', 'legislature', 'attorney', 'commission', 'office'],
#  ['federal', 'civil', 'second', 'legal', 'court'],
#  ['fire', 'defense', 'interest', 'loan', 'cause'],
#  ['prove', 'determine', 'challenge', 'establish', 'verify'],
#  ['merit', 'power', 'integrity', 'term', 'provision'],
#  ['bond', 'bond', 'contract', 'sale', 'debt'],
#  ['but', 'where', 'or', 'while', 'so'],
#  ['construction', 'work', 'investigation', 'negotiation', 'hearing'],
#  ['cease', 'be', 'continue', 'pay', 'come'],
#  ['be', 'are', 'is', 'being', 'then'],
#  ['signed', 'begin', 'commence', 'awarded', 'sign'],
#  ['the', 'construction', 'contract', 'their', 'engineering'],
#  ['project', 'contract', 'service', 'job', 'repair'],
#  ['Alabama', 'Texas', 'California', 'Kentucky', 'Oregon'],
#  ['more', 'least', 'le', 'other', 'many'],
#  ['lightly', 'densely', 'well', 'easily', 'poorly'],
#  ['used', 'damaged', 'developed', 'built', 'constructed'],
#  ['road', 'bridge', 'street', 'railroad', 'route'],
#  ['spokesman', 'spokesperson', 'official', 'report', 'ha'],
#  ['say', 'stated', 'suggested', 'suggests', 'state'],
#  ['still', 'already', 'currently', 'now', 'probably'],
#  ['wa', 'existed', 'exists', 'were', 'been'],
#  ['proposal', 'need', 'scheme', 'commission', 'program'],
#  ['underway', 'designed', 'proposed', 'intended', 'planned'],
#  ['use', 'sell', 'borrow', 'raise', 'secure'],
#  ['between', 'about', 'from', 'approximately', 'around'],
#  ['up'],
#  ['billion', 'thousand', 'hundred', 'm', 'Million'],
#  [],
#  ['billion', 'trillion', 'Million', 'thousand', 'year'],
#  ['annually', 'each', 'consisting', 'out', 'million'],
#  ['funding', 'grant', 'permit', 'fund', 'approval'],
#  ['the', 'additional', 'state', 'new', 'future'],
#  ['highway', 'infrastructure', 'roadway', 'freeway', 'bypass'],
#  ['maintenance', 'improvement', 'repair', 'infrastructure', 'development'],
#  ['project', 'company', 'purpose', 'contract', 'fund'],
#  ['government', 'bill', 'state', 'plan', 'legislation'],
#  ['also', 'now', 'instead', 'therefore', 'then'],
#  ['intended', 'planned', 'decided', 'wanted', 'hoped'],
#  ['give', 'offer', 'provide', 'grant', 'create'],
#  ['trust', 'new', 'special', 'reserve', 'hedge'],
#  ['the', 'state', 'government', 'these', 'tax'],
#  ['vehicle', 'tax', 'contract', 'fund', 'road'],
#  ['sold', 'released', 'paid', 'signed', 'purchased'],
#  ['each', 'any', 'over', 'the', 'Each'],
#  ['year', 'day', 'month', 'week', 'when'],
#  ['third', 'quarter', 'share', 'few', 'percentage'],
#  ['existing', 'new', 'older', 'previous', 'current'],
#  ['sold', 'taken', 'written', 'cut', 'bought'],
#  ['the', 'local', 'other', 'those', 'these'],
#  ['began', 'started', 'ended', 'concluded', 'launched'],
#  ['campaign', 'bid', 'candidacy', 'run', 'term'],
#  ['reelection', 'Governor', 'mayor', 'office', 'president'],
#  ['vote', 'motion', 'campaign', 'debate', 'resolution'],
#  ['Senate', 'primary', 'House', 'senate', 'court'],
#  ['issue', 'sale', 'cancellation', 'passage', 'introduction'],
#  [],
#  ['billion', 'thousand', 'Million', 'year', 'cent'],
#  ['consisting', 'short', 'out', 'instead', 'each'],
#  ['state', 'federal', 'new', 'the', 'private'],
#  ['toll', 'state', 'county', 'federal', 'interstate'],
#  ['development', 'school', 'government', 'bank', 'saving'],
#  ['a', 'originally', 'being', 'first', 'initially'],
#  ['signed', 'issued', 'owed', 'offered', 'promised'],
#  ['the', 'state', 'former', 'Louisiana', 'Texas'],
#  ['ha', 'had', 'also', 'later', 'is'],
#  ['from', 'in', 'to', 'on', 'of'],
#  ['though', 'therefore', 'meanwhile', 'too', 'then'],
#  ['never', 'only', 'no', 'hardly', 'neither'],
#  ['informed', 'told', 'notified', 'contacted', 'heard'],
#  ['since', 'again', 'directly', 'publicly', 'before'],
#  ['authority', 'proposal', 'process', 'decision', 'legislation'],
#  ['make', 'build', 'use', 'have', 'create'],
#  ['first', 'proposed', 'state', 'federal', 'two'],
#  ['state', 'toll', 'public', 'national', 'federal'],
#  ['development', 'state', 'bond', 'tax', 'highway'],
#  ['license', 'permit', 'license', 'licence', 'permit'],
#  ['pas', 'introduce', 'issue', 'sign', 'present'],
#  ['single', 'second', 'third', 'special', 'free'],
#  ['passed', 'elsewhere', 'circulating', 'unanimously', 'raised'],
#  ['support', 'address', 'end', 'review', 'protest'],
#  ['state', 'government', 'legislature', 'governor', 'county'],
#  ['right', 'lack', 'use', 'offer', 'choice'],
#  ['delay', 'assisting', 'resulting', 'succeeding', 'interfering'],
#  ['giving', 'granting', 'paying', 'providing', 'awarding'],
#  [],
#  ['year', 'cent', 'month', 'pound', 'hour'],
#  ['reduction', 'payment', 'hike', 'raise', 'cut'],
#  ['disability', 'tax', 'retirement', 'pension', 'housing'],
#  ['saving', 'payment', 'increase', 'tax', 'revenue'],
#  ['On', 'By', 'One', 'At', 'Late'],
#  ['that', 'last', 'at', 'Friday', 'Monday'],
#  ['meant', 'said', 'indicated', 'that', 'showed'],
#  ['is', 'were', 'are', 'being', 'been'],
#  ['work', 'debate', 'discussion', 'consultation', 'speculation'],
#  ['conducted', 'made', 'undertaken', 'performed', 'taken'],
#  ['no', 'yes', 'No', 'Yes', 'majority'],
#  ['clause', 'provision', 'bill', 'ban', 'act'],
#  ['bill', 'amendment', 'repeal', 'motion', 'measure'],
#  ['passed', 'won', 'taken', 'rejected', 'cast'],
#  ['immediately', 'again', 'quickly', 'now', 'indefinitely'],
#  ['it', 'approval', 'consent', 'time', 'permission'],
#  ['be', 'also', 'later', 'then', 'eventually'],
#  ['taken', 'made', 'granted', 'passed', 'issued'],
#  ['approval', 'none', 'notice', 'part', 'some'],
#  ['measure', 'bill', 'law', 'amendment', 'referendum'],
#  ['necessary', 'required', 'possible', 'needed', 'appropriate'],
#  ['noting', 'acknowledging', 'saying', 'admitting', 'stating'],
#  ['the', 'these', 'some', 'those', 'such'],
#  ['issue', 'matter', 'problem', 'difference', 'aspect'],
#  ['never', 'being', 'now', 'already', 'more'],
#  ['being', 'well', 'yet', 'always', 'properly'],
#  ['carried', 'thought', 'figured', 'mapped', 'spelled'],
#  ['stated', 'in', 'announced', 'and', 'indicated'],
#  ['administration', 'committee', 'party', 'colleague', 'office'],
#  ['serve', 'be', 'help', 'have', 'fail'],
#  ['put', 'lay', 'cast', 'setting', 'push'],
#  ['original', 'previous', 'final', 'earlier', 'budget'],
#  ['on', 'for', 'to', 'of', 'upon'],
#  ['passed', 'approved', 'moved', 'went', 'pass'],
#  ['joint', 'Senate', 'unanimous', 'House', 'congressional'],
#  ['bill', 'measure', 'motion', 'proposal', 'amendment'],
#  ['failed', 'approved', 'won', 'defeated', 'adopted'],
#  ['Senate', 'Assembly', 'House', 'end', 'Congress'],
#  ['margin', 'majority', 'score', 'total', 'resolution'],
#  [],
#  [],
#  ['that', 'last', 'Monday', 'Wednesday', 'this'],
#  ['approached', 'now', 'though', 'arrived', 'morning'],
#  ['is', 'were', 'came', 'remained', 'seemed'],
#  ['sign', 'prospect', 'indication', 'evidence', 'chance'],
#  ['hand', 'word', 'truce', 'sign', 'settlement'],
#  ['passed', 'reached', 'brought', 'made', 'put'],
#  ['or', 'yet', 'except', 'but', 'even'],
#  ['take', 'stop', 'prevent', 'justify', 'continue'],
#  ['ban', 'order', 'agreement', 'offer', 'invitation'],
#  ['point', 'point', 'found', 'pointing', 'find'],
#  ['the', 'Virginia', 'Louisiana', 'Vermont', 'Colorado'],
#  ['the', 'and', 'his', 'The', 'it'],
#  ['in', 'per', 'every', 'each', 'of'],
#  ['year', 'week', 'month', 'night', 'time'],
#  ['approved', 'passed', 'supported', 'for', 'ratified'],
#  ['proposed', 'legislative', 'Constitutional', 'House', 'bill'],
#  ['provision', 'proposal', 'bill', 'requirement', 'convention'],
#  ['require', 'permit', 'enable', 'direct', 'force'],
#  ['voter', 'them', 'senator', 'woman', 'Democrats'],
#  ['agree', 'decide', 'focus', 'bid', 'rely'],
#  ['tax', 'salary', 'fund', 'budget', 'wage'],
#  ['increase', 'cut', 'rise', 'ceiling', 'bill'],
#  ['state', 'their', 'the', 'special', 'regular'],
#  ['legislative', 'congressional', 'special', 'Senate', 'House'],
#  ['member', 'election', 'meeting', 'seat', 'candidate'],
#  ['former', 'young', 'white', 'new', 'fellow'],
#  ['council', 'official', 'commission', 'executive', 'board'],
#  ['use', 'urge', 'support', 'call', 'lead'],
#  ['government', 'legislature', 'not', 'district', 'party'],
#  ['approve', 'end', 'increase', 'withdraw', 'provide'],
#  ['up', 'it', 'state', 'down', 'their'],
#  ['funding', 'cut', 'grant', 'fund', 'assistance'],
#  ['Arizona', 'Alaska', 'agriculture', 'Texas', 'Oklahoma'],
#  ['successfully', 'strongly', 'long', 'actively', 'vigorously'],
#  ['done', 'accomplished', 'refused', 'did', 'failed'],
#  ['legislature', 'election', 'state', 'year', 'area'],
#  ['representing', 'leading', 'in', 'with', 'represented'],
#  ['joint', 'special', 'unanimous', 'committee', 'Senate'],
#  ['suit', 'letter', 'case', 'bill', 'request'],
#  ['provide', 'seek', 'approve', 'support', 'secure'],
#  ['all', 'the', 'any', 'direct', 'full'],
#  ['state', 'public', 'congressional', 'local', 'Federal'],
#  ['funding', 'fund', 'spending', 'grant', 'dollar'],
#  ['higher', 'special', 'free', 'secondary', 'basic'],
#  ['fund', 'school', 'work', 'spending', 'funding'],
#  ['federal', 'the', 'these', 'state', 'public'],
#  ['support', 'funding', 'assistance', 'aid', 'resource'],
#  ['collected', 'used', 'distributed', 'raised', 'spent'],
#  ['used', 'distributed', 'maintained', 'spent', 'administered'],
#  ['other', 'federal', 'appropriate', 'public', 'additional'],
#  ['policy', 'requires', 'law', 'required', 'legislation'],
#  ['wa', 'lived', 'served', 'died', 'came'],
#  ['second', 'third', 'first', 'fourth', 'last'],
#  ['term', 'decade', 'century', 'month', 'district'],
#  ['Congressman', 'senator', 'Representative', 'delegate', 'Senator'],
#  ['say', 'stated', 'state', 'added', 'noted'],
#  ['were', 'remain', 'is', 'exist', 'Are'],
#  ['many', 'several', 'few', 'certain', 'two'],
#  ['friend', 'Members', 'representative', 'people', 'part'],
#  ['parliamentary', 'Congressional', 'legislative', 'House', 'state'],
#  ['committee', 'party', 'caucus', 'staff', 'team'],
#  ['Washington', 'Congress', 'office', 'Virginia', 'California'],
#  ['have', 'hear', 'get', 'consider', 'know'],
#  ['bill', 'law', 'measure', 'legislation', 'Act'],
#  ['pas', 'adopted', 'approved', 'enacted', 'read'],
#  ['noted', 'said', 'note', 'found', 'stated'],
#  ['Washington', 'Lincoln', 'Virginia', 'Iowa', 'Louisiana'],
#  ['leader', 'representative', 'member', 'minister', 'inhabitant'],
#  ['had', 'ever', 'even', 'have', 'actually'],
#  ['wanted', 'urged', 'expected', 'invited', 'requested'],
#  ['sign', 'support', 'veto', 'oppose', 'write'],
#  ['job', 'offer', 'money', 'position', 'deal'],
#  ['letter', 'paper', 'book', 'bill', 'note'],
#  ['step', 'break', 'go', 'fly', 'move'],
#  ['by', 'and', 'in', 'a', 'on'],
#  ['machine', 'box', 'room', 'bucket', 'basket'],
#  ['to', 'first', 'then', 'all', 'now'],
#  ['announced', 'called', 'accepted', 'approved', 'dated'],
#  ['out', 'aloud', 'off', 'immediately', 'later'],
#  ['argued', 'added', 'argues', 'state', 'said'],
#  ['case', 'way', 'time', 'year', 'manner'],
#  ['approve', 'allow', 'reject', 'address', 'consider'],
#  ['amount', 'money', 'reduction', 'raise', 'benefit'],
#  ['state', 'education', 'public', 'school', 'pension'],
#  ['funding', 'spending', 'revenue', 'dollar', 'aid'],
#  ['asked', 'required', 'able', 'prepared', 'told'],
#  ['assign', 'add', 'put', 'provide', 'giving'],
#  ['in', 'way', 'rise', 'preference', 'effect'],
#  ['the', 'these', 'state', 'all', 'federal'],
#  ['salary', 'pension', 'wage', 'tax', 'compensation'],
#  ['increase', 'cut', 'increase', 'rise', 'rate'],
#  ['brief', 'short', 'lengthy', 'big', 'huge'],
#  ['bitter', 'heated', 'long', 'running', 'ongoing'],
#  ['summer', 'winter', 'drought', 'year', 'spring'],
#  ['elected', 'appointed', 'hired', 'had', 'chose'],
#  ['black', 'Republican', 'special', 'local', 'single'],
#  ['county', 'police', 'district', 'town', 'chief'],
#  ['resulting', 'who', 'and', 'running', 'which'],
#  ['newspaper', 'reporter', 'journalist', 'writer', 'legend'],
#  ['call', 'in', 'before', 'for', 'to'],
#  ['worst', 'best', 'first', 'greatest', 'biggest'],
#  ['office', 'position', 'year', 'uniform', 'district'],
#  ['never', 'have', 've', 'just', 'always'],
#  ['country', 'state', 'town', 'nation', 'city'],
#  ['current', 'former', 'incumbent', 'Republican', 'elected'],
#  ['county', 'district', 'state', 'assistant', 'deputy'],
#  ['wa', 'replaced', 'succeeded', 'hired', 'faced'],
#  ['former', 'retired', 'local', 'young', 'longtime'],
#  ['school', 'history', 'English', 'former', 'state'],
#  ['worker', 'consultant', 'expert', 'administrator', 'official'],
#  ['is', 'play', 'replaced', 'replaces', 'hired'],
#  ['former', 'new', 'previous', 'retired', 'local'],
#  ['member', 'chair', 'head', 'leader', 'president'],
#  ['got', 'had', 'won', 'obtained', 'gained'],
#  ['seat', 'point', 'voter', 'ballot', 'signature'],
#  ['today', 'August', 'November', 'May'],
#  ['favor', 'favour', 'poll', 'constituency', 'district'],
#  ['delivered', 'for', 'with', 'boy'],
#  ['A', 'The', 'Two', 'His', 'Some'],
#  ['equipped', 'along', 'loaded', 'also', 'one'],
#  ['shotgun', 'sword', 'gun', 'rifle', 'knife'],
#  ['stopped', 'came', 'stop', 'passed', 'stand'],
#  ['door', 'gate', 'window', 'entrance', 'doorway'],
#  ['restore', 'maintain', 'keep', 'ensure', 'enforce'],
#  ['victory', 'peace', 'vote', 'attendance', 'progress'],
#  ['is', 's', 'be', 'Is', 'in'],
#  ['biggest', 'best', 'longest', 'first', 'largest'],
#  ['best', 'biggest', 'worst', 'largest', 'greatest'],
#  ['thing', 'man', 'place', 'day', 'person'],
#  ['never', 'just', 'have', 'really', 'yet'],
#  ['replied', 'say', 'asked', 'wrote', 'answered'],
#  ['Being', 'Sitting', 'Getting', 'Speaking', 'Running'],
#  ['church', 'hospital', 'school', 'altar', 'bar'],
#  ['is', 'feel', 'felt', 'sound', 'seems'],
#  ['almost', 'more', 'not', 'nothing', 'much'],
#  ['sitting', 'that', 'it', 'running', 'speaking'],
#  ['home', 'poll', 'it', 'war', 'odds'],
#  ['have', 'get', 'drink', 'need', 'had'],
#  ['bit', 'lot', 'thing', 'little', 'penny'],
#  ['blood', 'it', 'coffee', 'rain', 'water'],
#  ['feel', 'smell', 'see', 'hear', 'want'],
#  ['alcohol', 'it', 'beer', 'liquor', 'wine'],
#  ['night', 'day', 'week', 'period', 'weekend'],
#  ['prior', 'close', 'response', 'reaction', 'approach'],
#  ['war', 'battle', 'coup', 'assassination', 'attack'],
#  ['is', 'were', 'remained', 'proved', 'became'],
#  ['never', 'ever', 'always', 'still', 'generally'],
#  ['always', 'entirely', 'a', 'very', 'kept'],
#  ['successful', 'promising', 'positive', 'bad', 'strong'],
#  ['though', 'either', 'then', 'too', 'nevertheless'],
#  ['marred', 'accompanied', 'fueled', 'characterized', 'surrounded'],
#  ['long', 'short', 'anonymous', 'frequent', 'brief'],
#  ['including', 'with', 'involving', 'numerous', 'frequent'],
#  ['phone', 'threatening', 'anonymous', 'telephone', 'public'],
#  ['telephone', 'radio', 'conference', 'police', 'bomb'],
#  ['repeated', 'constant', 'numerous', 'anonymous', 'frequent'],
#  ['act', 'accusation', 'display', 'incident', 'allegation'],
#  ['assault', 'death', 'harassment', 'arrest', 'retaliation'],
#  ['new', 'then', 'first', 'previous', 'last'],
#  ['local', 'district', 'town', 'city', 'assistant'],
#  ['education', 'district', 'police', 'health', 'assistant'],
#  ['burned', 'sentenced', 'stabbed', 'hanged', 'poisoned'],
#  ['Death', 'on', 'the', 'health', 'a'],
#  ['at', 'May', 'June', 'October', 'August'],
#  ['two', 'three', 'five', 'six', 'seven'],
#  ['month', 'year', 'week', 'hour', 'minute'],
#  ['left', 'lost', 'quit', 'took', 'vacated'],
#  ['position', 'seat', 'office', 'job', 'position'],
#  ['confrontation', 'disagreement', 'meeting', 'conflict', 'shootout'],
#  ['local', 'city', 'state', 'district', 'town'],
#  ['education', 'health', 'fire', 'library', 'water'],
#  ['primary', 'presidential', 'same', 'electoral', 'entire'],
#  ['process', 'period', 'night', 'day', 'season'],
#  ['woman', 'MPs', 'supporter', 'men', 'activist'],
#  ['had', 'frequently', 'have', 'often', 'also'],
#  ['made', 'exchanged', 'answered', 'took', 'had'],
#  ['threatening', 'several', 'numerous', 'frequent', 'many'],
#  ['phone', 'conference', 'radio', 'close', 'Phone'],
#  ['The', 'A', 'Mr', 'John', 'the'],
#  ['claimed', 'claim', 'say', 'claim', 'and'],
#  ['himself', 'however', 'unusually', 'personally', 'herself'],
#  ['responding', 'subject', 'exposed', 'referring', 'going'],
#  ['phone', 'telephone', 'similar', 'repeated', 'close'],
#  ['harassment', 'threat', 'attack', 'criticism', 'abuse'],
#  ['shortly', 'immediately', 'long', 'right', 'just'],
#  ['won', 'lost', 'entered', 'announced', 'contested'],
#  ['meeting', 'wedding', 'interview', 'event', 'funeral'],
#  ['The', 'Many', 'Some', 'Several', 'Most'],
#  ['resident', 'voter', 'people', 'politician', 'leader'],
#  ['worried', 'believed', 'warned', 'predicted', 'felt'],
#  ['been', 'become', 'arise', 'occur', 'come'],
#  ['trouble', 'violence', 'riot', 'unrest', 'chaos'],
#  ['election', 'election', 'meeting', 'time', 'assembly'],
#  ['gave', 'granted', 'denied', 'issued', 'obtained'],
#  ['license', 'licence', 'man', 'warrant', 'revolver'],
#  ['buy', 'use', 'purchase', 'fire', 'own'],
#  ['horse', 'ballot', 'newspaper', 'candidate', 'rifle'],
#  ['call', 'hold', 'conduct', 'called', 'organize'],
#  ['early', 'open', 'immediate', 'easy', 'indirect'],
#  ['funeral', 'burial', 'government', 'return', 'response'],
#  ['on', 'in', 'of', 'at', 'for'],
#  ['man', 'boy', 'priest', 'guy', 'king'],
#  ['man', 'boy', 'person', 'priest', 'one'],
#  ['did', 'make', 'making', 'wa', 'make'],
#  ['mind', 'day', 'story', 'case', 'reputation'],
#  ['go', 'going', 'is', 'wa', 'seems'],
#  ['pretty', 'so', 'really', 'very', 'perfectly'],
#  ['fast', 'well', 'good', 'quick', 'great'],
#  ['man', 'woman', 'voice', 'doctor', 'captain'],
#  ['replied', 'say', 'added', 'remarked', 'explained'],
#  ['is', 'be', 'a', 'are', 'need'],
#  ['one', 'least', 'mean', 'no', 'the'],
#  ['time', 'it', 'that', 'money', 'one'],
#  ['The', 'His', 'Their', 'Her', 'Public'],
#  ['investigation', 'hearing', 'criticism', 'hearing', 'discussion'],
#  ['intellectual', 'private', 'real', 'stolen', 'public'],
#  ['it', 'him', 'business', 'me', 'country'],
#  ['had', 'ha', 'still', 'also', 'now'],
#  ['on', 'for', 'in', 'at', 'by'],
#  ['to', 'like', 'inevitable', 'impossible', 'appropriate'],
#  ['enough', 'even', 'today', 'and', 'not'],
#  ['strong', 'repeated', 'vigorous', 'fierce', 'vocal'],
#  ['objection', 'support', 'opposition', 'effort', 'backing'],
#  ['the', 'his', 'local', 'many', 'other'],
#  ['member', 'supporter', 'lawyer', 'advocate', 'official'],
#  ['had', 'then', 'first', 'also', 'later'],
#  ['joined', 'began', 'launched', 'won', 'started'],
#  ['campaign', 'vote', 'argument', 'way', 'debate'],
#  ['bill', 'law', 'constitution', 'amendment', 'Constitution'],
#  ['put', 'turned', 'backed', 'voted', 'scaled'],
#  ['significantly', 'on', 'ever', 'much', 'somewhat'],
#  ['passage', 'adoption', 'introduction', 'approval', 'passing'],
#  ['the', 'several', 'three', 'all', 'his'],
#  ['state', 'successive', 'different', 'separate', 'territorial'],
#  ['committee', 'opponent', 'governor', 'senator', 'house'],
#  ['special', 'heated', 'joint', 'lengthy', 'brief'],
#  ['speech', 'meeting', 'address', 'debate', 'session'],
#  ['the', 'federal', 'Senate', 'new', 'current'],
#  ['control', 'law', 'approval', 'condition', 'recommendation'],
#  ['report', 'go', 'move', 'return', 'reported'],
#  ['back', 'down', 'up', 'directly', 'on'],
#  ['meeting', 'committee', 'minimum', 'conference', 'member'],
#  ['a', 'the', 'that', 'each', 'another'],
#  ['year', 'vote', 'month', 'day', 'term'],
#  ['experience', 'that', 'ease', 'skill', 'incident'],
#  ['family', 'it', 'party', 'the', 'church'],
#  ['or', 'and', 'of', 'are', 'have'],
#  ['in', 'by', 'on', 'or', 'at'],
#  ['and', 'or', 'such', 'acted', 'appear'],
#  ['such', 'spy', 'themselves', 'well', 'politician'],
#  ['leave', 'make', 'leaf', 'have', 'give'],
#  ['no', 'some', 'me', 'the', 'much'],
#  ['evidence', 'indication', 'sign', 'hope', 'question'],
#  ['gain', 'get', 'prevent', 'seek', 'deny'],
#  ['any', 'much', 'some', 'approval', 'proof'],
#  ['wa', 'called', 'is', 'said', 'stated'],
#  ['too', 'overly', 'very', 'so', 'surprisingly'],
#  ['optimistic', 'accurate', 'ambitious', 'reasonable', 'disappointing'],
#  ['proposal', 'forecast', 'prediction', 'claim', 'view'],
#  ['cost', 'take', 'be', 'require', 'save'],
#  [],
#  ['billion', 'trillion', 'thousand', 'Million', 'hundred'],
#  ['job', 'employee', 'worker', 'people', 'pound'],
#  ['effectively', 'completely', 'fully', 'roughly', 'temporarily'],
#  ['meet', 'offset', 'fill', 'cover', 'alleviate'],
#  ['economic', 'estimated', 'budget', 'existing', 'annual'],
#  ['surplus', 'loss', 'debt', 'shortage', 'recession'],
#  ['billion', 'thousand', 'trillion', 'Million', 'hundred'],
#  ['pound', 'USD', 'job', 'annually', 'euro'],
#  ['beginning', 'start', 'close', 'conclusion', 'completion'],
#  ['next', 'proposed', 'upcoming', 'projected', 'fiscal'],
#  ['financial', 'tax', 'economic', 'budget', 'academic'],
#  ['a', 'in', 'under', 'of', 'by'],
#  ['December', 'October', 'March', 'January', 'August'],
#  ['warned', 'informed', 'assured', 'advised', 'promised'],
#  ['council', 'press', 'court', 'assembly', 'government'],
#  ['bill', 'government', 'proposal', 'law', 'legislation'],
#  ['also', 'not', 'only', 'help', 'now'],
#  ['be', 'a', 'give', 'become', 'a'],
#  ['way', 'way', 'measure', 'method', 'purpose'],
#  ['changing', 'passing', 'implementing', 'breaking', 'removing'],
#  ['constitutional', 'new', 'martial', 'electoral', 'existing'],
#  ['clause', 'system', 'policy', 'doctrine', 'treaty'],
#  ['remained', 'stayed', 'existed', 'sat', 'stood'],
#  ['Brazil', 'Venezuela', 'India', 'it', 'France'],
#  ['is', 'became', 'were', 'becomes', 'formed'],
#  ['province', 'state', 'city', 'village', 'colony'],
#  ['allows', 'allowed', 'enables', 'authorized', 'enabled'],
#  ['bank', 'government', 'police', 'court', 'authority'],
#  ['turn', 'hand', 'look', 'trace', 'sign'],
#  ['the', 'all', 'personal', 'any', 'trust'],
#  ['asset', 'property', 'paper', 'passport', 'record'],
#  ['the', 'any', 'all', 'even', 'some'],
#  ['private', 'valuable', 'legal', 'public', 'other'],
#  ['those', 'anyone', 'people', 'individual', 'the'],
#  ['detained', 'imprisoned', 'abroad', 'unemployed', 'living'],
#  ['five', 'ten', 'three', 'twenty', 'several'],
#  ['month', 'day', 'week', 'decade', 'hour'],
#  ...]

# %%
for i in range(len(ppredict)):
    try:
        ground_truth_lemma = wn.lemma_from_key(ground_truth[i])
        ground_truth_synset = ground_truth_lemma.synset()
        print(ppredict[i].definition(),'|||', ground_truth_synset.definition(), '\n')
    except:
        # ground_err +=1
        print('ground_truth 轉不過去')
# Out:
# being the one previously mentioned or spoken of ||| express in words
#
# the sixth day of the week; the fifth working day ||| the sixth day of the week; the fifth working day
#
# the work of inquiring into something thoroughly and systematically ||| an inquiry into unfamiliar or questionable activities
#
# a siege in which Federal troops under Sherman cut off the railroads supplying the city and then burned it; 1864 ||| state capital and largest city of Georgia; chief commercial center of the southeastern United States; was plundered and burned by Sherman's army during the American Civil War
#
# ground_truth 轉不過去
# of primary importance ||| a preliminary election where delegates or nominees are chosen
#
# come to have or undergo a change of (physical features and attributes) ||| bring out for display
#
# give evidence ||| your basis for belief or disbelief; knowledge on which to base belief
#
# irregular and infrequent or difficult evacuation of the bowels; can be a symptom of intestinal obstruction or diverticulitis ||| behavior that breaches the rule or etiquette or custom or morality
#
# be stricken by an illness, fall victim to an illness ||| come to pass
#
# a committee appointed to judge a competition ||| a body of citizens sworn to give a true verdict according to the evidence presented in a court of law
#
# being the one previously mentioned or spoken of ||| express in words
#
# name formally or designate with a term ||| a limited period of time
#
# put an end to ||| the point in time at which something ends
#
# a show or display; the act of presenting something to sight or view ||| an accusation of crime made by a grand jury on its own initiative
#
# have sex with; archaic use ||| have ownership or possession of
#
# saturate ||| a special assignment that is given to a person or group
#
# the predestination of some individuals as objects of divine mercy (especially as conceived by Calvinists) ||| a vote to select the winner of a position or political office
#
# be worthy or deserving ||| be worthy or deserving
#
# express approval of ||| an expression of approval and commendation
#
# express gratitude or show appreciation to ||| an acknowledgment of appreciation
#
# a kind ||| how something is done or how it happens
#
# the predestination of some individuals as objects of divine mercy (especially as conceived by Calvinists) ||| a vote to select the winner of a position or political office
#
# lead musicians in the performance of ||| direct the course of; manage or control
#
# the month following August and preceding October ||| the month following August and preceding October
#
# the month following September and preceding November ||| the month following September and preceding November
#
# name formally or designate with a term ||| a limited period of time
#
# a committee appointed to judge a competition ||| a body of citizens sworn to give a true verdict according to the evidence presented in a court of law
#
# capable of producing violent emotion or arousing controversy ||| assign a duty, responsibility or obligation to
#
# conduct an inquiry or investigation of ||| conduct an inquiry or investigation of
#
# complain about; make a charge against ||| a short account of the news
#
# existing in possibility ||| existing in possibility
#
# irregular and infrequent or difficult evacuation of the bowels; can be a symptom of intestinal obstruction or diverticulitis ||| behavior that breaches the rule or etiquette or custom or morality
#
# ground_truth 轉不過去
# of primary importance ||| a preliminary election where delegates or nominees are chosen
#
# not subject to defeat ||| be the winner in a contest or competition; be victorious
#
# as recently as ||| and nothing more
#
# properly related in size or degree or other measurable characteristics; usually followed by `to' ||| estimated by comparison; not absolute or complete
#
# the quantity that can be held in the hand ||| a small number or amount
#
# ground_truth 轉不過去
# complain about; make a charge against ||| a short account of the news
#
# widely accepted as true or worthy; ; - Economist ||| receive a specified treatment (abstract)
#
# a committee appointed to judge a competition ||| a body of citizens sworn to give a true verdict according to the evidence presented in a court of law
#
# being the one previously mentioned or spoken of ||| express in words
#
# regard or treat with consideration, respect, and esteem ||| show consideration for; take into account
#
# ground_truth 轉不過去
# be of importance or consequence ||| a sense of concern with and curiosity about someone or something
#
# the predestination of some individuals as objects of divine mercy (especially as conceived by Calvinists) ||| a vote to select the winner of a position or political office
#
# place a limit on the number of ||| a concept of quantity involving zero and units
#
# a citizen who has a legal right to vote ||| a citizen who has a legal right to vote
#
# (used in combination) sized ||| the physical magnitude of something (how big it is)
#
# people living in a large densely populated municipality ||| a large and densely populated urban area; may include several independent administrative districts
#
# a committee appointed to judge a competition ||| a body of citizens sworn to give a true verdict according to the evidence presented in a court of law
#
# being the one previously mentioned or spoken of ||| report or maintain
#
# accept and make use of one's personality, abilities, and situation ||| decide on and make a declaration about
#
# a republic in Asia Minor on the Black Sea separated from Russia by the Caucasus mountains; formerly an Asian soviet but became independent in 1991 ||| a state in southeastern United States; one of the Confederate states during the American Civil War
#
# the act of adjusting something to match a standard ||| the act of enrolling
#
# the predestination of some individuals as objects of divine mercy (especially as conceived by Calvinists) ||| a vote to select the winner of a position or political office
#
# the force of policemen and officers ||| legal document setting forth rules governing a particular kind of activity
#
# be priced at ||| have the quality of being; (copula, used with an adjective or a predicate noun)
#
# ground_truth 轉不過去
# not sufficient to meet a need ||| lacking the requisite qualities or resources to meet a task
#
# in many cases or instances ||| many times at short intervals
#
# having no intrinsic or objective meaning; not organized in conventional patterns ||| having more than one possible meaning
#
# make attractive or acceptable ||| push for something
#
# someone who makes or enacts laws ||| someone who makes or enacts laws
#
# perform on a stage or theater ||| perform an action, or work out or perform (an action)
#
# have sex with; archaic use ||| cause to move; cause to be in a certain position or condition
#
# the force of policemen and officers ||| legal document setting forth rules governing a particular kind of activity
#
# produced or marked by conscious design or premeditation; ; - V.L.Parrington ||| consider in detail and subject to an analysis in order to discover essential features or meaning
#
# altered or revised by rephrasing or by adding or deleting material ||| make revisions in
#
# put an end to ||| the state of affairs that a plan is intended to achieve and that (when achieved) terminates behavior intended to achieve it
#
# become technologically advanced ||| make repairs, renovations, revisions or adjustments to
#
# getting higher or more vigorous ||| get better
#
# used of a person's appearance or behavior; befitting an eminent person ||| a jury to inquire into accusations of crime and to evaluate the grounds for indictments
#
# provide interlinear explanations for words or phrases ||| make or write a comment on
#
# place a limit on the number of ||| the property possessed by a sum or total or indefinite quantity of units or individuals
#
# very unusual; different in character or quality from the normal or expected; - Lance Morrow ||| not the same one or ones already mentioned or implied; - the White Queen
#
# some situation or event that is thought about ||| some situation or event that is thought about
#
# a siege in which Federal troops under Sherman cut off the railroads supplying the city and then burned it; 1864 ||| state capital and largest city of Georgia; chief commercial center of the southeastern United States; was plundered and burned by Sherman's army during the American Civil War
#
# obtain by purchase; acquire by means of a financial transaction ||| the division of a business that is responsible for purchases
#
# being the one previously mentioned or spoken of ||| report or maintain
#
# be priced at ||| have the quality of being; (copula, used with an adjective or a predicate noun)
#
# without unusual distress or resentment; with good humor ||| (often used as a combining form) in a good or proper or satisfactory manner or to a high standard (`good' is a nonstandard dialectal variant for `well')
#
# perform surgery on ||| perform as expected when applied
#
# keep to ||| choose and follow; as of theories, ideas, policies, strategies or plans
#
# without regard to specific details or exceptions ||| usually; as a rule
#
# engage in or perform ||| a customary way of operation or behavior
#
# cause to accept or become hardened to; habituate ||| cause to accept or become hardened to; habituate
#
# without unusual distress or resentment; with good humor ||| (superlative of `good') having the most positive qualities
#
# be of importance or consequence ||| a reason for wanting something done
#
# the study of government of states and other political units ||| the organization that is the governing authority of a political unit
#
# in whatever way or manner ||| despite anything to the contrary (usually following a concession)
#
# a committee appointed to judge a competition ||| a body of citizens sworn to give a true verdict according to the evidence presented in a court of law
#
# being the one previously mentioned or spoken of ||| report or maintain
#
# credit with veracity ||| be confident about something
#
# ground_truth 轉不過去
# a job in an organization ||| an administrative unit of government
#
# to gain with effort ||| to gain with effort
#
# ground_truth 轉不過去
# skillfulness in avoiding wasted time and effort ||| skillfulness in avoiding wasted time and effort
#
# take off weight ||| cut down on; make a reduction in
#
# require to lose, suffer, or sacrifice ||| the total spent for goods or services including money and time and labor
#
# the act of meting out justice according to the law ||| a method of tending to or managing the affairs of a some group of people (especially the group's business affairs)
#
# a committee appointed to judge a competition ||| a body of citizens sworn to give a true verdict according to the evidence presented in a court of law
#
# being the one previously mentioned or spoken of ||| report or maintain
#
# be priced at ||| have the quality of being; (copula, used with an adjective or a predicate noun)
#
# ground_truth 轉不過去
# having experience; having knowledge or skill from observation or participation ||| having experience; having knowledge or skill from observation or participation
#
# appropriate for or engaged in office work ||| of or relating to clerks
#
# the department responsible for hiring and training and placing employees and for setting policies for personnel management ||| group of people willing to obey orders
#
# come about or follow as a consequence ||| a phenomenon that follows and is caused by some previous phenomenon
#
# people living in a large densely populated municipality ||| an incorporated administrative district established by state charter
#
# the department responsible for hiring and training and placing employees and for setting policies for personnel management ||| group of people willing to obey orders
#
# written contract or certificate of insurance ||| a plan of action adopted by an individual or social group
#
# spur on or encourage especially by cheers and shouts ||| force or impel in an indicated direction
#
# people living in a large densely populated municipality ||| an incorporated administrative district established by state charter
#
# be stricken by an illness, fall victim to an illness ||| carry out
#
# move or proceed as if by steps into a new situation ||| any maneuver made as part of progress toward a goal
#
# provide relief for ||| set straight or right
#
# a source of difficulty ||| a question raised for consideration or solution
#
# the act of implementing (providing a practical means for accomplishing something); carrying into effect ||| the act of accomplishing some aim or executing some order
#
# a republic in Asia Minor on the Black Sea separated from Russia by the Caucasus mountains; formerly an Asian soviet but became independent in 1991 ||| a state in southeastern United States; one of the Confederate states during the American Civil War
#
# travel in an automobile ||| a motor vehicle with four wheels; usually propelled by an internal combustion engine
#
# designate by an identifying term ||| a legal document signed and sealed and delivered to effect a transfer of property and to show the legal right to possess it
#
# the force of policemen and officers ||| legal document setting forth rules governing a particular kind of activity
#
# in addition ||| in addition
#
# make attractive or acceptable ||| push for something
#
# at ease in talking to others ||| leaving a place or a position
#
# a committee appointed to judge a competition ||| a body of citizens sworn to give a true verdict according to the evidence presented in a court of law
#
# spur on or encourage especially by cheers and shouts ||| force or impel in an indicated direction
#
# ground_truth 轉不過去
# persons who make or amend or repeal laws ||| persons who make or amend or repeal laws
#
# take measures in preparation for ||| give something useful or necessary to
#
# providing legal power or sanction ||| providing legal power or sanction
#
# furnish money for ||| a reserve of money set aside for some purpose
#
# ground_truth 轉不過去
# provide with a dateline; mark with a date ||| the specified day of the month
#
# the act of implementing (providing a practical means for accomplishing something); carrying into effect ||| the act of accomplishing some aim or executing some order
#
# the force of policemen and officers ||| legal document setting forth rules governing a particular kind of activity
#
# settled securely and unconditionally ||| produce
#
# used of a person's appearance or behavior; befitting an eminent person ||| a jury to inquire into accusations of crime and to evaluate the grounds for indictments
#
# show and train ||| manual (or mechanical) carrying or moving or delivering or working with something
#
# ground_truth 轉不過去
# furnish money for ||| a reserve of money set aside for some purpose
#
# ground_truth 轉不過去
# a member of a clan or tribe ||| an administrative unit responsible for social work concerned with the welfare and vocational training of children
#
# providing or receiving nurture or parental care though not related by blood or legal ties ||| a household in which an orphaned or delinquent child is placed (usually by a social-service agency)
#
# be priced at ||| be identical to; be someone or something
#
# ground_truth 轉不過去
# of the elder of two boys with the same family name ||| of greater importance or stature or rank
#
# an individual instance of a type of symbol ||| an isolated fact that is considered separately from the whole
#
# of worldwide scope or applicability; ; - Christopher Morley ||| applying to all or most members of a category or group
#
# a resource ||| the activity of contributing to the fulfillment of a need or furtherance of an effort or purpose
#
# write a computer program ||| a series of steps to be carried out or goals to be accomplished
#
# a committee appointed to judge a competition ||| a body of citizens sworn to give a true verdict according to the evidence presented in a court of law
#
# being the one previously mentioned or spoken of ||| report or maintain
#
# to arrange in a systematic order ||| administer or bestow, as in small portions
#
# furnish money for ||| a reserve of money set aside for some purpose
#
# a contented state of being happy and healthy and prosperous ||| governmental provision of economic assistance to persons in need
#
# a specialized sphere of knowledge ||| a specialized division of a large organization
#
# to a complete degree or to the full or entire extent (`whole' is often used informally for `wholly') ||| quantifier; used with either mass or count nouns to indicate the whole number or amount of or every one of a class
#
# (United States) the largest administrative district within a state ||| (United Kingdom) a region created by territorial division for the purpose of local government
#
# indicate through a symbol, formula, etc. ||| the territory occupied by one of the constituent administrative districts of a nation
#
# grounds for adverse criticism ||| a deliberate act of omission
#
# regard favorably or with disapproval ||| get something; come into possession of
#
# the official currency issued by a government or national bank ||| the most common medium of exchange; functions as legal tender
#
# someone who serves (or waits to be called to serve) on a jury ||| someone who serves (or waits to be called to serve) on a jury
#
# being the one previously mentioned or spoken of ||| express in words
#
# expand or complete (a part in a piece of baroque music) by supplying the harmonies indicated in the figured bass ||| be fully aware or cognizant of
#
# ground_truth 轉不過去
# the commercial activity of transporting and selling goods from a producer to a consumer ||| the spatial or geographic property of being scattered about over a range, area, or volume
#
# furnish money for ||| a reserve of money set aside for some purpose
#
# injure permanently ||| make unable to perform a certain action
#
# write a computer program ||| a series of steps to be carried out or goals to be accomplished
#
# comparative of little ||| (comparative of `little' usually used with mass nouns) a quantifier meaning not as great in amount or degree
#
# ground_truth 轉不過去
# (United States) the largest administrative district within a state ||| (United Kingdom) a region created by territorial division for the purpose of local government
#
# despite anything to the contrary (usually following a concession) ||| despite anything to the contrary (usually following a concession)
#
# pass one's hands over the sexual organs of ||| come to believe on the basis of emotion, intuitions, or indefinite grounds
#
# regard favorably or with disapproval ||| get something; come into possession of
#
# (of quantities) imprecise but fairly close to correct ||| quantifier; used with either mass nouns or plural count nouns to indicate an unspecified number or quantity
#
# give out ||| the allotment of some amount by dividing something
#
# convenient for use or disposal ||| obtainable or accessible and ready for use or service
#
# furnish money for ||| a reserve of money set aside for some purpose
#
# someone who serves (or waits to be called to serve) on a jury ||| someone who serves (or waits to be called to serve) on a jury
#
# being the one previously mentioned or spoken of ||| report or maintain
#
# loss of ability to function normally ||| an act that fails
#
# travel or traverse (a distance) ||| engage in
#
# exist over a prolonged period of time ||| continue a certain state, condition, or activity
#
# sing a note with the correct pitch ||| put into a certain place or abstract location
#
# not proportionate ||| out of proportion
#
# impose a task upon, assign a responsibility to ||| an onerous or difficult concern
#
# someone who pays taxes ||| someone who pays taxes
#
# a committee appointed to judge a competition ||| a body of citizens sworn to give a true verdict according to the evidence presented in a court of law
#
# in addition ||| in addition
#
# provide interlinear explanations for words or phrases ||| make or write a comment on
#
# lacking special distinction, rank, or status; commonly encountered ||| the expected or commonplace condition or situation
#
# engage in social activities leading to marriage ||| an assembly (including one or more judges) to conduct judicial business
#
# ground_truth 轉不過去
# engage in or perform ||| a customary way of operation or behavior
#
# (law) the act of disposing of property by virtue of the power of appointment ||| the act of putting a person into a non-elective position
#
# one who determines authenticity (as of works of art) or who guarantees validity ||| one who estimates officially the worth or value or quality of things
#
# a person who cares for persons or property ||| a person who cares for persons or property
#
# someone who manages a government agency or department ||| someone who administers a business
#
# give as judged due or on the basis of merit ||| a grant made by a law court
#
# give a tip or gratuity to in return for a service, beyond the compensation agreed on ||| a fixed charge for a privilege or for professional services
#
# the act of compensating for service or loss or injury ||| something (such as money) given or received as payment or reparation (as for a service or loss or injury)
#
# a committee appointed to judge a competition ||| a body of citizens sworn to give a true verdict according to the evidence presented in a court of law
#
# being the one previously mentioned or spoken of ||| report or maintain
#
# come upon unexpectedly or after searching ||| establish after a calculation, investigation, experiment, survey, or study
#
# engage in social activities leading to marriage ||| an assembly (including one or more judges) to conduct judicial business
#
# introduced into as a part of the whole ||| make into a whole or make part of a whole
#
# being in effect or operation; - Leslie Marmon Silko ||| a procedure for operating something or for dealing with a given situation
#
# any quality or characteristic that gains a person a favorable reception or acceptance or admission ||| something (as a course of action) that is recommended as advisable
#
# ground_truth 轉不過去
# ground_truth 轉不過去
# used of a person's appearance or behavior; befitting an eminent person ||| a jury to inquire into accusations of crime and to evaluate the grounds for indictments
#
# ground_truth 轉不過去
# a native or naturalized member of a state or other political community ||| a self-constituted organization to promote something
#
# put in effect ||| something done (usually as opposed to something said)
#
# put the ball into play ||| contribute or conduce to
#
# use tariffs to favor domestic industry ||| shield from danger, injury, destruction, or damage
#
# to or toward the inside of ||| in reality or actuality
#
# to or toward the inside of ||| in actuality or reality or fact
#
# engage in social activities leading to marriage ||| an assembly (including one or more judges) to conduct judicial business
#
# watch over or shield from danger or harm; protect ||| a person who is under the protection or in the custody of another
#
# beyond normal limits ||| not yet payable
#
# require to lose, suffer, or sacrifice ||| the total spent for goods or services including money and time and labor
#
# provided with furnishing and accessories (especially of a tasteful kind) ||| subject to appointment
#
# subject to popular election ||| subject to popular election
#
# in a subordinate position ||| a person working in the service of another (especially in the household)
#
# ground_truth 轉不過去
# a written evaluation of a work of literature ||| disapproval expressed by pointing out faults or shortcomings
#
# a committee appointed to judge a competition ||| a body of citizens sworn to give a true verdict according to the evidence presented in a court of law
#
# being the one previously mentioned or spoken of ||| report or maintain
#
# connect closely and often incriminatingly ||| connect closely and often incriminatingly
#
# a siege in which Federal troops under Sherman cut off the railroads supplying the city and then burned it; 1864 ||| state capital and largest city of Georgia; chief commercial center of the southeastern United States; was plundered and burned by Sherman's army during the American Civil War
#
# very recently ||| not of long duration; having just (or relatively recently) come into being or been made or acquired or discovered
#
# ground_truth 轉不過去
# a symbol of commercialism or greed ||| the basic monetary unit in many countries; equal to 100 cents
#
# an airfield equipped with control tower and hangars as well as accommodations for passengers and cargo ||| an airfield equipped with control tower and hangars as well as accommodations for passengers and cargo
#
# a committee appointed to judge a competition ||| a body of citizens sworn to give a true verdict according to the evidence presented in a court of law
#
# make attractive or acceptable ||| push for something
#
# very recently ||| not of long duration; having just (or relatively recently) come into being or been made or acquired or discovered
#
# those in charge of running a business ||| those in charge of running a business
#
# be stricken by an illness, fall victim to an illness ||| assume control
#
# ground_truth 轉不過去
# an airfield equipped with control tower and hangars as well as accommodations for passengers and cargo ||| an airfield equipped with control tower and hangars as well as accommodations for passengers and cargo
#
# perform surgery on ||| direct or control; projects, businesses, etc.
#
# a kind ||| how something is done or how it happens
#
# remove (an unknown variable) from two or more equations ||| terminate, end, or take out
#
# of or relating to the profession of governing ||| involving or characteristic of politics or parties or politicians; - Daniel Goleman
#
# induce into action by using one's charm ||| a power to affect persons or events especially power based on prestige etc
#
# a committee appointed to judge a competition ||| a body of citizens sworn to give a true verdict according to the evidence presented in a court of law
#
# negation of a word or group of words ||| negation of a word or group of words
#
# developed or executed with care and in minute detail; ; - John Buchan ||| add details, as to an account or idea; clarify the meaning of and discourse in a learned way, usually in writing
#
# constitute an addition ||| state or say further
#
# be priced at ||| have the quality of being; (copula, used with an adjective or a predicate noun)
#
# recurring or reappearing from time to time ||| happening or recurring at regular intervals
#
# close observation of a person or group (usually by the police) ||| close observation of a person or group (usually by the police)
#
# ascertain or learn the price of ||| the evaluation of something in terms of its price
#
# engage in or perform ||| a customary way of operation or behavior
#
# someone who holds or operates a concession ||| someone who holds or operates a concession
#
# reach a decision ||| an anticipated outcome that is intended or that guides your planned actions
#
# prevent (food) from rotting ||| keep in a certain state, position, or activity; e.g.,
#
# ascertain or learn the price of ||| the amount of money needed to purchase something
#
# ground_truth 轉不過去
# very unusual; different in character or quality from the normal or expected; - Lance Morrow ||| not the same one or ones already mentioned or implied; - the White Queen
#
# have weight; have import, carry weight ||| some situation or event that is thought about
#
# a committee appointed to judge a competition ||| a body of citizens sworn to give a true verdict according to the evidence presented in a court of law
#
# make attractive or acceptable ||| push for something
#
# ground_truth 轉不過去
# ground_truth 轉不過去
# a person appointed to represent or act on behalf of others ||| an assistant with power to act when his superior is absent
#
# put to use ||| engage or hire for work
#
# restore by replacing a part or putting together what is torn or broken ||| a licensed medical practitioner
#
# of or belonging to Aesculapius or the healing art ||| an advanced student or graduate in medicine gaining supervised practical experience (`houseman' is a British term)
#
# a nonresident doctor or medical student; connected with a hospital but not living there ||| a nonresident doctor or medical student; connected with a hospital but not living there
#
# put to use ||| engage or hire for work
#
# Roman goddess of night; daughter of Erebus; counterpart of Greek Nyx ||| the time after sunset and before sunrise while it is dark outside
#
# spend the weekend ||| a time period usually extending from Friday night through Sunday; more loosely defined as any period of successive days including one and only one Sunday
#
# a government tax on imports or exports ||| work that you are obliged to perform for moral or legal reasons
#
# lock up or confine, in or as in a jail ||| a correctional institution used to detain persons who are in the lawful custody of the government (either accused persons awaiting trial or convicted persons serving a sentence)
#
# someone who makes or enacts laws ||| someone who makes or enacts laws
#
# arrive at a certain condition through repeated motion ||| exert oneself by doing mental or physical work for a purpose or out of necessity
#
# people living in a large densely populated municipality ||| an incorporated administrative district established by state charter
#
# someone who administers the rules of a game or sport ||| a worker who holds or is invested with an office
#
# of advancing the ball by throwing it ||| make laws, bills, etc. or bring into effect by legislation
#
# providing legal power or sanction ||| legislation that gives appropriate officials the authority to implement or enforce the law
#
# allow the presence of or allow (an activity) without opposing or prohibiting ||| consent to, give permission
#
# the cognitive process of establishing a valid proof ||| the act of forming or establishing something
#
# fair to all parties as dictated by reason and conscience ||| fair to all parties as dictated by reason and conscience
#
# grant a pension to ||| a regular payment to a person that is intended to allow them to subsist without working
#
# make a design of; plan out in systematic, often graphic form ||| a series of steps to be carried out or goals to be accomplished
#
# people living in a large densely populated municipality ||| an incorporated administrative district established by state charter
#
# a committee appointed to judge a competition ||| a body of citizens sworn to give a true verdict according to the evidence presented in a court of law
#
# express approval of ||| express approval of
#
# the act of meting out justice according to the law ||| a method of tending to or managing the affairs of a some group of people (especially the group's business affairs)
#
# the activity of operating something (a machine or business etc.) ||| the state of being in effect or being operative
#
# a siege in which Federal troops under Sherman cut off the railroads supplying the city and then burned it; 1864 ||| state capital and largest city of Georgia; chief commercial center of the southeastern United States; was plundered and burned by Sherman's army during the American Civil War
#
# maintain the security of by carrying out a patrol ||| the department of local government concerned with enforcing the law and preventing crime
#
# a prisonlike situation; a place of seeming confinement ||| a camp for trustworthy prisoners employed in government projects
#
# place in a container for keeping records ||| record in a public office or in a court of law
#
# enhance the appearance of ||| a comprehensive term for any proceeding in a court of law whereby an individual seeks a legal remedy
#
# get a divorce; formally terminate a marriage ||| the legal dissolution of a marriage
#
# a married woman; a man's partner in marriage ||| a married woman; a man's partner in marriage
#
# the sixth day of the week; the fifth working day ||| the sixth day of the week; the fifth working day
#
# write a petition for something to somebody; request formally and in writing ||| a formal message requesting something that is submitted to an authority
#
# capable of producing violent emotion or arousing controversy ||| file a formal charge against
#
# affected by a disorder of the mind ||| of or relating to the mind
#
# the quality of being cruel and causing tension or annoyance ||| feelings of extreme heartlessness
#
# engage in sexual intercourse ||| a pair of people who live together
#
# of or relating to the state of marriage ||| take in marriage
#
# ground_truth 轉不過去
# have sex with; archaic use ||| have or possess, either in a concrete or an abstract sense
#
# the divine word of God; the second person in the Trinity (incarnate in Jesus) ||| a male human offspring
#
# a female human offspring ||| a female human offspring
#
# a professional person authorized to practice law; conducts lawsuits or gives legal advice ||| a professional person authorized to practice law; conducts lawsuits or gives legal advice
#
# the head of a city government ||| the head of a city government
#
# being the one previously mentioned or spoken of ||| report or maintain
#
# characterized by friendship and good will ||| characterized by friendship and good will
#
# any movable articles or objects used on the set of a play or movie ||| (matrimonial law) the division of property owned or acquired by marriage partners during their marriage
#
# ground_truth 轉不過去
# write a petition for something to somebody; request formally and in writing ||| a formal message requesting something that is submitted to an authority
#
# on a list ||| give or make a list of; name individually; give the names of
#
# the head of a city government ||| the head of a city government
#
# the period of time during which a place or position or nation is occupied ||| the principal activity in your life that you do to earn money
#
# a professional person authorized to practice law; conducts lawsuits or gives legal advice ||| a professional person authorized to practice law; conducts lawsuits or gives legal advice
#
# make older ||| how long something has existed
#
# on a list ||| give or make a list of; name individually; give the names of
#
# a married woman; a man's partner in marriage ||| a married woman; a man's partner in marriage
#
# make older ||| how long something has existed
#
# sing a note with the correct pitch ||| the place where someone was born
#
# write a petition for something to somebody; request formally and in writing ||| a formal message requesting something that is submitted to an authority
#
# being the one previously mentioned or spoken of ||| report or maintain
#
# engage in sexual intercourse ||| a pair of people who live together
#
# negation of a word or group of words ||| negation of a word or group of words
#
# pursue a positive and satisfying existence ||| inhabit or live in; be an inhabitant of
#
# with a common plan ||| in each other's company
#
# provide with workers ||| two people who are married to each other
#
# comparative of much; to a greater degree or extent ||| comparative of much; to a greater degree or extent
#
# a body of students who graduate together ||| a period of time containing 365 (or 366) days
#
# to the fullest extent; to the heart ||| housing that someone is living in
#
# be priced at ||| occupy a certain position or area; be somewhere
#
# on a list ||| give or make a list of; name individually; give the names of
#
# write a petition for something to somebody; request formally and in writing ||| a formal message requesting something that is submitted to an authority
#
# the head of a city government ||| the head of a city government
#
# a professional person authorized to practice law; conducts lawsuits or gives legal advice ||| a professional person authorized to practice law; conducts lawsuits or gives legal advice
#
# be priced at ||| work in a specific place, with a specific subject, or in a specific function
#
# the head of a city government ||| the head of a city government
#
# a siege in which Federal troops under Sherman cut off the railroads supplying the city and then burned it; 1864 ||| state capital and largest city of Georgia; chief commercial center of the southeastern United States; was plundered and burned by Sherman's army during the American Civil War
#
# grounds for adverse criticism ||| a deliberate act of omission
#
# ground_truth 轉不過去
# ground_truth 轉不過去
# perform an interlude ||| an intervening period or episode
#
# of or relating to the profession of governing ||| of or relating to the profession of governing
#
# move headlong at high speed ||| the particular occupation for which you are trained
#
# stop operating or functioning ||| belong to an earlier time
#
# the predestination of some individuals as objects of divine mercy (especially as conceived by Calvinists) ||| a vote to select the winner of a position or political office
#
# people living in a large densely populated municipality ||| a municipal body that can pass ordinances and appropriate funds etc.
#
# the head of a city government ||| the head of a city government
#
# being or existing in a specified place ||| temporal sense; intermediate between past and future; now existing or happening or in consideration
#
# name formally or designate with a term ||| the term during which some position is held
#
# expel air ||| lose validity
#
# ground_truth 轉不過去
# be the successor (of) ||| be the successor (of)
#
# enhance the appearance of ||| undergo a change or development
#
# someone who is considered for something (for an office or prize or honor etc.) ||| a politician who is running for public office
#
# ground_truth 轉不過去
# of primary importance ||| a preliminary election where delegates or nominees are chosen
#
# declared publicly; made widely known ||| make known; make an announcement
#
# negation of a word or group of words ||| negation of a word or group of words
#
# become undone ||| run, stand, or compete for an office or a position
#
# election again ||| election again
#
# a republic in Asia Minor on the Black Sea separated from Russia by the Caucasus mountains; formerly an Asian soviet but became independent in 1991 ||| a state in southeastern United States; one of the Confederate states during the American Civil War
#
# a tributary of the Kansas River that flows from eastern Colorado eastward through Nebraska and Kansas ||| a member of the Republican Party
#
# make children ||| receive a specified treatment (abstract)
#
# ground_truth 轉不過去
# the feeling of being encouraged ||| the act of giving hope or support to someone
#
# set out on (an enterprise or subject of study) ||| register formally as a participant or member
#
# someone who is considered for something (for an office or prize or honor etc.) ||| a politician who is running for public office
#
# a control that maintains a steady speed in a machine (as by controlling the supply of fuel) ||| a race for election to the governorship
#
# (of a church) given official status as a national or state institution ||| a worker who holds or is invested with an office
#
# being the one previously mentioned or spoken of ||| express in words
#
# the fourth day of the week; the third working day ||| the fourth day of the week; the third working day
#
# indicate through a symbol, formula, etc. ||| the group of people comprising the government of a sovereign state
#
# the younger of two major political parties in the United States; GOP is an acronym for grand old party ||| the younger of two major political parties in the United States; GOP is an acronym for grand old party
#
# act or preside as chair, as of an academic department in a university ||| the officer who presides at the meetings of an organization
#
# being the one previously mentioned or spoken of ||| express in words
#
# be in direct physical contact with; make contact ||| a formally arranged gathering
#
# occupied or in the control of; often used in combination ||| organize or be responsible for
#
# the third day of the week; the second working day ||| the third day of the week; the second working day
#
# Roman goddess of night; daughter of Erebus; counterpart of Greek Nyx ||| the time after sunset and before sunrise while it is dark outside
#
# induce or persuade ||| cause to happen or to occur as a consequence
#
# having or showing great excitement and interest ||| having or showing great excitement and interest
#
# the manner in which an electrical or mechanical device responds to an input signal or a range of input signals ||| the manner in which something is greeted
#
# a conference (usually with someone important) ||| a gathering of spectators or listeners at a (usually public) performance
#
# constitute an addition ||| state or say further
#
# a lively interest ||| a lively interest
#
# eat intermittently; take small bites of ||| improve significantly; go from bad to good
#
# indicate through a symbol, formula, etc. ||| the territory occupied by one of the constituent administrative districts of a nation
#
# harass with persistent criticism or carping ||| a large gathering of people intended to arouse enthusiasm
#
# occupied or in the control of; often used in combination ||| organize or be responsible for
#
# ground_truth 轉不過去
# a flat grassland in tropical or subtropical regions ||| a port in eastern Georgia near the mouth of the Savannah river
#
# very recently ||| very recently
#
# subject to popular election ||| subject to popular election
#
# the second largest state; located in southwestern United States on the Gulf of Mexico ||| the second largest state; located in southwestern United States on the Gulf of Mexico
#
# be priced at ||| be identical to; be someone or something
#
# ground_truth 轉不過去
# the presiding officer of a deliberative assembly ||| someone who expresses in language; someone who talks (especially someone who delivers a public speech or someone especially garrulous)
#
# be in direct physical contact with; make contact ||| a formally arranged gathering
#
# a conference (usually with someone important) ||| a gathering of spectators or listeners at a (usually public) performance
#
# notify, usually in advance ||| notify of danger, potential harm, or risk
#
# set out on (an enterprise or subject of study) ||| register formally as a participant or member
#
# someone who is considered for something (for an office or prize or honor etc.) ||| a politician who is running for public office
#
# a control that maintains a steady speed in a machine (as by controlling the supply of fuel) ||| the head of a state government
#
# take by force ||| to cause to do through pressure or necessity, by physical, moral or intellectual means :
#
# be stricken by an illness, fall victim to an illness ||| take something or somebody with oneself somewhere
#
# write a petition for something to somebody; request formally and in writing ||| a formal message requesting something that is submitted to an authority
#
# from one's possession ||| moving or appearing to move away from a place, especially one that is enclosed or hidden
#
# bring into existence or make available by vote ||| one of several districts into which a city or town is divided for voting; each contains one polling place
#
# be valid, applicable, or true ||| come into possession of
#
# a sheet with several pages printed on it; it folds to page size and is bound with other signatures to form a book ||| your name written in your own handwriting
#
# (of a boat or vessel) furnished with necessary official documents specifying ownership etc ||| enroll to vote
#
# a citizen who has a legal right to vote ||| a citizen who has a legal right to vote
#
# serving to warn ||| cautionary advice about something imminent (especially imminent danger or other unpleasantness)
#
# be priced at ||| happen, occur, take place
#
# ground_truth 轉不過去
# bring into existence or make available by vote ||| a choice that is made by counting the number of people in favor of each alternative
#
# set out on (an enterprise or subject of study) ||| register formally as a participant or member
#
# someone who is considered for something (for an office or prize or honor etc.) ||| a politician who is running for public office
#
# a tributary of the Kansas River that flows from eastern Colorado eastward through Nebraska and Kansas ||| a member of the Republican Party
#
# having a caretaker or other watcher ||| be present at (meetings, church services, university), etc.
#
# approach a certain age or speed ||| a large number of things or people considered together
#
# require or ask for as a price or condition ||| inquire about
#
# characterized by feeling or showing fond affection for ||| feel or have a desire for; want strongly
#
# serve as a waiter or waitress in a restaurant ||| wait before acting
#
# ground_truth 轉不過去
# name formally or designate with a term ||| a limited period of time
#
# eliminate urine ||| give rise to; cause to happen or occur, not always intentionally
#
# cause to move fast or to rush or race ||| any competition
#
# bring into existence or make available by vote ||| express a choice or opinion
#
# used to express refusal or denial or disagreement etc or especially to emphasize a negative statement ||| referring to the degree to which a certain quality is present
#
# be priced at ||| happen, occur, take place
#
# be of different opinions ||| a difference of opinion
#
# jump a hurdle ||| a light movable barrier that competitors must leap over in certain races
#
# a tributary of the Kansas River that flows from eastern Colorado eastward through Nebraska and Kansas ||| a member of the Republican Party
#
# cover the front or surface of ||| oppose, as in hostility or a competition
#
# be priced at ||| be identical to; be someone or something
#
# indicate through a symbol, formula, etc. ||| a politically organized body of people under a single government
#
# the force of policemen and officers ||| legal document setting forth rules governing a particular kind of activity
#
# indicate ||| report or maintain
#
# eliminate urine ||| engage in
#
# prominently forward ||| preceding all others in time or space or degree
#
# cause to move fast or to rush or race ||| any competition
#
# ground_truth 轉不過去
# ground_truth 轉不過去
# ground_truth 轉不過去
# hunt with hounds ||| general line of orientation
#
# be affected with an indisposition ||| make use of or accept for some purpose
#
# ground_truth 轉不過去
# ground_truth 轉不過去
# a citizen who has a legal right to vote ||| a citizen who has a legal right to vote
#
# ground_truth 轉不過去
# (United States) the largest administrative district within a state ||| (United Kingdom) a region created by territorial division for the purpose of local government
#
# used of the language of the deaf ||| be engaged by a written agreement
#
# write a petition for something to somebody; request formally and in writing ||| a formal message requesting something that is submitted to an authority
#
# inquire for (information) ||| ask (a person) to do something
#
# a tributary of the Kansas River that flows from eastern Colorado eastward through Nebraska and Kansas ||| a member of the Republican Party
#
# allow the presence of or allow (an activity) without opposing or prohibiting ||| make it possible through a specific action or lack of action for something to happen
#
# sing a note with the correct pitch ||| put into a certain place or abstract location
#
# determine or distinguish the nature of a problem or an illness through a diagnostic analysis ||| a language unit by which a person or thing is known
#
# someone who is considered for something (for an office or prize or honor etc.) ||| a politician who is running for public office
#
# of worldwide scope or applicability; ; - Christopher Morley ||| a national or state election; candidates are chosen in all constituencies
#
# vote by ballot ||| a choice that is made by counting the number of people in favor of each alternative
#
# a tributary of the Kansas River that flows from eastern Colorado eastward through Nebraska and Kansas ||| a member of the Republican Party
#
# keep from exhaling or expelling ||| organize or be responsible for
#
# of primary importance ||| a preliminary election where delegates or nominees are chosen
#
# ...
#
# not known or lacking marked individuality ||| having no known name or identity or known source
#
# rouse somebody from sleep with a call ||| a telephone connection
#
# in the near future ||| in the near future
#
# planned or scheduled for some certain time or times ||| plan for an activity or event
#
# the predestination of some individuals as objects of divine mercy (especially as conceived by Calvinists) ||| a vote to select the winner of a position or political office
#
# a quantifier that can be used with count nouns and is often preceded by `as' or `too' or `so' or `that'; amounting to a large but indefinite number ||| a quantifier that can be used with count nouns and is often preceded by `as' or `too' or `so' or `that'; amounting to a large but indefinite number
#
# a native or naturalized member of a state or other political community ||| a native or naturalized member of a state or other political community
#
# regard with feelings of respect and reverence; consider hallowed or exalted or be in awe of ||| be afraid or feel anxious or apprehensive about a possible or probable situation or event
#
# be priced at ||| be identical to; be someone or something
#
# irregular and infrequent or difficult evacuation of the bowels; can be a symptom of intestinal obstruction or diverticulitis ||| behavior that breaches the rule or etiquette or custom or morality
#
# convert into a pollard ||| the place where people vote
#
# make children ||| come into the possession of something concrete or abstract
#
# allow the presence of or allow (an activity) without opposing or prohibiting ||| a legal document giving official permission to do something
#
# be pregnant with ||| have with oneself; have on one's person
#
# shoot with a gun ||| a weapon that discharges a missile at high velocity (especially from a metal tube or barrel)
#
# give grounds for expectations ||| promise to undertake or give
#
# clean or organized ||| devoid of violence or disruption
#
# the predestination of some individuals as objects of divine mercy (especially as conceived by Calvinists) ||| a vote to select the winner of a position or political office
#
# being the one previously mentioned or spoken of ||| express in words
#
# lacking special distinction, rank, or status; commonly encountered ||| a judge of a probate court
#
# unmistakably (`plain' is often used informally for `plainly') ||| from appearances alone; ; ; -Thomas Hardy
#
# successful or assured of success; - Christopher Marlowe ||| act as promised
#
# give grounds for expectations ||| a verbal commitment by one person to another agreeing to do (or not to do) something in the future
#
# stop operating or functioning ||| follow a certain course
#
# used as intensifiers; `real' is sometimes used informally for `really'; `rattling' is informal ||| used as intensifiers; `real' is sometimes used informally for `really'; `rattling' is informal
#
# (of a body of water) free from disturbance by heavy waves ||| having a surface free from roughness or bumps or ridges or irregularities
#
# the principal law-enforcement officer in a county ||| the principal law-enforcement officer in a county
#
# being the one previously mentioned or spoken of ||| express in words
#
# be priced at ||| be identical to; be someone or something
#
# the blood group whose red cells carry the A antigen ||| to a small degree; somewhat
#
# cause bodily suffering to and make sick or indisposed ||| an angry disturbance
#
# a self-constituted organization to promote something ||| a special group delegated to consider some matter;  - Milton Berle
#
# a message expressing a favorable opinion ||| the formal act of approving
#
# ground_truth 轉不過去
# any movable articles or objects used on the set of a play or movie ||| something owned; any tangible or intangible possession that is owned by someone
#
# perform on a stage or theater ||| a legal document codifying the result of deliberations of a committee or society or legislative body
#
# appear to one's own mind or opinion ||| give a certain impression or have a certain outward aspect
#
# exercising or taking care great enough to bring assurance ||| certain to occur; destined or inevitable; ; ; - Benjamin Franklin
#
# the fifth day of the week; the fourth working day ||| the fifth day of the week; the fourth working day
#
# ground_truth 轉不過去
# affirm or avow formally or solemnly ||| a formal and solemn declaration of objection
#
# the second largest state; located in southwestern United States on the Gulf of Mexico ||| the second largest state; located in southwestern United States on the Gulf of Mexico
#
# the person in charge of the bank in a gambling game ||| a financier who owns or is an executive in a bank
#
# concerning the speaker ||| as yourself
#
# preside over ||| be in charge of
#
# exert oneself continuously, vigorously, or obtrusively to gain an end or engage in a crusade for a certain cause or person; be an advocate for ||| the act of fighting; any contest or struggle
#
# evaluate or estimate the nature, quality, ability, extent, or significance of ||| a statute in draft before it becomes law
#
# (of silk fabric) having a wavelike pattern ||| make less strong or intense
#
# to a great extent or degree ||| to a great extent or degree
#
# the speech act of rejecting ||| the act of rejecting something
#
# ground_truth 轉不過去
# ground_truth 轉不過去
# persons who make or amend or repeal laws ||| persons who make or amend or repeal laws
#
# affecting the people or community as a whole ||| not private; open to or concerning the people as a whole
#
# able to perceive sound ||| (law) a proceeding (usually by a court) where evidence is taken for the purpose of determining an issue of fact and reaching a decision based on that evidence
#
# a self-constituted organization to promote something ||| a special group delegated to consider some matter;  - Milton Berle
#
# keep in check ||| prescribed guide for conduct or action
#
# stop operating or functioning ||| follow a procedure or take a course
#
# in a mechanical manner; by a mechanism ||| in a reflex manner
#
# a subset of committee members organized for a specific purpose ||| a subset of committee members organized for a specific purpose
#
# ground_truth 轉不過去
# a period of seven consecutive days starting on Sunday ||| any period of seven consecutive days
#
# place in doubt or express doubtful speculation ||| an instance of questioning
#
# a self-constituted organization to promote something ||| a member of a committee
#
# harass with persistent criticism or carping ||| harass with persistent criticism or carping
#
# the person in charge of the bank in a gambling game ||| a financier who owns or is an executive in a bank
#
# present oneself formally, as before a (judicial) authority ||| come into sight or view
#
# perceive or be contemporaneous with ||| someone who sees an event and reports what happened
#
# toward or on the left; also used figuratively ||| make a possibility or provide opportunity for; permit to be attainable or cause to remain
#
# not much ||| (quantifier used with mass nouns) small in quantity or degree; not much or almost none or (with `a') at least some
#
# lack confidence in or have doubts about ||| the state of being unsure of something
#
# make attractive or acceptable ||| push for something
#
# the act of passing something to another person ||| the passing of a law by a legislative body
#
# name formally or designate with a term ||| name formally or designate with a term
#
# to an extreme degree ||| to an extreme degree
#
# conforming to the standards and conventions of the middle class ||| resistant to change
#
# judge to be probable ||| an approximate calculation of quantity or degree or worth
#
# come to have or undergo a change of (physical features and attributes) ||| bring forth or yield
#
# ground_truth 轉不過去
# (in Roman numerals, M written with a macron over it) denoting a quantity consisting of 1,000,000 items or units ||| the number that is represented as a one followed by 6 zeros
#
# a symbol of commercialism or greed ||| the basic monetary unit in many countries; equal to 100 cents
#
# improve; change for the better ||| give help or assistance; be of service
#
# wipe out digitally or magnetically recorded information ||| remove from memory or existence
#
# ground_truth 轉不過去
# an excess of liabilities over assets (usually over a certain period) ||| the property of being an amount by which something is less than expected or required
#
# (in Roman numerals, M written with a macron over it) denoting a quantity consisting of 1,000,000 items or units ||| the number that is represented as a one followed by 6 zeros
#
# a symbol of commercialism or greed ||| the basic monetary unit in many countries; equal to 100 cents
#
# put an end to ||| the point in time at which something ends
#
# occurring in or belonging to the present time ||| occurring in or belonging to the present time
#
# involving financial matters ||| any accounting period of 12 months
#
# ground_truth 轉不過去
# ground_truth 轉不過去
# mark as different ||| express in words
#
# a self-constituted organization to promote something ||| a special group delegated to consider some matter;  - Milton Berle
#
# evaluate or estimate the nature, quality, ability, extent, or significance of ||| a statute in draft before it becomes law
#
# and nothing more ||| and nothing more
#
# take measures in preparation for ||| give something useful or necessary to
#
# destine or designate for a certain purpose ||| how a result is obtained or an end is achieved
#
# compel to behave in a certain way ||| ensure observance of laws and rules
#
# the property that reverts to the state ||| a reversion to the state (as the ultimate owner of property) in the absence of legal heirs
#
# the force of policemen and officers ||| legal document setting forth rules governing a particular kind of activity
#
# be priced at ||| occupy a certain position or area; be somewhere
#
# the second largest state; located in southwestern United States on the Gulf of Mexico ||| the second largest state; located in southwestern United States on the Gulf of Mexico
#
# be priced at ||| have the quality of being; (copula, used with an adjective or a predicate noun)
#
# a form of government whose head of state is not a monarch ||| a political system in which the supreme power lies in a body of citizens who can elect people to represent them
#
# allow the presence of or allow (an activity) without opposing or prohibiting ||| consent to, give permission
#
# indicate through a symbol, formula, etc. ||| the group of people comprising the government of a sovereign state
#
# be stricken by an illness, fall victim to an illness ||| take on as one's own the expenses or debts of another person
#
# have confidence or faith in ||| a fund that a customer has entrusted to a bank and from which the customer can make withdrawals
#
# put forth and grow sprouts or shoots ||| the capital raised by a corporation through the issue of shares entitling holders to an ownership interest (equity)
#
# very unusual; different in character or quality from the normal or expected; - Lance Morrow ||| not the same one or ones already mentioned or implied; - the White Queen
#
# indicating grammatical person ||| movable property (as distinguished from real estate)
#
# a grammatical category used in the classification of pronouns, possessive determiners, and verb forms according to whether they indicate the speaker, the addressee, or a third party ||| a human being
#
# nonexistent ||| be absent
#
# ground_truth 轉不過去
# a body of students who graduate together ||| a period of time containing 365 (or 366) days
#
# comparative of much; to a greater degree or extent ||| (comparative of `many' used with count nouns) quantifier meaning greater in number
#
# publicize or announce by placards ||| a statute in draft before it becomes law
#
# being the one previously mentioned or spoken of ||| express in words
#
# make a blueprint of ||| draw up an outline or sketch for something
#
# concerning the speaker ||| as yourself
#
# take by force ||| to cause to do through pressure or necessity, by physical, moral or intellectual means :
#
# have confidence or faith in ||| a financial institution that accepts deposits and channels the money into lending activities
#
# protection against future loss ||| a financial institution that sells insurance
#
# a pipe used to transport liquids or gases ||| a company that operates oil pipelines for the oil industry
#
# very unusual; different in character or quality from the normal or expected; - Lance Morrow ||| not the same one or ones already mentioned or implied; - the White Queen
#
# slang for a paunch ||| a business firm whose articles of incorporation have been approved in some state
#
# complain about; make a charge against ||| to give an account or representation of in words
#
# ground_truth 轉不過去
# any movable articles or objects used on the set of a play or movie ||| something owned; any tangible or intangible possession that is owned by someone
#
# indicate through a symbol, formula, etc. ||| the treasurer for a state government
#
# the property that reverts to the state ||| a reversion to the state (as the ultimate owner of property) in the absence of legal heirs
#
# the force of policemen and officers ||| legal document setting forth rules governing a particular kind of activity
#
# forced or compelled or put in force ||| ensure observance of laws and rules
#
# in the immediate past ||| in these times; - Nancy Mitford
#
# be priced at ||| have the quality of being; (copula, used with an adjective or a predicate noun)
#
# (of actions or states) slightly short of or not quite accomplished; all but ||| (of actions or states) slightly short of or not quite accomplished; all but
#
# used of persons or their behavior ||| not capable of occurring or being accomplished or dealt with
#
# take up residence and become established ||| discover the location of; determine the place of; find by searching or examining
#
# ground_truth 轉不過去
# any movable articles or objects used on the set of a play or movie ||| something owned; any tangible or intangible possession that is owned by someone
#
# declared as fact; explicitly stated ||| state emphatically and authoritatively
#
# a professional person authorized to practice law; conducts lawsuits or gives legal advice ||| a professional person authorized to practice law; conducts lawsuits or gives legal advice
#
# to establish a mapping (of mathematical elements or sets) ||| be representative or typical for
#
# measure the depth of (a body of water) with a sounding line ||| appear in a certain way
#
# the major political party opposed to the party in office and prepared to replace it if elected ||| a contestant that you are matched against
#
# give the keynote address to (an audience) ||| the principal theme in a speech or literary work
#
# being the one previously mentioned or spoken of ||| express in words
#
# take by force ||| to cause to do through pressure or necessity, by physical, moral or intellectual means :
#
# have confidence or faith in ||| a financial institution that accepts deposits and channels the money into lending activities
#
# destroy and strip of its possession ||| act in disregard of laws, rules, contracts, or promises
#
# relating to or part of a binding legal agreement ||| relating to or part of a binding legal agreement
#
# a legal agreement specifying a payment or action and the penalty for failure to comply ||| the social force that binds you to the courses of action demanded by that force; ; - John D.Rockefeller Jr
#
# a person who has deposited money in a bank or similar institution ||| a person who has deposited money in a bank or similar institution
#
# hollow out as if making a cave or opening ||| destroy property or hinder normal operations
#
# a secret that is confided or entrusted to another ||| a feeling of trust (in someone or something)
#
# have confidence or faith in ||| a financial institution that accepts deposits and channels the money into lending activities
#
# someone who pays for goods or services ||| someone who pays for goods or services

# %%
print(sent[3])
print(word[3])
print(ground_truth[3])
print(candidate_lemmas[3])
# Out:
# the fulton county grand jury said friday an investigation of [MASK] 's recent primary election produced " no evidence " that any irregularities took place .
# atlanta
# atlanta%1:15:00::
# ['California', 'Virginia', 'Florida', 'Arizona', 'Alabama']

# %%
ground_truth[4]
# Out:
# 'recent%3:00:00:past:00'

# %% [markdown]
# For evaluation purpose, for i = 50, please run the process and print out the following:
# 1. word[50]
# 2. ground_truth[50] (in synset or lemma)
# 3. sent[50]
# 4. candidate_lemmas
# 5. predicted_sense (in synset or lemma)
#
# Also, please print out the accuracy of the process over our dataset

# %%
hit = wn.synset('hit.v.01')
slap = wn.synset('slap.v.01')
print(type(hit))
wn.path_similarity(hit, slap)
# Out:
# <class 'nltk.corpus.reader.wordnet.Synset'>
# 0.14285714285714285

# %%
print(f'correct: {correct}, total: {total}')

score = correct/(total-ground_err)
print(f'acc: {score}')
# Out:
# correct: 305, total: 1042
# acc: 0.31671858774662515

# %% [markdown]
# ## TA's Note
#
# Congratulations, you made it to the end of the tutorial! Make sure you make an appointment to show your work and turn in your finished assignment before next week's lesson. We will ask you to run your code, so double check that everything is working and that your model is saved. Don't worry if you didn't pass the evaluation requirements, you'll still get partial points for trying.

# %%
# word[50]
# ground_truth[50] (in synset or lemma)
# sent[50]
# candidate_lemmas
# predicted_sense (in synset or lemma)    

def eva(i):
    print(f'+ word[{i}]: {word[i]}\n')
    print(f'+ ground_truth[{i}]: {wn.lemma_from_key(ground_truth[i]).synset()}\n')
    print(f'+ sent[{i}]: {sent[i]}\n')
    print(f'+ candidate_lemmas[{i}]: {candidate_lemmas[i]}\n')
    print(f'+ predicted_sense[{i}]: {ppredict[i]}\n')

# %%
eva(50)
# Out:
# + word[50]: size
#
# + ground_truth[50]: Synset('size.n.01')
#
# + sent[50]: " only a relative handful of such reports was received " , the jury said , " considering the widespread interest in the election , the number of voters and the [MASK] of this city " .
#
# + candidate_lemmas[50]: ['population', 'reputation', 'status', 'character', 'history']
#
# + predicted_sense[50]: Synset('size.n.02')
